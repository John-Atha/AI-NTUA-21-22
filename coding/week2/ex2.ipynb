# %% [markdown]
# ## Ομάδα
#
# Στοιχεία Μέλους 1: Αθανασίου Ιωάννης, 03117041
#
# Στοιχεία Μέλους 2:

# %% [markdown]
# # Τεχνητή Νοημοσύνη: Εργαστηριακή Άσκηση 2
# ---
#
# Ο στόχος της εργασίας είναι η κατασκευή ενός συστήματος προτάσεων (Recommendation System) για ταινίες. Οι προτάσεις αυτές θα πηγάζουν τόσο από τα χαρακτηριστικά της ταινίας όσο και από ορισμένες αξιολογήσεις του κάθε χρήστη.
#
# Στα δεδομένα της άσκησης περιλαμβάνονται ένα αρχείο με το όνομα movies_metadata.csv το όποιο περιέχει τα χαρακτηριστικά κάθε ταινίας όπως θέμα, σκηνοθέτης ηθοποιοί, λέξεις κλειδιά κ.α. από το imdb καθώς και τα αρχεία ratings.csv τα όποια περιέχουν πραγματικές αξιολογήσεις χρηστών, χωρισμένες σε train και σε test.

# %% [markdown]
# ## Εκφώνηση
# Στην παρούσα εργασία σας ζητείται να μελετήσετε και να υλοποιήσετε τα παρακάτω:<br>

# %% [markdown]
# ### Μέρος 1

# %% [markdown]
# Στο μέρος 1 και 2 θα εργαστείτε μόνο με το αρχείο movies_metadata.csv, ενώ στο μέρος τρία θα δουλέψετε και με τα αρχεία των αξιολογήσεων.
# #### Ερώτημα 1α
#
# Αρχικά θα πρέπει, αφού μελετήσετε τη δομή και τα χαρακτηριστικά του movies_metadata.csv, να κατασκευάσετε μια βάση γνώσης για την Prolog η όποια ουσιαστικά θα αποτελεί τον κόσμο με τον όποιο θα εργαστείτε στην συνέχεια. Τα κατηγορήματα που θα δημιουργηθούν θα σας βοηθήσουν και στην κατασκευή του recommender και θα είναι της μορφής:
#
# ```
# director(Movie, Director).
# genre(Movie, Genre).
# ```
# #### Ερώτημα 1β
#
# Αφού δημιουργήσετε τον κόσμο του προβλήματος, στη συνέχεια καλείστε να δημιουργήσετε, σε Prolog, απλούς κανόνες οι οποίοι θα βρίσκουν όλες τις ταινίες με:
# 1.	Κοινό θέμα (κάποιες λέξεις σχετικά με το genre κοινές)
# 2.	Αρκετά κοινό θέμα (κάποιες λιγότερες λέξεις σχετικά με το genre κοινές π.χ. 3)
# 3.	Σχετικά κοινό θέμα (λίγες λέξεις σχετικές με το genre κοινές π.χ. 1)
# 4.	Κοινός σκηνοθέτης
# 5.	Ακριβώς ίδια πλοκή (κάποιες λέξεις κλειδιά της πλοκής κοινές)
# 6.	Σχετικά ίδια πλοκή (κάποιες λιγότερες λέξεις κλειδιά κοινές)
# 7.	Ίδιους τους βασικούς ηθοποιούς (και τους 3)
# 8.	Αρκετά ίδιους βασικούς ηθοποιούς (ορισμένους βασικούς ηθοποιούς κοινούς π.χ. 2)
# 9.	Σχετικά ίδιους ηθοποιούς (π.χ. 1 από τους 3)
# 10.	Ίδια γλώσσα
# 11.	Είναι έγχρωμες ή ασπρόμαυρες
# 12. Κοινό studio παραγωγής
# 13. Κοινή χώρα παραγωγής
# 14. Ίδια δεκαετία
#
# Αξίζει να σημειωθεί ότι στα παραπάνω μπορείτε να προσθέσετε περισσότερα ερωτήματα ή να αλλάξετε την κλιμακωσιμότητα των queries (πέρα από το ίδιο, αρκετά ίδιο, σχετικά ίδιο) που θα κατασκευάσετε(π.χ. μια κλίμακα από 1 στα 5 όπου αυτό είναι δυνατόν), μιας και αυτά στην συνέχεια θα χρησιμοποιηθούν για την λειτουργία του recommender. Έτσι μπορείτε να προσθέσετε queries με τα όποια μπορεί να παράγονται καλύτερες συστάσεις  (το αρχείο movie_metadata.csv περιέχει πολλές πληροφορίες ακόμα για κάθε ταινία όπως έτος κυκλοφορίας, βαθμολογία στο imdb, facebοok_likes κ.α.). Το συγκεκριμένο μέρος εργασίας είναι προπαρασκευαστικό οπότε όσο καλύτερα και πλουσιότερα τα ερωτήματα που θα φτιάξετε σε αυτό το μέρος τόσο καλύτερη θα είναι η απόδοσή των συστημάτων συστάσεων των επόμενων ερωτημάτων.
#
# Περισσότερες πληροφορίες για το dataset μπορείτε να διαβάσετε σε αυτό το [Link](https://www.kaggle.com/georgefila/movies-metadata):

# %% [markdown]
# ### Μέρος 2: Recommendation System

# %% [markdown]
# Στο σημείο αυτό καλείστε με βάση αυτά που κάνατε στο μέρος 1 να κατασκευάσετε queries τα όποια θα σας επιστρέφουν παρόμοιες (σε χαρακτηριστικά) ταινίες. Τα ερωτήματα αυτά θα είναι κλιμακούμενα, δηλαδή θα υπάρχουν ερωτήματα που επιστρέφουν αρκετά κοινές ταινίες αλλά και που επιστρέφουν λιγότερο και λιγότερο κοινές (σε μια κλίμακα π.χ. από 1 σε 5). Για παράδειγμα:
#
# ```
# find_simmilar_movies_5("Pirates Of The Caribbean", M).
# M = "Pirates Of The Caribbean: On Stranger Tides"
# M = "The Chronicles Of Narnia"
# M = "Prince Of Persia: The Sands Of Time"
# ...
# ```
# Για παράδειγμα, το παραπάνω ερώτημα θα επιστρέφει αρκετά κοινές σε περιεχόμενο ταινίες με την ταινια "Pirates Of The Caribbean". Θα υπάρχουν και αντίστοιχα ερωτήματα που θα βρίσκουν λιγότερο όμοιες ταινίες. Ο δείκτης ομοιότητας των ταινιών είναι αυθαίρετος και μπορείτε να τον ορίσετε εσείς όπως θέλετε, αρκεί να υπάρχει κάποια λογική σύνδεση με τα δεδομένα που περιέχονται στο αρχείο movies_metadata.csv.
#
# Συνεπώς η συνάρτηση που θα κάνει τις προτάσεις (recommendation) με είσοδο μια ταινία πρέπει να επιστρέφει-εκτυπώνει μια λίστα με τις προτεινόμενες ταινίες κατά φθίνουσα σειρά ομοιότητας.

# %% [markdown]
# ### 3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις - Αξιολογήσεις του χρήστη

# %% [markdown]
# Σε αυτό το σημείο θα εργαστείτε με τα αρχεία ratings τα όποια περιέχουν αξιολογήσεις (από 1 μέχρι 5) για τις παραπάνω ταινίες. Το προηγούμενο σύστημα συστάσεων προτείνει στον χρήστη ταινίες αποκλειστικά με βάση την ομοιότητά τους. Σε αυτό το σημείο θα γίνει μια αναβάθμιση του συστήματος έτσι ώστε να παράγονται καλύτερες  συστάσεις οι όποιες θα λαμβάνουν υπόψιν και τις προτιμήσεις του χρήστη, οι όποιες θα εξάγονται από τις αξιολογήσεις που έχει κάνει μέχρι στιγμής.
#
# Η εκπαίδευση του recommender θα γίνεται ως εξής:
#
# Για κάθε ταινία θα υπάρχει ένα score το όποιο αρχικά θε είναι ίσο με 0 και θα διαμορφώνεται από τις αξιολογήσεις κάθε user. Έτσι για έναν χρήστη με βάση τις αξιολογήσεις που υπάρχουν στο αρχείο train_ratings θα πρέπει:
#
# 1.	Για κάθε ταινία που έχει βαθμολογήσει να βρίσκονται οι κοινές ταινίες ανά κλίμακα και στο μέχρι τώρα σκορ κάθε παρόμοιας ταινίας θα προστίθεται ένα βάρος το όποιο θα μπορούσε να είναι το ποσοστό ομοιότητας της ταινίας (δηλαδή ένα βάρος για κάθε κλίμακα, αν δύο ταινίες μοιάζουν ενισχύουμε το βάρος που προσθέτουμε από το να μοιάζουν λιγότερο) επί τον βαθμό που έχει βάλει ο χρήστης για την αρχική ταινία (διαφορετικό είναι ο χρήστης να έχει βάλει 5/5 ή 1/5 σε μια ταινία από 3/5).
#
# 2. Στη συνέχεια, ανάλογα με το σκορ που έχει σχηματιστεί για κάθε ταινία, θα επιλέγεται αν αυτή θα μπορούσε να είναι προτεινόμενη για τον χρήστη ή όχι και θα μετράμε το πόσο καλά τα πήγε το σύστήμά μας με βάση ορισμένες μετρικές.
#
# Η λογική πίσω από την παραπάνω διαδικασία είναι ότι παρόμοιες ταινίες θα έχουν ανάλογο βαθμό. Για παράδειγμα αν ένας χρήστης έχει αξιολογήσει αρκετές  ταινίες οι όποιες είναι sci-fiction με 5/5 τότε μια ταίνια sci-fiction την όποια δεν έχει δεί λογικά θα του αρέσει και θα έπρεπε να την προτείνουμε.
#
# Μετά την εκπαίδευση του συστήματος σας καλείστε να δοκιμάσετε τον recommender που κατασκευάσατε στην πράξη. Για τον σκοπό αυτό θα φορτώσετε το αρχείο test_ratings.csv όπου περιέχονται οι αξιολογήσεις του ίδιου χρήστη για άλλες ταινίες. Το σύστημά σας πρέπει να προβλέπει αν μια ταινία θα πρέπει να προταθεί στον χρήστη. Μια ταίνια θα έπρεπε να έχει προταθεί στον  χρήστη, αν έχει βαθμό μεγαλύτερο του 3. Συνεπώς για την επίβλεψη του συστήματός σας θα πρέπει για κάθε μια από τις ταινίες του αρχείου test_ratings.csv να επιστρέφεται 1 ή 0 αν η ταινία θα έπαιρνε βαθμό μεγαλύτερο του 3 ή όχι, δηλαδή αν θα έπρεπε να την είχαμε προτείνει ή όχι.
#
# Στην συνέχεια, σε συνδιασμό με τις πραγματικές απαντήσεις του χρήστη θα αξιολογήσετε το σύστημά σας χρησιμοποιόντας τις μετρικές: precision, recall, f1 οι οποίες είναι οι πλέον γνωστές μετρικές και ευρέως χρησιμοποιούμενες τεχνικές για την επίβλεψη-μέτρηση απόδοσης ανάλογων συστημάτων.
#
# 1. Precision: Δείχνει πόσο ακριβές είναι το σύστημα. Υπολογίζει πόσα από τα στιγμιότυπα τα όποια προβλέψαμε ότι ανήκουν σε μια κλάση όντως ανήκουν σε αυτή. Η μετρική αυτή μας δίνει μια εικόνα σχετικά με τον αριθμό των ταινίων που προβλέψαμε ως προτεινόμενες ενώ δεν θα έπρεπε.
#
# 2. Recall: Υπολογίζει πόσα από τα στιγμιότυπα που ανήκουν σε μια κλάση (π.χ. προτεινόμενες ταινίες) προβλέφθηκαν σωστά.
#
# 3. F1: Είναι ένας μέσος μεταξύ των παραπάνω δυο μετρικών, έτσι ώστε να διατηρείται μια ισορροπία μεταξύ τους. Υπολογίζεται από την παρακάτω σχέση:
#
# $$F_1=2\frac{Precision\times{Recall}}{Precision+Recall}$$
#
# Οι παραπάνω συναρτήσεις παρέχονται από την βιβλιοθήκη scikit-learn.
#
# Τέλος για την καλύτερη επίβλεψη του συστήματος σας μπορείτε να εκπαιδεύσετε  τον recommender σας με ένα υποσύνολο ταινίων από ελάχιστες, λίγες μέχρι και πολλές (π.χ. 3, 5, 10, 50, ...) για να μελετήσετε κατά πόσο σας βοηθούν οι επιπλέον αξιολογήσεις κάθε φορά (δηλαδή κατά πόσο βελτιώνονται οι παραπάνω μετρικές στο test set).
#
# Έτσι π.χ. μπορείτε να εντοπίσετε περιπτώσεις όπως για παράδειγμα ότι με έναν recommender μπορεί να μην επιτυγχάνετε πολύ υψηλό σκορ όσο με άλλους, αλλά το βέλτιστο σκόρ σας επιτυγχάνεται πολύ γρηγόρα π.χ. με μόνο 10 ταινίες αντί 100. Έτσι για παράδειγμα αν ο αλγόριθμος τα πηγαίνει πολύ καλά για τρεις ταινίες και στη συνέχεια το σκορ βελτιώνεται ελάχιστα τότε αυτός ενδείκνυται για ένα σύστημα συστάσεων για νέους χρήστες όπου δεδομένου λίγων ταινιών ο αλγόριθμος είναι σε θέση να το να προτείνει καλές συστάσεις. Ενώ αν η καλύτερη απόδοση του αλγορίθμου σας είναι βέλτιστη με περισσότερες ταινίες π.χ. 50 τότε αυτός ο αλγόριθμος συστάσεων ενδείκνυται για παλιούς χρήστες με πολλές αξιολόγησεις.

# %% [markdown]
# ---
# ## Κατασκευή Περιβάλλοντος Εργασίας
# ---

# %% [markdown]
# ### Διάβασμα Αρχείων στο Colab (Μόνο για το Colab)
# Αν η υλοποίηση γίνει στο google colab τότε μπορεί να χρησιμοποιηθεί το google drive ως file system. Για να γίνει Mount το google drive τρέχουμε τον παρακάτω κώδικα και κλικάρουμε στο link που θα μας εμφανιστεί.
#
# ```
# from google.colab import drive
# drive.mount('/content/drive')
# import os
# os.listdir('/content/drive/My Drive')
# ```
# Έπειτα στην σελίδα που άνοιξε επιλέγουμε το mail μας και στο επόμενο παράθυρο που θα μας ανοίξει πατάμε Να επιτρέπεται. Στην συνέχεια αντιγράφουμε τον κωδικό που θα μας βγάλει και τον κάνουμε paste στο Input που έχει ανοίξει στο colab. Έτσι πλέον αν έχουμε ανεβάσει ένα αρχείο στο google drive μπορούμε να το βρούμε στην θέση:
#
# ```
# movies_filename = '/content/drive/My Drive/' + movies_metadata.csv
# ```
# Μπορούμε πλέον κανονικά να δουλέψουμε φτιάχνοντας φακέλους ή αρχεία και γενικότερα κάνοντας οτιδήποτε θα κάναμε αν ήμασταν τοπικά.
#
# ### Prolog μέσω Python
#
# Το πακέτο που θα χρησιμοποιηθεί για την επικοινωνία Python και Prolog είναι το pyswip (https://pypi.org/project/pyswip/). Για να δουλέψει το Pyswip  χρειάζεται να υπάρχει το Swi-Prolog το όποιο αν δουλεύουμε τοπικά πρέπει να το εγκαταστήσουμε, ακολουθώντας αντίστοιχες οδηγίες στην σελίδα του εργαλείου. Για να γίνει του Swi-Prolog η εγκατάσταση στο Google Colab πρέπει να τρέξουμε τον παρακάτω κώδικα:
#
# ```
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog/stable
# !sudo apt-get update
# !sudo apt-get install swi-prolog
# ```
# Σε κάποιο σημείο της εκτέλεσης εμφανίζεται ένα μήνυμα ότι πρέπει να πατήσουμε enter σε ένα input για να συνεχίσει η διαδικασία. Έπειτα από αυτό η εκτέλεση θα συνεχίσει χωρίς κάποιο πρόβλημα.
#
# Τέλος πρέπει να εγκαταστήσουμε το pyswip (**όπου και να δουλεύουμε**) όπως παρακάτω:
#
# ```
# !pip isntall pyswip
# ```

# %% [markdown]
# ---
# # Κώδικας για κατασκευή περιβάλλοντος εργασίας
#
# ## Μόνο για Google Colab
#
# Κώδικας για να γίνει Mount to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
path="" # με ευκόλο τρόπο μπορείτε να αλλάξετε το path που είναι αποθηκευμένα τα αρχεία σας
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_21900/2048306587.py in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#       3
#       4 import os
#       5 path="" # με ευκόλο τρόπο μπορείτε να αλλάξετε το path που είναι αποθηκευμένα τα αρχεία σας
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
# %%capture
#install swi-prolog
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog
# !sudo apt-get update
# !sudo apt-get install swi-prolog
#install pyswip
# !pip install pyswip
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     161                 # know whether we've finished (if we matched EOF) or not
# --> 162                 res_idx = child.expect_list(patterns, self.read_timeout)
#     163                 print(child.before[out_size:].decode(enc, 'replace'), end='')
#
# /usr/lib/python3/dist-packages/pexpect/spawnbase.py in expect_list(self, pattern_list, timeout, searchwindowsize, async_, **kw)
#     368         else:
# --> 369             return exp.expect_loop(timeout)
#     370
#
# /usr/lib/python3/dist-packages/pexpect/expect.py in expect_loop(self, timeout)
#     110                 # Still have time left, so read more data
# --> 111                 incoming = spawn.read_nonblocking(spawn.maxread, timeout)
#     112                 if self.spawn.delayafterread is not None:
#
# /usr/lib/python3/dist-packages/pexpect/pty_spawn.py in read_nonblocking(self, size, timeout)
#     469         else:
# --> 470             r, w, e = select_ignore_interrupts(
#     471                 [self.child_fd], [], [], timeout
#
# /usr/lib/python3/dist-packages/pexpect/utils.py in select_ignore_interrupts(iwtd, owtd, ewtd, timeout)
#     142         try:
# --> 143             return select.select(iwtd, owtd, ewtd, timeout)
#     144         except InterruptedError:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_21900/1576051914.py in <module>
#       2 get_ipython().system('sudo apt-get install software-properties-common')
#       3 get_ipython().system('sudo apt-add-repository ppa:swi-prolog')
# ----> 4 get_ipython().system('sudo apt-get update')
#       5 get_ipython().system('sudo apt-get install swi-prolog')
#       6 #install pyswip
#
# ~/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py in system_piped(self, cmd)
#     635                 self.user_ns['_exit_code'] = system(cmd)
#     636         else:
# --> 637             self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#     638
#     639     # Ensure new system_piped implementation is used
#
# ~/.local/lib/python3.8/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     184             finally:
#     185                 # Ensure the subprocess really is terminated
# --> 186                 child.terminate(force=True)
#     187         # add isalive check, to ensure exitstatus is set:
#     188         child.isalive()
#
# /usr/lib/python3/dist-packages/pexpect/pty_spawn.py in terminate(self, force)
#     621                 return True
#     622             self.kill(signal.SIGCONT)
# --> 623             time.sleep(self.delayafterterminate)
#     624             if not self.isalive():
#     625                 return True
#
# KeyboardInterrupt:

# %% [markdown]
# # **Μέρος 1: Μελέτη των Metadata, Δημιουργία κόσμου και των βασικών queries.**

# %% [markdown]
# ### Μέρος 1Α - Κατασκευή βάσης γνώσης

# %%
import pandas as pd
from pyswip import Prolog

# %%
# Η βιβλιοθήκη pandas είναι χρήσιμη για την εργασία με τέτοια δεδομένα
import pandas as pd 
# Διάβασμα του αρχείου 'movie_metadata.csv' 
path=""
data = pd.read_csv(path + "movies_metadata.csv") 
#Στο csv υπαρχούν κελία με nan τιμές
#Στις θέσεις αυτές βάζουμε 'UNK' πράγμα που  κάνουμε με την παρακάτω συνάρτηση
data.fillna("UNK", inplace=True)
# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#    Unnamed: 0     budget                                    genres  \
# 0           0  237000000  Action|Adventure|Fantasy|Science Fiction
# 1           1  300000000                  Adventure|Fantasy|Action
# 2           2  245000000                    Action|Adventure|Crime
# 3           3  250000000               Action|Crime|Drama|Thriller
# 4           4  260000000          Action|Adventure|Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                        plot_keywords  language  \
# 0  culture clash|future|space war|space colony|so...   English
# 1  ocean|drug abuse|exotic island|east india trad...   English
# 2  spy|based on novel|secret agent|sequel|mi6|bri...  Français
# 3  dc comics|crime fighter|terrorist|secret ident...   English
# 4  based on novel|mars|medallion|space travel|pri...   English
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  ...  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577  ...
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615  ...
# 2  A cryptic message from Bond’s past sends him o...  107.376788  ...
# 3  Following the death of District Attorney Harve...  112.312950  ...
# 4  John Carter is a war-weary, former military ca...   43.926995  ...
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                 movie_title vote_average  num_voted_users  \
# 0                                    Avatar          7.2            11800
# 1  Pirates of the Caribbean: At World's End          6.9             4500
# 2                                   Spectre          6.3             4466
# 3                     The Dark Knight Rises          7.6             9106
# 4                               John Carter          6.1             2124
#
#   title_year                   country      director_name     actor_1_name  \
# 0     2009.0  United States of America      James Cameron      Zoe Saldana
# 1     2007.0  United States of America     Gore Verbinski    Orlando Bloom
# 2     2015.0            United Kingdom         Sam Mendes  Christoph Waltz
# 3     2012.0  United States of America  Christopher Nolan    Michael Caine
# 4     2012.0  United States of America     Andrew Stanton     Lynn Collins
#
#        actor_2_name       actor_3_name
# 0  Sigourney Weaver       Stephen Lang
# 1   Keira Knightley  Stellan Skarsgård
# 2       Léa Seydoux      Ralph Fiennes
# 3       Gary Oldman      Anne Hathaway
# 4   Samantha Morton       Willem Dafoe
#
# [5 rows x 27 columns]

# %%
def clean_text(text):
    text = text.replace(u'\xa0', u'')
    text = text.replace(u"'", u'')
    return text

# %%
import json
from copy import copy

def parse_object_str_to_json(st):
    '''
    * used to parse object-like string as json
    * replace --in the middle of strings-- (") with (\")
    * use the json.loads() method
    '''
    s = copy(st)
    s = s.replace("'", '"')
    for i in range(len(s)):
        if s[i]=='"':
            if s[i-1]=="\\":
                continue
            elif s[i-1]=='{' or s[i+1]=='}':
                pass
            elif s[i+1]==',' or s[i+1]==':':
                pass
            elif s[i-2:i]==', ' or s[i-2:i]==': ':
                pass
            else:
                s = s[:i] + '\\' + s[i:]
    s = json.loads(s)
    return s


prolog = Prolog()

# list with all the KB literals
literals = []

for row in data.itertuples(index=True, name='Pandas'):
    movie_title = clean_text(getattr(row, 'movie_title'))
    
    # parse the single-valued attributes (for example genre is not a single-valued attribute, as it contains a list)
    singles = [
        'budget', 'homepage', 'language', 'original_title',
        'overview', 'popularity', 'release_date', 'gross', 'duration',
        'status', 'tagline', 'vote_average',
        'num_voted_users', 'title_year', 'country', 'director_name',
        'actor_1_name', 'actor_2_name', 'actor_3_name',
    ]    
    for attr in singles:
        val = getattr(row, attr)
        if isinstance(val, str):
            if '"' in val:
                val = val.replace('"', '\\"')
        literals.append(f"{attr}(\"{movie_title}\", \"{val}\")")
        
    # parse the multi-valued attributes
    for genre in getattr(row, 'genres').split("|"):
        genre = genre.replace('"', '\\"')
        literals.append(f"genre(\"{movie_title}\",\"{genre}\")")
    
    
    for plot_keyword in getattr(row, 'plot_keywords').split("|"):
        plot_keyword = plot_keyword.replace('"', '\\"')
        literals.append(f"plot_keyword(\"{movie_title}\",\"{plot_keyword}\")")

    companies = getattr(row, 'production_companies')
    companies = parse_object_str_to_json(companies)
    for company in companies:
        literals.append(f"production_company(\"{movie_title}\", \"{company['id']}\")")
    
    countries = getattr(row, 'production_countries')
    countries = parse_object_str_to_json(countries)
    for country in countries:
        literals.append(f"production_country(\"{movie_title}\", \"{country['iso_3166_1']}\")")
    
    languages = getattr(row, 'spoken_languages')
    languages = parse_object_str_to_json(languages)
    for lang in languages:
        literals.append(f"spoken_languages(\"{movie_title}\", \"{lang['iso_639_1']}\")")

# sort the literals and write them in a swipl file
literals.sort()
f = open("knowledge_base.pl", "w+")
for literal in literals:
    f.write(literal+'.\n')

# %% [markdown]
# ### Μέρος 1Β - κατασκευή ερωτημάτων

# %%
# I have written the queries in the queries.pl file
prolog.consult('knowledge_base.pl')
prolog.consult('queries.pl')

# %% [markdown]
# # **2ο Μέρος: Recommendation System με βάση μόνο τα χαρακτηριστικά των ταινιών.**

# %% [markdown]
# Στο σημείο αυτό με βάση τους κανόνες που κατασκευάστηκαν στο Μέρος 1 θα κατασκευαστούν κατηγορήματα για την ομοιότητα ταινιών. Παρακάτω δίνεται ένα μικρό παράδειγμα ενός κανόνα και πώς αυτός θα μπορούσε να γραφτεί μέσω του Pyswip. Επίσης όπως αναφέρεται και σε σχόλιο παραπάνω θα μπορεί να γραφτεί και μια βάση δεδομένων με τους κανόνες και να γίνει απευθείας consult.
#
# Στο παρακάτω παράδειγμα το 5 και το 4 εκφράζουν την ομοιότητα των ταινιών π.χ. οι ταινίες που παράγονται μέσω του find_similar_5 είναι πιο όμοιες από αυτές που παράγονται μέσω του find_similar_4.

# %%
# similarity checking queries are written in db.pl file
prolog.consult("db.pl")
# testing the most similar movies to the "Avatar" movie
q = prolog.query("find_sim_5(\"Avatar\", Y)")
s = set()
for soln in q:
    m = soln['Y'] 
    if m not in s:
        s.add(soln['Y'].decode("utf-8"))
print(s)
# Out:
# {'Predators', 'Star Trek Into Darkness', 'Guardians of the Galaxy', 'Alien', 'The Fifth Element', 'John Carter', 'Galaxina', 'Pirates of the Caribbean: On Stranger Tides', 'Alien³', 'Aliens'}

# %% [markdown]
# * Υλοποιώ τις συναρτήσεις simple_recommender, recommender_2, recommender_3, recommender_4 και recommender_5 που χρησιμοποιούν τα αντίστοιχα find_sim{index} queries της prolog, και βρίσκουν όμοιες ταινίες με διαφορετικά επίπεδα ομοιότητας.
# * Προσπαθώ οι προτάσεις να ξεκινούν από περίπου 100 για τον simple_recommender, να μειώνονται όσο οι συναρτήσεις εξειδικεύονται, και να φτάνουν περίπου σε μονοψήφιο αριθμό στον recommender_5.

# %%
prolog.consult('queries.pl')
prolog.consult("db.pl")

def recommender_body(method, movie, query=None):
    s = set()
    if not query:
        query = f"{method}(\"{movie}\",M)"
        # print(query)
    q = prolog.query(query)
    for soln in q:
        m = soln['M'] 
        if m not in s:
            s.add(soln['M'].decode("utf-8"))
    q.close()
    answers = s
    return answers

# use the swipl similarity-checking queries to inside the python code
def dummy_recommender(movie):
    return recommender_body(None, None, query=f"status(M, \"Released\")" )

def simple_recommender(movie):
    return recommender_body('find_sim_1', movie)

def recommender_2(movie):
    return recommender_body('find_sim_2', movie)

def recommender_3(movie):
    return recommender_body('find_sim_3', movie)

def recommender_4(movie):
    return recommender_body('find_sim_4', movie)

def recommender_5(movie):
    return recommender_body('find_sim_5', movie)

recommenders = [
    simple_recommender,
    recommender_2,
    recommender_3,
    recommender_4,
    recommender_5,
]

# %% [markdown]
# * Διαλέγω τυχαία τέσσερις ταινίες από το dataset και βρίσκω τις όμοιες ταινίες τους χρησιμοποιώντας τις προηγούμενες συναρτήσεις.
# * Για κάθε ταινία εκτυπώνω το πλήθος των ταινιών που πρότεινε η κάθε μία συνάρτηση.
#     * Για τις πιο εξειδικευμένες συναρτήσεις (find_sim_3, find_sim_4, find_sim_5) εκτυπώνω και ποιες ήταν οι
#       προτάσεις, αφού αυτές είναι πιο λίγες και έτσι μπορώ να έχω ένα δείγμα της ποιότητας του συστήματος.

# %%
# some tests...
titles = [
    "Avatar",
    "How to Train Your Dragon",
    "Pirates of the Caribbean: At Worlds End",
    "Batman v Superman: Dawn of Justice",
    "Batman",
]

for title in titles:
    recs = [rec(title) for rec in recommenders]
    print('-->', title)
    print("Number of suggestions:")
    print('rec1\t| rec2\t| rec3\t| rec4\t| rec5\t|')
    print('-----------------------------------------')
    for rec in recs:
        print(len(rec), end= '\t| ')
    print()
    for rec in [('Recommender 3', recs[2]), ('Recommender 4', recs[3]), ('Recommender 5', recs[4])]:
        print()
        print(f"{rec[0]}:")
        print(rec[1])
    print('-----------------------------------'*3)
    print()
# Out:
# --> Avatar
# Number of suggestions:
# rec1	| rec2	| rec3	| rec4	| rec5	|
# -----------------------------------------
# 136	| 75	| 54	| 34	| 10	|
#
# Recommender 3:
# {'Star Trek Into Darkness', 'Across the Universe', 'Edge of Tomorrow', 'Total Recall', 'How to Train Your Dragon', 'The Muppet Christmas Carol', 'The Thing', 'Interstellar', '2001: A Space Odyssey', 'Frozen', 'Aliens', 'The Longest Day', 'Maleficent', 'The Hunger Games: Catching Fire', 'How to Train Your Dragon 2', 'Batman: The Dark Knight Returns, Part 2', 'Source Code', 'The Fifth Element', 'Dawn of the Planet of the Apes', 'Gravity', 'Captain America: The Winter Soldier', 'Avengers: Age of Ultron', 'Big Hero 6', 'Captain America: Civil War', 'Frequency', 'Apocalypto', 'Dances with Wolves', 'Star Trek', 'The Wild Bunch', 'Batman Begins', 'Sleeper', 'The Little Prince', 'The Last Samurai', 'Ant-Man', 'Solaris', 'The Empire Strikes Back', 'Minority Report', 'The Martian', 'K-PAX', 'Dark City', 'Mad Max: Fury Road', 'Alien', 'Guardians of the Galaxy', 'Moon', 'Treasure Planet', 'District 9', 'Metropolis', 'Seven Samurai', 'Hugo', 'Close Encounters of the Third Kind', 'The Hobbit: The Battle of the Five Armies', 'Predator', 'Children of Men', 'Platoon'}
#
# Recommender 4:
# {'Independence Day', 'Star Trek Into Darkness', 'Home', 'Battle: Los Angeles', 'Edge of Tomorrow', 'Interstellar', 'Green Lantern', 'Aliens', 'Terminator Genisys', 'Renaissance', 'The Fifth Element', 'Titan A.E.', 'I, Robot', 'Captain America: The Winter Soldier', 'John Carter', 'Pirates of the Caribbean: On Stranger Tides', 'Jimmy Neutron: Boy Genius', 'Alien³', 'Silent Running', 'Enders Game', 'Predators', 'Jupiter Ascending', 'A Monster in Paris', 'Meet Dave', 'Stargate: The Ark of Truth', 'The Hitchhikers Guide to the Galaxy', 'Alien', 'Guardians of the Galaxy', 'Planet of the Apes', 'Treasure Planet', 'You Only Live Twice', 'Lockout', 'Predator', 'Planet 51'}
#
# Recommender 5:
# {'Predators', 'Star Trek Into Darkness', 'Guardians of the Galaxy', 'Alien', 'The Fifth Element', 'John Carter', 'Galaxina', 'Pirates of the Caribbean: On Stranger Tides', 'Alien³', 'Aliens'}
# ---------------------------------------------------------------------------------------------------------
#
# --> How to Train Your Dragon
# Number of suggestions:
# rec1	| rec2	| rec3	| rec4	| rec5	|
# -----------------------------------------
# 101	| 47	| 35	| 16	| 8	|
#
# Recommender 3:
# {'Star Trek Into Darkness', 'Jurassic Park', 'The Life Aquatic with Steve Zissou', 'The Iron Giant', 'Bridge to Terabithia', 'Hachi: A Dogs Tale', 'Pirates of the Caribbean: Dead Mans Chest', 'Dear Frankie', 'George and the Dragon', 'Toy Story 2', 'Howls Moving Castle', 'Crouching Tiger, Hidden Dragon', 'Pirates of the Caribbean: The Curse of the Black Pearl', 'Mulan', 'Gladiator', 'Apocalypto', 'Princess Mononoke', 'Petes Dragon', 'Harry Potter and the Prisoner of Azkaban', 'The Wild Bunch', 'The Hobbit: The Desolation of Smaug', 'The Mummy: Tomb of the Dragon Emperor', 'The Black Stallion', 'Avatar', 'Ernest & Celestine', 'Anne of Green Gables', 'Toy Story', 'Reign of Fire', 'Dungeons & Dragons: Wrath of the Dragon God', 'The First Great Train Robbery', 'The Last Dragon', 'The Hobbit: The Battle of the Five Armies', 'The Lego Movie', 'How to Train Your Dragon 2', 'The Incredibles'}
#
# Recommender 4:
# {'Petes Dragon', 'Beowulf', 'The Sorcerers Apprentice', 'Savva. Heart of the Warrior', 'Crouching Tiger, Hidden Dragon', 'Reign of Fire', 'Shipwrecked', 'Alvin and the Chipmunks', 'Dungeons & Dragons: Wrath of the Dragon God', 'Shrek the Third', 'George and the Dragon', 'Pirates of the Caribbean: On Stranger Tides', 'The Hobbit: The Battle of the Five Armies', 'How to Train Your Dragon 2', 'Mulan', 'Kung Fu Panda 3'}
#
# Recommender 5:
# {'Petes Dragon', 'How to Train Your Dragon 2', 'Reign of Fire', 'Dungeons & Dragons: Wrath of the Dragon God', 'Shrek the Third', 'Platoon', 'DragonHeart', 'The Mummy: Tomb of the Dragon Emperor'}
# ---------------------------------------------------------------------------------------------------------
#
# --> Pirates of the Caribbean: At Worlds End
# Number of suggestions:
# rec1	| rec2	| rec3	| rec4	| rec5	|
# -----------------------------------------
# 116	| 55	| 42	| 15	| 8	|
#
# Recommender 3:
# {'VeggieTales: The Pirates Who Dont Do Anything', 'Iron Man', 'Jurassic Park', 'Life of Pi', 'The Book of Life', 'The Life Aquatic with Steve Zissou', 'Harry Potter and the Chamber of Secrets', 'The Princess Bride', 'Pirates of the Caribbean: Dead Mans Chest', 'Captain Phillips', 'How to Train Your Dragon', 'Kill Bill: Vol. 2', 'Frozen', 'The Avengers', 'Enter the Void', 'Deadpool', 'The Hunger Games: Catching Fire', 'Cast Away', 'Captain America: The Winter Soldier', 'Aladdin', 'The Lost World: Jurassic Park', 'Pirates of the Caribbean: The Curse of the Black Pearl', 'Pirates of the Caribbean: On Stranger Tides', 'Big Hero 6', 'Captain America: Civil War', 'The Muppet Movie', 'The Ice Pirates', 'Harry Potter and the Prisoner of Azkaban', 'Scott Pilgrim vs. the World', 'Cirque du Soleil: Worlds Away', 'Ant-Man', 'Big Fish', 'Wreck-It Ralph', 'War of the Worlds', 'Guardians of the Galaxy', 'Jaws', 'The Pirates! In an Adventure with Scientists!', 'Beetlejuice', 'X-Men: Days of Future Past', 'The Abyss', 'The Worlds End', '22 Jump Street'}
#
# Recommender 4:
# {'VeggieTales: The Pirates Who Dont Do Anything', 'Harry Potter and the Prisoner of Azkaban', 'Life of Pi', 'King Kong', 'The Pirates! In an Adventure with Scientists!', 'Cutthroat Island', 'The Lost World: Jurassic Park', 'Pirates of the Caribbean: Dead Mans Chest', 'Pirates of the Caribbean: The Curse of the Black Pearl', 'The Man with the Golden Gun', 'In the Heart of the Sea', 'Pirates of the Caribbean: On Stranger Tides', 'Nims Island', 'Poseidon', 'Shrek the Third'}
#
# Recommender 5:
# {'Cutthroat Island', 'The Lost World: Jurassic Park', 'Pirates of the Caribbean: Dead Mans Chest', 'Pirates of the Caribbean: The Curse of the Black Pearl', 'In the Heart of the Sea', 'Pirates of the Caribbean: On Stranger Tides', 'Nims Island', 'Shrek the Third'}
# ---------------------------------------------------------------------------------------------------------
#
# --> Batman v Superman: Dawn of Justice
# Number of suggestions:
# rec1	| rec2	| rec3	| rec4	| rec5	|
# -----------------------------------------
# 120	| 60	| 38	| 42	| 18	|
#
# Recommender 3:
# {'Superman IV: The Quest for Peace', 'Oldboy', 'V for Vendetta', 'Iron Man', 'Sin City', 'Superman III', 'Man of Steel', 'Batman', 'Watchmen', 'The Equalizer', 'Fantastic Mr. Fox', 'Superman Returns', 'The Avengers', 'Deadpool', 'Batman: The Dark Knight Returns, Part 2', 'Superman', 'Captain America: The Winter Soldier', 'Avengers: Age of Ultron', 'Point Blank', 'Big Hero 6', 'Captain America: Civil War', 'The Revenant', 'Batman Returns', 'Batman Forever', 'The Dark Knight', 'Superman II', 'Kick-Ass', 'Batman Begins', 'Kill Bill: Vol. 1', 'Ice Age: Dawn of the Dinosaurs', 'Ant-Man', 'The Dark Knight Rises', 'Furious 7', 'X-Men: Days of Future Past', 'X-Men: First Class', 'The Lego Movie', 'Batman & Robin', 'The Incredibles'}
#
# Recommender 4:
# {'Superman IV: The Quest for Peace', 'Fantastic Four', 'Suicide Squad', 'Iron Man', 'Superman III', 'Man of Steel', 'Batman', 'Watchmen', 'Superman Returns', 'Green Lantern', 'Iron Man 3', 'The Avengers', 'Deadpool', 'Superman', 'Captain America: The Winter Soldier', 'Avengers: Age of Ultron', 'Fantastic 4: Rise of the Silver Surfer', 'Captain America: The First Avenger', 'Captain America: Civil War', 'The Incredible Hulk', 'Thor: The Dark World', 'X2', 'The Shadow', 'Batman Returns', 'Batman Forever', 'X-Men', 'Spider-Man 3', 'Superman II', 'Mystery Men', 'Batman Begins', 'Ant-Man', 'Blade: Trinity', 'Now You See Me 2', 'Thor', 'Dragonball Evolution', 'The Wolverine', 'X-Men: First Class', 'The Amazing Spider-Man 2', 'Batman & Robin', 'The Amazing Spider-Man', 'Teenage Mutant Ninja Turtles', 'Iron Man 2'}
#
# Recommender 5:
# {'Superman IV: The Quest for Peace', 'Suicide Squad', 'The Dark Knight', 'Superman', 'Superman III', 'Superman II', 'Man of Steel', 'Batman', 'Watchmen', 'Batman Begins', 'Batman & Robin', 'Iron Man 2', 'Superman Returns', 'Green Lantern', 'Teenage Mutant Ninja Turtles', 'The Dark Knight Rises', 'Batman Returns', 'Batman Forever'}
# ---------------------------------------------------------------------------------------------------------
#
# --> Batman
# Number of suggestions:
# rec1	| rec2	| rec3	| rec4	| rec5	|
# -----------------------------------------
# 259	| 194	| 36	| 24	| 15	|
#
# Recommender 3:
# {'The NeverEnding Story', 'Iron Man', 'Crimson Tide', 'Watchmen', 'Total Recall', 'Interstellar', 'The Avengers', 'Deadpool', 'The Talented Mr. Ripley', 'Batman: The Dark Knight Returns, Part 2', 'Captain America: The Winter Soldier', 'Avengers: Age of Ultron', 'Captain America: Civil War', 'Alice in Wonderland', 'The Secret Life of Walter Mitty', 'The Hunt for Red October', 'Frequency', 'Batman Returns', 'The Dark Knight', '127 Hours', 'Kick-Ass', 'Batman Begins', 'Birdman', 'Gangs of New York', 'Ant-Man', 'The Dark Knight Rises', 'The Black Stallion', 'Mad Max: Fury Road', 'Touching the Void', 'Jaws', 'Das Boot', 'Taken', 'X-Men: First Class', 'The Lego Movie', 'How to Train Your Dragon 2', 'The Incredibles'}
#
# Recommender 4:
# {'Superman IV: The Quest for Peace', 'Suicide Squad', 'Kick-Ass 2', 'Superman III', 'Man of Steel', 'Defendor', 'Green Lantern', 'Superman Returns', 'Superman', 'Deep Blue Sea', 'Alice in Wonderland', 'Batman Returns', 'Batman v Superman: Dawn of Justice', 'Batman Forever', 'The Dark Knight', 'Spider-Man 3', 'Superman II', 'Kick-Ass', 'Spider-Man 2', 'Batman Begins', 'The Spy Who Loved Me', 'The Dark Knight Rises', 'Batman & Robin', 'G.I. Joe: Retaliation'}
#
# Recommender 5:
# {'Superman IV: The Quest for Peace', 'The Dark Knight', 'Superman', 'Superman III', 'Superman II', 'Man of Steel', 'Batman Begins', 'Batman & Robin', 'Alice in Wonderland', 'Green Lantern', 'Superman Returns', 'The Dark Knight Rises', 'Batman Returns', 'Batman v Superman: Dawn of Justice', 'Batman Forever'}
# ---------------------------------------------------------------------------------------------------------

# %% [markdown]
# # **3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις-Αξιολογήσεις του χρήστη-Εκπαίδευση και Πρόβλεψη**
#
#
# Αρχικά μελετάμε τις αξιολογήσεις κάθε χρήστη για να καταλάβουμε την δομή και τις πληροφορίες κάθε αρχείου.

# %%
from tqdm.notebook import tqdm
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import random

# ανάλογα με τα επίπεδα ομοιότητας που έχουν οριστεί στην simple_recommender
score_weights = {
    1: 0,
    2: 1,
    3: 4,
    4: 8,
    5: 16,
}

rating_weights = {
    0: 1,
    1: 1,
    2: 1,
    3: 1,
    4: 1,
    5: 1,
}

def train_recommender(ratings, rating_weights, score_weights, number_of_movies = 10, rec=(recommender_3, 2)):
    """
    Στην συνάρτηση αυτή μπορούμε να ορίζουμε ποιο υποσύνολο των αξιολογήσεων θα χρησιμοποιήσουμε
    για το train μαζί με τα βάρη ομοιότητας και σκορ
    Σε συνδυασμό με τον αριθμό των ταινιών που θέλουμε να χρησιμοποιήσουμε σαν σύνολο δεδομένων
    π.χ. 10 από τις 100 ή 3 από τις 100 κ.ο.κ
    Αν θέλουμε να χρησιμοποιήσουμε όλες τις ταινίες σαν training set τότε ορίζουμε το number_of_movies = - 1
    """

    if number_of_movies > len(ratings):
        number_of_movies = len(ratings)


    if number_of_movies != -1:
        indexes = random.sample(range(len(ratings)), number_of_movies)
        ratings = ratings.iloc[indexes]

    movie_score = {}
    
    rec_index, recommender = rec
    
    for row in tqdm(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = int(getattr(row, 'rating'))

        similar_movies = recommender(movie)
        print(f"Found {len(similar_movies)} similar movies for {movie}:")
        # print(similar_movies)
        for sim in similar_movies:
            # sim = sim.decode("utf-8")
            if sim not in movie_score:
                movie_score[sim] = rating_weights[rating] * score_weights[rec_index+1]
                #print(f"updating {sim} to {movie_score[sim]}={rating_weights[rating]}*{score_weights[3]}")                
            else:
                movie_score[sim] += rating_weights[rating] * score_weights[rec_index+1] #το weight θα το ορίσετε ανα επίπεδο ομοιότητας οι πολύ όμοιες ταινίες θα έχουν μεγαλύτερο βάρος
    return movie_score


#αυτό είναι ένα παράδειγμα για το πως θα μπορούσε να υλοποιήθει η predict
#έχουμε ορίσει ότι μια ταινία θα έπρεπε να είναι προτεινόμενη αν είχε σκορ > 0
def predict_example(ratings, movie_score):
    #print(movie_score)
    real, pred = [], []
    for i, row in enumerate(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        if movie in movie_score.keys(): #αν έχουμε σχηματίσει βαθμολογία για την ταινία αυτή
            print("-------@----- MOVIE IN MOVIE_SCORE -------@----")
            pred.append(int(movie_score[movie] > 0)) #heuristic για το αν μια ταινία είναι προτεινόμενη
            real.append(int(rating > 2))# έτσι ορίζουμε ότι μια ταινία θα έπρεπε να είναι προτεινόμενη
            #η συνθήκη αυτή δεν μπορεί να αλλάξει
        else: #δεν μπορούμε να προτείνουμε κάτι για το όποιο δεν έχουμε σχηματίσει εικόνα
            #print(f"----{movie} with rating {rating} not in movies_score-------------")
            pred.append(0)
            real.append(int(rating > 2))

    return real, pred


def get_metrics(real, pred):
    metrics = {}
    metrics["precision"] = precision_score(real, pred, zero_division=True)
    metrics["recall"] = recall_score(real, pred)
    metrics["f1"] = f1_score(real, pred)
    return metrics

# %% [markdown]
# Οι παραπάνω εκπαιδεύουν, τεστάρουν και μετρούν την απόδοσή του συστήματος στάσεων μας.
# Για την εκπαίδευση του συστήματος μπορούμε κάθε φορά να χρησιμοποιήσουμε ένα τυχαίο υποσύνολο του training set.
# Όμως είναι πιθανό το υποσύνολο των ταινιών αυτόν να επηρεάζει τα αποτελέσματα στο training set.
# Για παράδειγμα, για ένα πείραμα, αν επιλέξουμε 3 ταινίες στις 10, τα αποτελέσματα μας μπορεί να είναι ίδια και αυτό να μην οφείλεται στο γεγονός ότι ο ταξινομητής μας τα πηγαίνει καλά στις 3 ταινίες αλλά στο γεγονός ότι οι υπόλοιπες 7 είναι τέτοιες ταινίες που δεν μας βοηθούν καθόλου.
# Αν είχαμε επιλέξει διαφορετικές 3 ταινίες, μπορεί να τα πηγαίναμε χάλια.
# Οπότε, προτείνουμε να τρέξετε κάθε φορά έναν αριθμό πειραμάτων για κάθε υποσύνολο ταινιών π.χ. 10 πειράματα με 3 ταινίες, 10 πειράματα για 20 ταινίες κ.ο.κ. και να κρατήσετε σαν τελικό σκορ το μέσο όρο όλων των πειραμάτων. Έτσι τα αποτελέσματα των προβλέψεών σας θα είναι πιο αντικειμενικά.

# %%
train_ratings = pd.read_csv(path + "train_ratings.csv")
test_ratings = pd.read_csv(path + "test_ratings.csv")

# %%
metrics = []
for rec in enumerate(recommenders):
    print(f"Recommender {rec[0]}:")
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 1, rec=rec)
    real, pred = predict_example(test_ratings, movie_score)
    metrics = get_metrics(real, pred)
    print(metrics)
    '''
    for metric in metrics.keys():
        print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
    '''
    print('-----------------------'*3)
# Out:
# Recommender 0:
# 0it [00:00, ?it/s]
# Found 138 similar movies for About Schmidt:
# -------@----- MOVIE IN MOVIE_SCORE -------@----
# -------@----- MOVIE IN MOVIE_SCORE -------@----
# -------@----- MOVIE IN MOVIE_SCORE -------@----
# -------@----- MOVIE IN MOVIE_SCORE -------@----
# -------@----- MOVIE IN MOVIE_SCORE -------@----
# {'precision': 1.0, 'recall': 0.0, 'f1': 0.0}
# ---------------------------------------------------------------------
# Recommender 1:
# 0it [00:00, ?it/s]
# Found 67 similar movies for Spellbound:
# -------@----- MOVIE IN MOVIE_SCORE -------@----
# -------@----- MOVIE IN MOVIE_SCORE -------@----
# -------@----- MOVIE IN MOVIE_SCORE -------@----
# -------@----- MOVIE IN MOVIE_SCORE -------@----
# -------@----- MOVIE IN MOVIE_SCORE -------@----
# -------@----- MOVIE IN MOVIE_SCORE -------@----
# {'precision': 0.6666666666666666, 'recall': 0.035398230088495575, 'f1': 0.06722689075630253}
# ---------------------------------------------------------------------
# Recommender 2:
# 0it [00:00, ?it/s]
# Found 7 similar movies for Flash Gordon:
# {'precision': 1.0, 'recall': 0.0, 'f1': 0.0}
# ---------------------------------------------------------------------
# Recommender 3:
# 0it [00:00, ?it/s]
# Found 0 similar movies for Barry Lyndon:
# {'precision': 1.0, 'recall': 0.0, 'f1': 0.0}
# ---------------------------------------------------------------------
# Recommender 4:
# 0it [00:00, ?it/s]
# Found 4 similar movies for Escape from New York:
# -------@----- MOVIE IN MOVIE_SCORE -------@----
# {'precision': 1.0, 'recall': 0.008849557522123894, 'f1': 0.017543859649122806}
# ---------------------------------------------------------------------

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 30)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# My similar movies for Match Point: 14
# My similar movies for Hannibal Rising: 4
# My similar movies for Men in Black II: 24
# My similar movies for License to Wed: 2
# My similar movies for Mean Streets: 0
# My similar movies for Charlie Wilsons War: 2
# My similar movies for Pandoras Box: 1
# My similar movies for Being John Malkovich: 2
# My similar movies for The Karate Kid: 0
# My similar movies for Team America: World Police: 6
# My similar movies for Terminator 3: Rise of the Machines: 23
# My similar movies for Bill & Teds Bogus Journey: 10
# My similar movies for Seven Samurai: 3
# My similar movies for Lions for Lambs: 8
# My similar movies for Alexander: 2
# My similar movies for The Curse of the Jade Scorpion: 6
# My similar movies for Army of Darkness: 15
# My similar movies for The Talented Mr. Ripley: 12
# My similar movies for Payback: 6
# My similar movies for The Transporter: 1
# My similar movies for Amélie: 1
# My similar movies for Open Season: 1
# My similar movies for Escape from New York: 11
# My similar movies for The Last Emperor: 2
# My similar movies for Y Tu Mamá También: 9
# My similar movies for Mission to Mars: 1
# My similar movies for Dear Frankie: 1
# My similar movies for Kindergarten Cop: 0
# My similar movies for The Wedding Planner: 8
# My similar movies for Under Siege 2: Dark Territory: 2
# I am the predict method, seeing a movie score of 159 movies
# {b'Shooting Fish': 200, b'In the Land of Women': 200, b'The Oh in Ohio': 200, b'Everyone Says I Love You': 600, b'Cruel Intentions': 200, b'Notes on a Scandal': 400, b'The Piano': 200, b'Country Strong': 200, b'Her': 200, b'Days of Heaven': 200, b'Troy': 200, b'Annie Hall': 200, b'The Horse Whisperer': 200, b'Lost in Translation': 200, b'Malevolence': 200, b'Red Dragon': 200, b'The Devils Rejects': 200, b'The Silence of the Lambs': 200, b'The Black Hole': 200, b'Terminator Salvation': 400, b'Battle: Los Angeles': 200, b'Men in Black': 200, b'Mission: Impossible': 200, b'The Terminator': 400, b'E.T. the Extra-Terrestrial': 200, b'Aliens': 200, b'Mars Attacks!': 200, b'Men in Black 3': 200, b'On Her Majestys Secret Service': 200, b'Terminator 3: Rise of the Machines': 200, b'Armageddon': 400, b'AVP: Alien vs. Predator': 200, b'Alien': 200, b'Austin Powers: The Spy Who Shagged Me': 200, b'Bad Boys II': 200, b'Treasure Planet': 200, b'Mission: Impossible II': 200, b'I Am Number Four': 200, b'Megamind': 200, b'Alien\xc2\xb3': 200, b'Austin Powers in Goldmember': 200, b'Planet 51': 200, b'Because I Said So': 200, b'Something Borrowed': 200, b'Wag the Dog': 200, b'Conspiracy Theory': 200, b'Lolita': 200, b'As It Is in Heaven': 200, b'My Best Friends Wedding': 400, b'Raiders of the Lost Ark': 200, b'Around the World in 80 Days': 200, b'The Spy Who Loved Me': 200, b'A View to a Kill': 400, b'Ronin': 200, b'Terminator 2: Judgment Day': 200, b'Fortress': 200, b'I Am Legend': 200, b'Terminator Genisys': 400, b'RoboCop 3': 400, b'The Thirteenth Floor': 200, b'I, Robot': 200, b'Men in Black II': 200, b'The Matrix Reloaded': 600, b'Ex Machina': 200, b'Transcendence': 200, b'Surrogates': 200, b'RoboCop': 200, b'The Matrix Revolutions': 600, b'Blade Runner': 200, b'The Matrix': 400, b'Automata': 200, b'TRON: Legacy': 200, b'9': 200, b'Logans Run': 200, b'Army of Darkness': 200, b'Heartbeeps': 200, b'Bill & Teds Excellent Adventure': 200, b'Sleeper': 400, b'Southland Tales': 400, b'Click': 200, b'A Sound of Thunder': 200, b'The Last Samurai': 400, b'47 Ronin': 200, b'Platoon': 200, b'Max': 200, b'The Hunting Party': 200, b'Fury': 200, b'Vantage Point': 200, b'The Lucky Ones': 200, b'Damnation Alley': 200, b'The Hunger Games: Catching Fire': 200, b'Agora': 200, b'Beowulf': 200, b'Celebrity': 200, b'Small Time Crooks': 200, b'Deconstructing Harry': 200, b'Radio Days': 200, b'Warlock': 200, b'Monty Python and the Holy Grail': 200, b'The Sorcerers Apprentice': 200, b'Black Knight': 200, b'Dead Snow': 200, b'Snow White: A Tale of Terror': 200, b'Evil Dead II': 200, b'Darkness Falls': 200, b'The Return of the Living Dead': 200, b'Oz: The Great and Powerful': 200, b'Hotel Transylvania': 200, b'Bill & Teds Bogus Journey': 200, b'The Visitors': 200, b'The Evil Dead': 200, b'The Visitors II: The Corridors of Time': 200, b'The Lady from Shanghai': 200, b'The Life Aquatic with Steve Zissou': 200, b'The Godfather: Part III': 200, b'The Bourne Ultimatum': 200, b'Married Life': 200, b'A History of Violence': 200, b'Eastern Promises': 200, b'Poseidon': 200, b'Titanic': 200, b'Gattaca': 200, b'The Crying Game': 200, b'A Mighty Heart': 200, b'Thank You for Smoking': 200, b'Party Monster': 200, b'Sexy Beast': 200, b'The Way of the Gun': 200, b'15 Minutes': 200, b'Live and Let Die': 200, b'The Fast and the Furious: Tokyo Drift': 200, b'Over the Hedge': 200, b'They Live': 200, b'Total Recall': 200, b'Escape from the Planet of the Apes': 200, b'Lockout': 200, b'Escape from L.A.': 200, b'\xc3\x86on Flux': 200, b'Babylon A.D.': 200, b'1911': 200, b'Outside Providence': 200, b'The Spectacular Now': 200, b'Maurice': 200, b'LOL': 200, b'Crossroads': 200, b'High School Musical 3: Senior Year': 200, b'A Walk to Remember': 200, b'Shortbus': 200, b'Green Lantern': 200, b'Letters to God': 200, b'My Big Fat Greek Wedding': 200, b'Our Family Wedding': 200, b'American Wedding': 200, b'My Big Fat Greek Wedding 2': 200, b'Four Weddings and a Funeral': 200, b'Monsoon Wedding': 200, ...
# ----Star Wars with rating 3.0 not in movies_score-------------
# ----American Beauty with rating 3.5 not in movies_score-------------
# ----Dancer in the Dark with rating 4.0 not in movies_score-------------
# ----Jarhead with rating 4.5 not in movies_score-------------
# ----Scarface with rating 5.0 not in movies_score-------------
# ----Donnie Darko with rating 1.0 not in movies_score-------------
# ----Lost in Translation with rating 2.0 not in movies_score-------------
# ----The Dark Knight with rating 2.0 not in movies_score-------------
# ----Oceans Eleven with rating 1.0 not in movies_score-------------
# ----Edward Scissorhands with rating 3.0 not in movies_score-------------
# ----Back to the Future Part II with rating 4.5 not in movies_score-------------
# ----Saw with rating 5.0 not in movies_score-------------
# ----Minority Report with rating 0.5 not in movies_score-------------
# ----Lucky Number Slevin with rating 3.0 not in movies_score-------------
# ----Cat on a Hot Tin Roof with rating 4.0 not in movies_score-------------
# ----Batman Begins with rating 4.0 not in movies_score-------------
# ----High Noon with rating 4.0 not in movies_score-------------
# ----Casablanca with rating 1.5 not in movies_score-------------
# ----Magnolia with rating 1.0 not in movies_score-------------
# ----Summer Storm with rating 4.0 not in movies_score-------------
# ----Eyes Wide Shut with rating 3.0 not in movies_score-------------
# ----The Devil Wears Prada with rating 3.0 not in movies_score-------------
# ----A Nightmare on Elm Street with rating 2.0 not in movies_score-------------
# ----Rain Man with rating 3.0 not in movies_score-------------
# ----Leaving Las Vegas with rating 3.0 not in movies_score-------------
# ----Monsoon Wedding with rating 3.0 not in movies_score-------------
# ----Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan with rating 3.0 not in movies_score-------------
# ----Reservoir Dogs with rating 4.0 not in movies_score-------------
# ----Love Actually with rating 3.0 not in movies_score-------------
# ----Casino with rating 1.0 not in movies_score-------------
# ----Basquiat with rating 2.5 not in movies_score-------------
# ----Die Hard with rating 0.5 not in movies_score-------------
# ----Big Fish with rating 3.0 not in movies_score-------------
# ----The Hours with rating 3.0 not in movies_score-------------
# ----The Conversation with rating 1.0 not in movies_score-------------
# ----The Terminal with rating 5.0 not in movies_score-------------
# ----Harry Potter and the Goblet of Fire with rating 3.0 not in movies_score-------------
# ----The Living Daylights with rating 2.5 not in movies_score-------------
# ----American Graffiti with rating 3.0 not in movies_score-------------
# ----Finding Neverland with rating 4.5 not in movies_score-------------
# ----The Thomas Crown Affair with rating 5.0 not in movies_score-------------
# ----Cars with rating 5.0 not in movies_score-------------
# ----Dawn of the Dead with rating 5.0 not in movies_score-------------
# ----Galaxy Quest with rating 5.0 not in movies_score-------------
# ----Gremlins with rating 5.0 not in movies_score-------------
# ----Gremlins 2: The New Batch with rating 5.0 not in movies_score-------------
# ----Halloween with rating 3.5 not in movies_score-------------
# ----Ice Age: The Meltdown with rating 4.5 not in movies_score-------------
# ----Mission: Impossible II with rating 5.0 not in movies_score-------------
# ----Mulholland Drive with rating 2.5 not in movies_score-------------
# ----Whale Rider with rating 5.0 not in movies_score-------------
# ----The Thirteenth Floor with rating 4.0 not in movies_score-------------
# ----The Prestige with rating 3.0 not in movies_score-------------
# ----Ghost Rider with rating 3.5 not in movies_score-------------
# ----Bridge to Terabithia with rating 5.0 not in movies_score-------------
# ----Street Kings with rating 3.0 not in movies_score-------------
# ----300 with rating 4.0 not in movies_score-------------
# ----Dogtown and Z-Boys with rating 5.0 not in movies_score-------------
# ----Hellboy with rating 2.5 not in movies_score-------------
# ----Die Hard 2 with rating 1.0 not in movies_score-------------
# ----School of Rock with rating 4.0 not in movies_score-------------
# ----Whats Eating Gilbert Grape with rating 1.0 not in movies_score-------------
# ----Speed 2: Cruise Control with rating 0.5 not in movies_score-------------
# ----The Reaping with rating 3.0 not in movies_score-------------
# ----The Mummy Returns with rating 3.5 not in movies_score-------------
# ----Fahrenheit 9/11 with rating 3.0 not in movies_score-------------
# ----Pirates of the Caribbean: On Stranger Tides with rating 1.0 not in movies_score-------------
# ----Malcolm X with rating 3.0 not in movies_score-------------
# ----Don Juan DeMarco with rating 3.0 not in movies_score-------------
# ----The Sea Inside with rating 4.5 not in movies_score-------------
# ----Sweet November with rating 2.0 not in movies_score-------------
# ----Shakespeare in Love with rating 3.5 not in movies_score-------------
# ----eXistenZ with rating 5.0 not in movies_score-------------
# ----An Unfinished Life with rating 5.0 not in movies_score-------------
# ----Crank with rating 5.0 not in movies_score-------------
# ----Lucky You with rating 5.0 not in movies_score-------------
# ----The Elephant Man with rating 4.0 not in movies_score-------------
# ----Gerry with rating 5.0 not in movies_score-------------
# ----8 Women with rating 3.0 not in movies_score-------------
# ----My Name Is Bruce with rating 3.0 not in movies_score-------------
# ----Two Brothers with rating 3.0 not in movies_score-------------
# ----Persepolis with rating 1.0 not in movies_score-------------
# ----The Diving Bell and the Butterfly with rating 2.0 not in movies_score-------------
# ----Hidalgo with rating 2.0 not in movies_score-------------
# ----The Station Agent with rating 3.5 not in movies_score-------------
# ----Original Sin with rating 3.5 not in movies_score-------------
# ----Romeo Must Die with rating 3.0 not in movies_score-------------
# ----Romeo Is Bleeding with rating 2.0 not in movies_score-------------
# ----The Time Machine with rating 1.0 not in movies_score-------------
# ----Reindeer Games with rating 2.0 not in movies_score-------------
# ----The Glass House with rating 4.0 not in movies_score-------------
# ----The Golden Compass with rating 3.0 not in movies_score-------------
# ----Cold Mountain with rating 5.0 not in movies_score-------------
# ----Jakob the Liar with rating 4.0 not in movies_score-------------
# ----Asterix at the Olympic Games with rating 2.0 not in movies_score-------------
# ----The Chronicles of Narnia: Prince Caspian with rating 3.5 not in movies_score-------------
# ----The Bourne Identity with rating 3.5 not in movies_score-------------
# ----The Bourne Supremacy with rating 2.5 not in movies_score-------------
# ----Spanglish with rating 3.0 not in movies_score-------------
# ----Return to Me with rating 3.0 not in movies_score-------------
# ----Adaptation. with rating 3.0 not in movies_score-------------
# ----American Pie 2 with rating 4.0 not in movies_score-------------
# ----Hairspray with rating 3.5 not in movies_score-------------
# ----The Big Parade with rating 5.0 not in movies_score-------------
# ----Basic Instinct 2 with rating 2.0 not in movies_score-------------
# ----88 Minutes with rating 1.5 not in movies_score-------------
# ----Flags of Our Fathers with rating 4.0 not in movies_score-------------
# ----Beetlejuice with rating 0.5 not in movies_score-------------
# ----The Kingdom with rating 4.5 not in movies_score-------------
# ----Seabiscuit with rating 3.0 not in movies_score-------------
# ----Enchanted with rating 3.0 not in movies_score-------------
# ----Ghost Dog: The Way of the Samurai with rating 4.0 not in movies_score-------------
# ----Impostor with rating 4.5 not in movies_score-------------
# ----Boogie Nights with rating 4.0 not in movies_score-------------
# ----The Chorus with rating 3.5 not in movies_score-------------
# ----The Sentinel with rating 3.0 not in movies_score-------------
# ----The Mist with rating 4.0 not in movies_score-------------
# ----A Bridge Too Far with rating 5.0 not in movies_score-------------
# ----The Good Thief with rating 4.0 not in movies_score-------------
# ----The Shipping News with rating 2.0 not in movies_score-------------
# ----Idle Hands with rating 4.5 not in movies_score-------------
# ----Love in the Time of Cholera with rating 4.5 not in movies_score-------------
# ----The 40 Year Old Virgin with rating 3.5 not in movies_score-------------
# ----No Country for Old Men with rating 3.5 not in movies_score-------------
# ----xXx with rating 2.5 not in movies_score-------------
# ----Midnight in the Garden of Good and Evil with rating 1.5 not in movies_score-------------
# ----They Live with rating 4.0 not in movies_score-------------
# ----Wild Wild West with rating 2.5 not in movies_score-------------
# ----Prom Night with rating 3.0 not in movies_score-------------
# ----The History Boys with rating 4.0 not in movies_score-------------
# ----K-19: The Widowmaker with rating 3.5 not in movies_score-------------
# ----Mercury Rising with rating 4.0 not in movies_score-------------
# ----Twilight with rating 4.0 not in movies_score-------------
# ----The Out-of-Towners with rating 3.5 not in movies_score-------------
# ----Disclosure with rating 2.5 not in movies_score-------------
# ----The River Wild with rating 3.0 not in movies_score-------------
# ----Jackass: The Movie with rating 4.0 not in movies_score-------------
# ----Carriers with rating 4.0 not in movies_score-------------
# ----Harry Brown with rating 4.0 not in movies_score-------------
# ----Once in a Lifetime: The Extraordinary Story of the New York Cosmos with rating 5.0 not in movies_score-------------
# ----Kevin Hart: Laugh at My Pain with rating 3.5 not in movies_score-------------
# 0it [00:00, ?it/s]
# My similar movies for Under Siege 2: Dark Territory: 2
# My similar movies for Notting Hill: 7
# My similar movies for To Kill a Mockingbird: 7
# My similar movies for Army of Darkness: 15
# My similar movies for Kindergarten Cop: 0
# My similar movies for Manderlay: 0
# My similar movies for Flashdance: 4
# My similar movies for The Curse of the Jade Scorpion: 6
# My similar movies for Titanic: 8
# My similar movies for Rosemarys Baby: 1
# My similar movies for Mean Streets: 0
# My similar movies for Somethings Gotta Give: 7
# My similar movies for Maurice: 8
# My similar movies for Notes on a Scandal: 47
# My similar movies for The Forbidden Kingdom: 0
# My similar movies for Live and Let Die: 31
# My similar movies for Wasabi: 0
# My similar movies for Barry Lyndon: 0
# My similar movies for Aliens vs Predator: Requiem: 10
# My similar movies for Pandoras Box: 1
# My similar movies for Hannibal Rising: 4
# My similar movies for Dances with Wolves: 5
# My similar movies for Gothika: 1
# My similar movies for Along Came Polly: 7
# My similar movies for X-Men Origins: Wolverine: 41
# My similar movies for Escape from New York: 11
# My similar movies for License to Wed: 2
# My similar movies for The Talented Mr. Ripley: 12
# My similar movies for Amadeus: 0
# My similar movies for Moulin Rouge!: 7
# I am the predict method, seeing a movie score of 229 movies
# {b'Zero Dark Thirty': 200, b'The Peacemaker': 200, b'Bridget Jones: The Edge of Reason': 200, b'Love Actually': 200, b'102 Dalmatians': 200, b'Bridget Joness Diary': 400, b'Boys and Girls': 400, b'Something Borrowed': 600, b'About a Boy': 200, b'Sleepers': 200, b'Wild Things': 200, b'Mystic River': 200, b'Stand by Me': 200, b'The Green Mile': 200, b'High Crimes': 200, b'Freedom Writers': 200, b'Warlock': 200, b'Monty Python and the Holy Grail': 200, b'The Sorcerers Apprentice': 200, b'Black Knight': 200, b'Dead Snow': 200, b'Snow White: A Tale of Terror': 200, b'Evil Dead II': 200, b'Darkness Falls': 200, b'The Return of the Living Dead': 200, b'Oz: The Great and Powerful': 200, b'Hotel Transylvania': 200, b'Bill & Teds Bogus Journey': 200, b'The Visitors': 200, b'The Evil Dead': 200, b'The Visitors II: The Corridors of Time': 200, b'Honey': 200, b'Step Up': 200, b'Dancer in the Dark': 200, b'Footloose': 200, b'Celebrity': 200, b'Everyone Says I Love You': 400, b'Small Time Crooks': 200, b'Deconstructing Harry': 200, b'Sleeper': 200, b'Radio Days': 200, b'The Time Travelers Wife': 400, b'Pompeii': 200, b'In the Heart of the Sea': 200, b'Poseidon': 400, b'A Walk to Remember': 400, b'Days of Heaven': 200, b'The Immigrant': 400, b'The Talented Mr. Ripley': 200, b'End of Days': 200, b'The Intern': 200, b'An Education': 200, b'Its Complicated': 200, b'Love the Coopers': 200, b'The Holiday': 400, b'North Country': 200, b'What Women Want': 200, b'Latter Days': 200, b'Weekend': 200, b'My Beautiful Laundrette': 200, b'The Broken Hearts Club: A Romantic Comedy': 200, b'My Own Private Idaho': 200, b'Y Tu Mam\xc3\xa1 Tambi\xc3\xa9n': 400, b'A Home at the End of the World': 200, b'Beginners': 200, b'New York Stories': 200, b'The Oh in Ohio': 200, b'Love in the Time of Cholera': 200, b'The Scarlet Letter': 200, b'Dear John': 200, b'One Day': 200, b'The Fault in Our Stars': 200, b'Going the Distance': 200, b'The Postman Always Rings Twice': 200, b'The Shipping News': 200, b'Desire': 200, b'Good Luck Chuck': 200, b'Love and Death on Long Island': 200, b'Cruel Intentions': 200, b'Eternal Sunshine of the Spotless Mind': 200, b'Married Life': 400, b'Crossroads': 200, b'The Good Girl': 200, b'Country Strong': 200, b'Revolutionary Road': 200, b'Silver Linings Playbook': 200, b'Autumn in New York': 200, b'Forrest Gump': 200, b'In the Land of Women': 200, b'The Spanish Apartment': 200, b'Iris': 200, b'Alone With Her': 200, b'Entrapment': 200, b'Little Children': 200, b'Match Point': 200, b'Her': 200, b'Solitary Man': 200, b'Outside Providence': 200, b'The Art of Getting By': 200, b'Paper Towns': 200, b'The Great Gatsby': 200, b'Beastly': 200, b'Kabhi Alvida Naa Kehna': 200, b'(500) Days of Summer': 200, b'2046': 200, b'Clear and Present Danger': 200, b'Kick-Ass 2': 400, b'Octopussy': 200, b'The Man Who Knew Too Little': 200, b'Licence to Kill': 200, b'Mission: Impossible': 200, b'Payback': 200, b'From Russia with Love': 200, b'The Avengers': 400, b'The Living Daylights': 200, b'Goldfinger': 200, b'Stormbreaker': 200, b'Dr. No': 200, b'Captain America: The First Avenger': 400, b'On Her Majestys Secret Service': 200, b'Pirates of the Caribbean: The Curse of the Black Pearl': 200, b'A View to a Kill': 200, b'For Your Eyes Only': 200, b'Diamonds Are Forever': 200, b'Mr. & Mrs. Smith': 200, b'Mission: Impossible III': 200, b'The Spy Who Loved Me': 200, b'Around the World in 80 Days': 200, b'Lake Placid': 200, b'You Only Live Twice': 200, b'Young Sherlock Holmes': 200, b'Mission: Impossible II': 200, b'Mission: Impossible - Rogue Nation': 200, b'The Man with the Golden Gun': 200, b'Tomorrow Never Dies': 200, b'GoldenEye': 200, b'AVP: Alien vs. Predator': 200, b'Predators': 200, b'Alien': 200, b'Alien: Resurrection': 200, b'Alien\xc2\xb3': 200, b'Predator': 200, b'Skyline': 200, b'Aliens': 200, b'Aliens in the Attic': 200, b'Predator 2': 200, b'Lolita': 200, b'Malevolence': 200, b'Red Dragon': 200, b'The Devils Rejects': 200, b'The Silence of the Lambs': 2 ...
# ----Star Wars with rating 3.0 not in movies_score-------------
# ----American Beauty with rating 3.5 not in movies_score-------------
# ----Dancer in the Dark with rating 4.0 not in movies_score-------------
# ----Jarhead with rating 4.5 not in movies_score-------------
# ----Scarface with rating 5.0 not in movies_score-------------
# ----Donnie Darko with rating 1.0 not in movies_score-------------
# ----Lost in Translation with rating 2.0 not in movies_score-------------
# ----The Dark Knight with rating 2.0 not in movies_score-------------
# ----Oceans Eleven with rating 1.0 not in movies_score-------------
# ----Edward Scissorhands with rating 3.0 not in movies_score-------------
# ----Back to the Future Part II with rating 4.5 not in movies_score-------------
# ----Saw with rating 5.0 not in movies_score-------------
# ----Minority Report with rating 0.5 not in movies_score-------------
# ----Lucky Number Slevin with rating 3.0 not in movies_score-------------
# ----Cat on a Hot Tin Roof with rating 4.0 not in movies_score-------------
# ----Batman Begins with rating 4.0 not in movies_score-------------
# ----High Noon with rating 4.0 not in movies_score-------------
# ----Casablanca with rating 1.5 not in movies_score-------------
# ----Magnolia with rating 1.0 not in movies_score-------------
# ----Summer Storm with rating 4.0 not in movies_score-------------
# ----Eyes Wide Shut with rating 3.0 not in movies_score-------------
# ----The Devil Wears Prada with rating 3.0 not in movies_score-------------
# ----A Nightmare on Elm Street with rating 2.0 not in movies_score-------------
# ----Rain Man with rating 3.0 not in movies_score-------------
# ----Leaving Las Vegas with rating 3.0 not in movies_score-------------
# ----Monsoon Wedding with rating 3.0 not in movies_score-------------
# ----Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan with rating 3.0 not in movies_score-------------
# ----Reservoir Dogs with rating 4.0 not in movies_score-------------
# ----Love Actually with rating 3.0 not in movies_score-------------
# ----Casino with rating 1.0 not in movies_score-------------
# ----Basquiat with rating 2.5 not in movies_score-------------
# ----Die Hard with rating 0.5 not in movies_score-------------
# ----Big Fish with rating 3.0 not in movies_score-------------
# ----The Hours with rating 3.0 not in movies_score-------------
# ----The Conversation with rating 1.0 not in movies_score-------------
# ----The Terminal with rating 5.0 not in movies_score-------------
# ----Harry Potter and the Goblet of Fire with rating 3.0 not in movies_score-------------
# ----The Living Daylights with rating 2.5 not in movies_score-------------
# ----American Graffiti with rating 3.0 not in movies_score-------------
# ----Finding Neverland with rating 4.5 not in movies_score-------------
# ----The Thomas Crown Affair with rating 5.0 not in movies_score-------------
# ----Cars with rating 5.0 not in movies_score-------------
# ----Dawn of the Dead with rating 5.0 not in movies_score-------------
# ----Galaxy Quest with rating 5.0 not in movies_score-------------
# ----Gremlins with rating 5.0 not in movies_score-------------
# ----Gremlins 2: The New Batch with rating 5.0 not in movies_score-------------
# ----Halloween with rating 3.5 not in movies_score-------------
# ----Ice Age: The Meltdown with rating 4.5 not in movies_score-------------
# ----Mission: Impossible II with rating 5.0 not in movies_score-------------
# ----Mulholland Drive with rating 2.5 not in movies_score-------------
# ----Whale Rider with rating 5.0 not in movies_score-------------
# ----The Thirteenth Floor with rating 4.0 not in movies_score-------------
# ----The Prestige with rating 3.0 not in movies_score-------------
# ----Ghost Rider with rating 3.5 not in movies_score-------------
# ----Bridge to Terabithia with rating 5.0 not in movies_score-------------
# ----Street Kings with rating 3.0 not in movies_score-------------
# ----300 with rating 4.0 not in movies_score-------------
# ----Dogtown and Z-Boys with rating 5.0 not in movies_score-------------
# ----Hellboy with rating 2.5 not in movies_score-------------
# ----Die Hard 2 with rating 1.0 not in movies_score-------------
# ----School of Rock with rating 4.0 not in movies_score-------------
# ----Whats Eating Gilbert Grape with rating 1.0 not in movies_score-------------
# ----Speed 2: Cruise Control with rating 0.5 not in movies_score-------------
# ----The Reaping with rating 3.0 not in movies_score-------------
# ----The Mummy Returns with rating 3.5 not in movies_score-------------
# ----Fahrenheit 9/11 with rating 3.0 not in movies_score-------------
# ----Pirates of the Caribbean: On Stranger Tides with rating 1.0 not in movies_score-------------
# ----Malcolm X with rating 3.0 not in movies_score-------------
# ----Don Juan DeMarco with rating 3.0 not in movies_score-------------
# ----The Sea Inside with rating 4.5 not in movies_score-------------
# ----Sweet November with rating 2.0 not in movies_score-------------
# ----Shakespeare in Love with rating 3.5 not in movies_score-------------
# ----eXistenZ with rating 5.0 not in movies_score-------------
# ----An Unfinished Life with rating 5.0 not in movies_score-------------
# ----Crank with rating 5.0 not in movies_score-------------
# ----Lucky You with rating 5.0 not in movies_score-------------
# ----The Elephant Man with rating 4.0 not in movies_score-------------
# ----Gerry with rating 5.0 not in movies_score-------------
# ----8 Women with rating 3.0 not in movies_score-------------
# ----My Name Is Bruce with rating 3.0 not in movies_score-------------
# ----Two Brothers with rating 3.0 not in movies_score-------------
# ----Persepolis with rating 1.0 not in movies_score-------------
# ----The Diving Bell and the Butterfly with rating 2.0 not in movies_score-------------
# ----Hidalgo with rating 2.0 not in movies_score-------------
# ----The Station Agent with rating 3.5 not in movies_score-------------
# ----Original Sin with rating 3.5 not in movies_score-------------
# ----Romeo Must Die with rating 3.0 not in movies_score-------------
# ----Romeo Is Bleeding with rating 2.0 not in movies_score-------------
# ----The Time Machine with rating 1.0 not in movies_score-------------
# ----Reindeer Games with rating 2.0 not in movies_score-------------
# ----The Glass House with rating 4.0 not in movies_score-------------
# ----The Golden Compass with rating 3.0 not in movies_score-------------
# ----Cold Mountain with rating 5.0 not in movies_score-------------
# ----Jakob the Liar with rating 4.0 not in movies_score-------------
# ----Asterix at the Olympic Games with rating 2.0 not in movies_score-------------
# ----The Chronicles of Narnia: Prince Caspian with rating 3.5 not in movies_score-------------
# ----The Bourne Identity with rating 3.5 not in movies_score-------------
# ----The Bourne Supremacy with rating 2.5 not in movies_score-------------
# ----Spanglish with rating 3.0 not in movies_score-------------
# ----Return to Me with rating 3.0 not in movies_score-------------
# ----Adaptation. with rating 3.0 not in movies_score-------------
# ----American Pie 2 with rating 4.0 not in movies_score-------------
# ----Hairspray with rating 3.5 not in movies_score-------------
# ----The Big Parade with rating 5.0 not in movies_score-------------
# ----Basic Instinct 2 with rating 2.0 not in movies_score-------------
# ----88 Minutes with rating 1.5 not in movies_score-------------
# ----Flags of Our Fathers with rating 4.0 not in movies_score-------------
# ----Beetlejuice with rating 0.5 not in movies_score-------------
# ----The Kingdom with rating 4.5 not in movies_score-------------
# ----Seabiscuit with rating 3.0 not in movies_score-------------
# ----Enchanted with rating 3.0 not in movies_score-------------
# ----Ghost Dog: The Way of the Samurai with rating 4.0 not in movies_score-------------
# ----Impostor with rating 4.5 not in movies_score-------------
# ----Boogie Nights with rating 4.0 not in movies_score-------------
# ----The Chorus with rating 3.5 not in movies_score-------------
# ----The Sentinel with rating 3.0 not in movies_score-------------
# ----The Mist with rating 4.0 not in movies_score-------------
# ----A Bridge Too Far with rating 5.0 not in movies_score-------------
# ----The Good Thief with rating 4.0 not in movies_score-------------
# ----The Shipping News with rating 2.0 not in movies_score-------------
# ----Idle Hands with rating 4.5 not in movies_score-------------
# ----Love in the Time of Cholera with rating 4.5 not in movies_score-------------
# ----The 40 Year Old Virgin with rating 3.5 not in movies_score-------------
# ----No Country for Old Men with rating 3.5 not in movies_score-------------
# ----xXx with rating 2.5 not in movies_score-------------
# ----Midnight in the Garden of Good and Evil with rating 1.5 not in movies_score-------------
# ----They Live with rating 4.0 not in movies_score-------------
# ----Wild Wild West with rating 2.5 not in movies_score-------------
# ----Prom Night with rating 3.0 not in movies_score-------------
# ----The History Boys with rating 4.0 not in movies_score-------------
# ----K-19: The Widowmaker with rating 3.5 not in movies_score-------------
# ----Mercury Rising with rating 4.0 not in movies_score-------------
# ----Twilight with rating 4.0 not in movies_score-------------
# ----The Out-of-Towners with rating 3.5 not in movies_score-------------
# ----Disclosure with rating 2.5 not in movies_score-------------
# ----The River Wild with rating 3.0 not in movies_score-------------
# ----Jackass: The Movie with rating 4.0 not in movies_score-------------
# ----Carriers with rating 4.0 not in movies_score-------------
# ----Harry Brown with rating 4.0 not in movies_score-------------
# ----Once in a Lifetime: The Extraordinary Story of the New York Cosmos with rating 5.0 not in movies_score-------------
# ----Kevin Hart: Laugh at My Pain with rating 3.5 not in movies_score-------------
# 0it [00:00, ?it/s]
# My similar movies for Titanic: 8
# My similar movies for Bill & Teds Bogus Journey: 10
# My similar movies for Charlie Wilsons War: 2
# My similar movies for Highlander: The Final Dimension: 2
# My similar movies for Psycho: 4
# My similar movies for Amadeus: 0
# My similar movies for The Butterfly Effect: 2
# My similar movies for Army of Darkness: 15
# My similar movies for Rocky Balboa: 1
# My similar movies for Mean Streets: 0
# My similar movies for About Schmidt: 0
# My similar movies for Terminator 3: Rise of the Machines: 23
# My similar movies for Aliens vs Predator: Requiem: 10
# My similar movies for Under Siege 2: Dark Territory: 2
# My similar movies for Rebecca: 9
# My similar movies for Interview with the Vampire: 6
# My similar movies for The Transporter: 1
# My similar movies for Mr. Beans Holiday: 1
# My similar movies for The Karate Kid: 0
# My similar movies for Live and Let Die: 31
# My similar movies for Confessions of a Dangerous Mind: 1
# My similar movies for Transformers: Revenge of the Fallen: 9
# My similar movies for Alvin and the Chipmunks: 25
# My similar movies for Rosemarys Baby: 1
# My similar movies for Notes on a Scandal: 47
# My similar movies for Cinderella Man: 7
# My similar movies for Rambo III: 3
# My similar movies for Friends with Money: 13
# My similar movies for X-Men Origins: Wolverine: 41
# My similar movies for Dances with Wolves: 5
# I am the predict method, seeing a movie score of 263 movies
# {b'The Time Travelers Wife': 400, b'Pompeii': 200, b'In the Heart of the Sea': 200, b'Poseidon': 200, b'A Walk to Remember': 400, b'Days of Heaven': 200, b'The Immigrant': 400, b'The Talented Mr. Ripley': 200, b'Army of Darkness': 200, b'The Matrix Revolutions': 400, b'Heartbeeps': 200, b'Bill & Teds Excellent Adventure': 200, b'Sleeper': 200, b'Southland Tales': 400, b'Click': 200, b'A Sound of Thunder': 200, b'The Matrix Reloaded': 400, b'Terminator Genisys': 400, b'Wag the Dog': 200, b'Conspiracy Theory': 400, b'Captain America: The First Avenger': 600, b'Highlander': 200, b'The Way of the Gun': 200, b'Kill List': 200, b'The Devils Rejects': 200, b'Nine Queens': 200, b'Crank: High Voltage': 200, b'Warlock': 200, b'Monty Python and the Holy Grail': 200, b'The Sorcerers Apprentice': 200, b'Black Knight': 200, b'Dead Snow': 200, b'Snow White: A Tale of Terror': 200, b'Evil Dead II': 200, b'Darkness Falls': 200, b'The Return of the Living Dead': 200, b'Oz: The Great and Powerful': 200, b'Hotel Transylvania': 200, b'Bill & Teds Bogus Journey': 200, b'The Visitors': 200, b'The Evil Dead': 200, b'The Visitors II: The Corridors of Time': 200, b'Rocky': 200, b'Terminator 2: Judgment Day': 200, b'Terminator Salvation': 200, b'The Terminator': 200, b'Fortress': 200, b'I Am Legend': 200, b'RoboCop 3': 200, b'The Thirteenth Floor': 200, b'I, Robot': 200, b'Men in Black II': 200, b'A View to a Kill': 400, b'Ex Machina': 200, b'Transcendence': 200, b'Surrogates': 200, b'RoboCop': 200, b'Blade Runner': 200, b'The Matrix': 200, b'Automata': 200, b'TRON: Legacy': 200, b'9': 200, b'Logans Run': 200, b'AVP: Alien vs. Predator': 200, b'Predators': 200, b'Alien': 200, b'Alien: Resurrection': 200, b'Alien\xc2\xb3': 200, b'Predator': 200, b'Skyline': 200, b'Aliens': 200, b'Aliens in the Attic': 200, b'Predator 2': 200, b'Zero Dark Thirty': 200, b'The Peacemaker': 200, b'The Lady from Shanghai': 200, b'The Trouble with Harry': 200, b'Spellbound': 200, b'The Number 23': 200, b'The Village': 200, b'High Crimes': 200, b'The Prestige': 200, b'Topaz': 200, b'Dracula': 200, b'Gone with the Wind': 200, b'Vampire in Brooklyn': 200, b'The Little Vampire': 200, b'Vampires Suck': 200, b'Abraham Lincoln: Vampire Hunter': 200, b'The Fast and the Furious: Tokyo Drift': 200, b'The Holiday': 200, b'Clear and Present Danger': 200, b'Kick-Ass 2': 400, b'Octopussy': 200, b'The Man Who Knew Too Little': 200, b'Licence to Kill': 200, b'Mission: Impossible': 200, b'Payback': 200, b'From Russia with Love': 200, b'The Avengers': 400, b'The Living Daylights': 400, b'Goldfinger': 200, b'Stormbreaker': 200, b'Dr. No': 200, b'On Her Majestys Secret Service': 200, b'Pirates of the Caribbean: The Curse of the Black Pearl': 200, b'For Your Eyes Only': 200, b'Diamonds Are Forever': 200, b'Mr. & Mrs. Smith': 200, b'Mission: Impossible III': 200, b'The Spy Who Loved Me': 200, b'Around the World in 80 Days': 200, b'Lake Placid': 200, b'You Only Live Twice': 200, b'Young Sherlock Holmes': 200, b'Mission: Impossible II': 200, b'Mission: Impossible - Rogue Nation': 200, b'The Man with the Golden Gun': 200, b'Tomorrow Never Dies': 200, b'GoldenEye': 200, b'A Dangerous Method': 200, b'Armageddon': 200, b'Transformers: Dark of the Moon': 200, b'Night at the Museum': 200, b'Pain & Gain': 200, b'Captain America: Civil War': 400, b'Interstellar': 200, b'Transformers': 200, b'Pacific Rim': 200, b'Transformers: Age of Extinction': 200, b'Charlottes Web': 200, b'Alvin and the Chipmunks: The Road Chip': 200, b'Walk Hard: The Dewey Cox Story': 200, b'How to Train Your Dragon': 200, b'The Three Stooges': 200, b'Pitch Perfect 2': 200, b'Toy Story 2': 200, b'Josie and the Pussycats': 200, b'Cars': 200, b'Hairspray': 200, b'The Jungle Book': 200, b'The Blues Brothers': 200, b'Rio': 200, b'High School Musical 3: Senior Year': 200, b'Zookeeper': 200, b'Spice World': 200, b'Meet Dave': 200, b'Mr. Peabody & Sherman': 200, b'Wreck-It Ralph': 200, b'Alvin and the Chipmunks: Chipwrecked': 200, b'Megamind':  ...
# ----Star Wars with rating 3.0 not in movies_score-------------
# ----American Beauty with rating 3.5 not in movies_score-------------
# ----Dancer in the Dark with rating 4.0 not in movies_score-------------
# ----Jarhead with rating 4.5 not in movies_score-------------
# ----Scarface with rating 5.0 not in movies_score-------------
# ----Donnie Darko with rating 1.0 not in movies_score-------------
# ----Lost in Translation with rating 2.0 not in movies_score-------------
# ----The Dark Knight with rating 2.0 not in movies_score-------------
# ----Oceans Eleven with rating 1.0 not in movies_score-------------
# ----Edward Scissorhands with rating 3.0 not in movies_score-------------
# ----Back to the Future Part II with rating 4.5 not in movies_score-------------
# ----Saw with rating 5.0 not in movies_score-------------
# ----Minority Report with rating 0.5 not in movies_score-------------
# ----Lucky Number Slevin with rating 3.0 not in movies_score-------------
# ----Cat on a Hot Tin Roof with rating 4.0 not in movies_score-------------
# ----Batman Begins with rating 4.0 not in movies_score-------------
# ----High Noon with rating 4.0 not in movies_score-------------
# ----Casablanca with rating 1.5 not in movies_score-------------
# ----Magnolia with rating 1.0 not in movies_score-------------
# ----Summer Storm with rating 4.0 not in movies_score-------------
# ----Eyes Wide Shut with rating 3.0 not in movies_score-------------
# ----The Devil Wears Prada with rating 3.0 not in movies_score-------------
# ----A Nightmare on Elm Street with rating 2.0 not in movies_score-------------
# ----Rain Man with rating 3.0 not in movies_score-------------
# ----Leaving Las Vegas with rating 3.0 not in movies_score-------------
# ----Monsoon Wedding with rating 3.0 not in movies_score-------------
# ----Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan with rating 3.0 not in movies_score-------------
# ----Reservoir Dogs with rating 4.0 not in movies_score-------------
# ----Love Actually with rating 3.0 not in movies_score-------------
# ----Casino with rating 1.0 not in movies_score-------------
# ----Basquiat with rating 2.5 not in movies_score-------------
# ----Die Hard with rating 0.5 not in movies_score-------------
# ----Big Fish with rating 3.0 not in movies_score-------------
# ----The Hours with rating 3.0 not in movies_score-------------
# ----The Conversation with rating 1.0 not in movies_score-------------
# ----The Terminal with rating 5.0 not in movies_score-------------
# ----Harry Potter and the Goblet of Fire with rating 3.0 not in movies_score-------------
# ----The Living Daylights with rating 2.5 not in movies_score-------------
# ----American Graffiti with rating 3.0 not in movies_score-------------
# ----Finding Neverland with rating 4.5 not in movies_score-------------
# ----The Thomas Crown Affair with rating 5.0 not in movies_score-------------
# ----Cars with rating 5.0 not in movies_score-------------
# ----Dawn of the Dead with rating 5.0 not in movies_score-------------
# ----Galaxy Quest with rating 5.0 not in movies_score-------------
# ----Gremlins with rating 5.0 not in movies_score-------------
# ----Gremlins 2: The New Batch with rating 5.0 not in movies_score-------------
# ----Halloween with rating 3.5 not in movies_score-------------
# ----Ice Age: The Meltdown with rating 4.5 not in movies_score-------------
# ----Mission: Impossible II with rating 5.0 not in movies_score-------------
# ----Mulholland Drive with rating 2.5 not in movies_score-------------
# ----Whale Rider with rating 5.0 not in movies_score-------------
# ----The Thirteenth Floor with rating 4.0 not in movies_score-------------
# ----The Prestige with rating 3.0 not in movies_score-------------
# ----Ghost Rider with rating 3.5 not in movies_score-------------
# ----Bridge to Terabithia with rating 5.0 not in movies_score-------------
# ----Street Kings with rating 3.0 not in movies_score-------------
# ----300 with rating 4.0 not in movies_score-------------
# ----Dogtown and Z-Boys with rating 5.0 not in movies_score-------------
# ----Hellboy with rating 2.5 not in movies_score-------------
# ----Die Hard 2 with rating 1.0 not in movies_score-------------
# ----School of Rock with rating 4.0 not in movies_score-------------
# ----Whats Eating Gilbert Grape with rating 1.0 not in movies_score-------------
# ----Speed 2: Cruise Control with rating 0.5 not in movies_score-------------
# ----The Reaping with rating 3.0 not in movies_score-------------
# ----The Mummy Returns with rating 3.5 not in movies_score-------------
# ----Fahrenheit 9/11 with rating 3.0 not in movies_score-------------
# ----Pirates of the Caribbean: On Stranger Tides with rating 1.0 not in movies_score-------------
# ----Malcolm X with rating 3.0 not in movies_score-------------
# ----Don Juan DeMarco with rating 3.0 not in movies_score-------------
# ----The Sea Inside with rating 4.5 not in movies_score-------------
# ----Sweet November with rating 2.0 not in movies_score-------------
# ----Shakespeare in Love with rating 3.5 not in movies_score-------------
# ----eXistenZ with rating 5.0 not in movies_score-------------
# ----An Unfinished Life with rating 5.0 not in movies_score-------------
# ----Crank with rating 5.0 not in movies_score-------------
# ----Lucky You with rating 5.0 not in movies_score-------------
# ----The Elephant Man with rating 4.0 not in movies_score-------------
# ----Gerry with rating 5.0 not in movies_score-------------
# ----8 Women with rating 3.0 not in movies_score-------------
# ----My Name Is Bruce with rating 3.0 not in movies_score-------------
# ----Two Brothers with rating 3.0 not in movies_score-------------
# ----Persepolis with rating 1.0 not in movies_score-------------
# ----The Diving Bell and the Butterfly with rating 2.0 not in movies_score-------------
# ----Hidalgo with rating 2.0 not in movies_score-------------
# ----The Station Agent with rating 3.5 not in movies_score-------------
# ----Original Sin with rating 3.5 not in movies_score-------------
# ----Romeo Must Die with rating 3.0 not in movies_score-------------
# ----Romeo Is Bleeding with rating 2.0 not in movies_score-------------
# ----The Time Machine with rating 1.0 not in movies_score-------------
# ----Reindeer Games with rating 2.0 not in movies_score-------------
# ----The Glass House with rating 4.0 not in movies_score-------------
# ----The Golden Compass with rating 3.0 not in movies_score-------------
# ----Cold Mountain with rating 5.0 not in movies_score-------------
# ----Jakob the Liar with rating 4.0 not in movies_score-------------
# ----Asterix at the Olympic Games with rating 2.0 not in movies_score-------------
# ----The Chronicles of Narnia: Prince Caspian with rating 3.5 not in movies_score-------------
# ----The Bourne Identity with rating 3.5 not in movies_score-------------
# ----The Bourne Supremacy with rating 2.5 not in movies_score-------------
# ----Spanglish with rating 3.0 not in movies_score-------------
# ----Return to Me with rating 3.0 not in movies_score-------------
# ----Adaptation. with rating 3.0 not in movies_score-------------
# ----American Pie 2 with rating 4.0 not in movies_score-------------
# ----Hairspray with rating 3.5 not in movies_score-------------
# ----The Big Parade with rating 5.0 not in movies_score-------------
# ----Basic Instinct 2 with rating 2.0 not in movies_score-------------
# ----88 Minutes with rating 1.5 not in movies_score-------------
# ----Flags of Our Fathers with rating 4.0 not in movies_score-------------
# ----Beetlejuice with rating 0.5 not in movies_score-------------
# ----The Kingdom with rating 4.5 not in movies_score-------------
# ----Seabiscuit with rating 3.0 not in movies_score-------------
# ----Enchanted with rating 3.0 not in movies_score-------------
# ----Ghost Dog: The Way of the Samurai with rating 4.0 not in movies_score-------------
# ----Impostor with rating 4.5 not in movies_score-------------
# ----Boogie Nights with rating 4.0 not in movies_score-------------
# ----The Chorus with rating 3.5 not in movies_score-------------
# ----The Sentinel with rating 3.0 not in movies_score-------------
# ----The Mist with rating 4.0 not in movies_score-------------
# ----A Bridge Too Far with rating 5.0 not in movies_score-------------
# ----The Good Thief with rating 4.0 not in movies_score-------------
# ----The Shipping News with rating 2.0 not in movies_score-------------
# ----Idle Hands with rating 4.5 not in movies_score-------------
# ----Love in the Time of Cholera with rating 4.5 not in movies_score-------------
# ----The 40 Year Old Virgin with rating 3.5 not in movies_score-------------
# ----No Country for Old Men with rating 3.5 not in movies_score-------------
# ----xXx with rating 2.5 not in movies_score-------------
# ----Midnight in the Garden of Good and Evil with rating 1.5 not in movies_score-------------
# ----They Live with rating 4.0 not in movies_score-------------
# ----Wild Wild West with rating 2.5 not in movies_score-------------
# ----Prom Night with rating 3.0 not in movies_score-------------
# ----The History Boys with rating 4.0 not in movies_score-------------
# ----K-19: The Widowmaker with rating 3.5 not in movies_score-------------
# ----Mercury Rising with rating 4.0 not in movies_score-------------
# ----Twilight with rating 4.0 not in movies_score-------------
# ----The Out-of-Towners with rating 3.5 not in movies_score-------------
# ----Disclosure with rating 2.5 not in movies_score-------------
# ----The River Wild with rating 3.0 not in movies_score-------------
# ----Jackass: The Movie with rating 4.0 not in movies_score-------------
# ----Carriers with rating 4.0 not in movies_score-------------
# ----Harry Brown with rating 4.0 not in movies_score-------------
# ----Once in a Lifetime: The Extraordinary Story of the New York Cosmos with rating 5.0 not in movies_score-------------
# ----Kevin Hart: Laugh at My Pain with rating 3.5 not in movies_score-------------
# 0it [00:00, ?it/s]
# My similar movies for Madagascar: 2
# My similar movies for Notting Hill: 7
# My similar movies for Aliens vs Predator: Requiem: 10
# My similar movies for Interview with the Vampire: 6
# My similar movies for Bill & Teds Bogus Journey: 10
# My similar movies for Live and Let Die: 31
# My similar movies for Alexander: 2
# My similar movies for My Best Friends Wedding: 26
# My similar movies for Men in Black II: 24
# My similar movies for My Super Ex-Girlfriend: 3
# My similar movies for Shine a Light: 3
# My similar movies for Amélie: 1
# My similar movies for Terminator 3: Rise of the Machines: 23
# My similar movies for X-Men Origins: Wolverine: 41
# My similar movies for Dances with Wolves: 5
# My similar movies for The Talented Mr. Ripley: 12
# My similar movies for Payback: 6
# My similar movies for The Transporter: 1
# My similar movies for The Butterfly Effect: 2
# My similar movies for Horrible Bosses: 2
# My similar movies for Amadeus: 0
# My similar movies for 54: 1
# My similar movies for Maurice: 8
# My similar movies for Raiders of the Lost Ark: 9
# My similar movies for Flashdance: 4
# My similar movies for Superman: 47
# My similar movies for The Last Emperor: 2
# My similar movies for Mean Streets: 0
# My similar movies for Team America: World Police: 6
# My similar movies for Mission to Mars: 1
# I am the predict method, seeing a movie score of 245 movies
# ...
# ----Mercury Rising with rating 4.0 not in movies_score-------------
# ----Twilight with rating 4.0 not in movies_score-------------
# ----The Out-of-Towners with rating 3.5 not in movies_score-------------
# ----Disclosure with rating 2.5 not in movies_score-------------
# ----The River Wild with rating 3.0 not in movies_score-------------
# ----Jackass: The Movie with rating 4.0 not in movies_score-------------
# ----Carriers with rating 4.0 not in movies_score-------------
# ----Harry Brown with rating 4.0 not in movies_score-------------
# ----Once in a Lifetime: The Extraordinary Story of the New York Cosmos with rating 5.0 not in movies_score-------------
# ----Kevin Hart: Laugh at My Pain with rating 3.5 not in movies_score-------------
# 0it [00:00, ?it/s]
# My similar movies for Letters from Iwo Jima: 6
# My similar movies for Mean Streets: 0
# My similar movies for Notting Hill: 7
# My similar movies for Manderlay: 0
# My similar movies for Deconstructing Harry: 15
# My similar movies for The Karate Kid: 0
# My similar movies for 54: 1
# My similar movies for Psycho: 4
# My similar movies for Match Point: 14
# My similar movies for Alvin and the Chipmunks: 25
# My similar movies for Moulin Rouge!: 7
# My similar movies for The Kite Runner: 1
# My similar movies for Lions for Lambs: 8
# My similar movies for My Best Friends Wedding: 26
# My similar movies for Wasabi: 0
# My similar movies for License to Wed: 2
# My similar movies for Harry Potter and the Philosophers Stone: 21
# My similar movies for The Sixth Sense: 8
# My similar movies for The Legend of Suriyothai: 0
# My similar movies for Amadeus: 0
# My similar movies for Highlander: The Final Dimension: 2
# My similar movies for Flash Gordon: 0
# My similar movies for The Talented Mr. Ripley: 12
# My similar movies for Friends with Money: 13
# My similar movies for Rosemarys Baby: 1
# My similar movies for Terminator 3: Rise of the Machines: 23
# My similar movies for Rocky Balboa: 1
# My similar movies for Confessions of a Dangerous Mind: 1
# My similar movies for About Schmidt: 0
# My similar movies for This Is 40: 4
# I am the predict method, seeing a movie score of 194 movies
# {b'Flags of Our Fathers': 200, b'Downfall': 200, b'Tora! Tora! Tora!': 200, b'The English Patient': 200, b'Million Dollar Baby': 200, b'City of Life and Death': 200, b'Bridget Jones: The Edge of Reason': 200, b'Love Actually': 200, b'102 Dalmatians': 200, b'Bridget Joness Diary': 200, b'Boys and Girls': 200, b'Something Borrowed': 400, b'About a Boy': 400, b'Just Looking': 200, b'Please Give': 400, b'Celebrity': 200, b'Everyone Says I Love You': 600, b'The Curse of the Jade Scorpion': 200, b'Small Time Crooks': 200, b'When Harry Met Sally...': 200, b'Party Monster': 200, b'Metropolitan': 200, b'Sleeper': 200, b'Radio Days': 200, b'Analyze This': 200, b'Vicky Cristina Barcelona': 200, b'The Astronaut Farmer': 200, b'Bullets Over Broadway': 200, b'The Doors': 200, b'The Way of the Gun': 200, b'Kill List': 200, b'The Devils Rejects': 200, b'Nine Queens': 200, b'Shooting Fish': 200, b'In the Land of Women': 200, b'The Oh in Ohio': 200, b'Cruel Intentions': 200, b'Notes on a Scandal': 200, b'The Piano': 400, b'Country Strong': 200, b'Her': 200, b'Days of Heaven': 200, b'Troy': 200, b'Annie Hall': 200, b'The Horse Whisperer': 200, b'Lost in Translation': 200, b'Charlottes Web': 200, b'Alvin and the Chipmunks: The Road Chip': 200, b'Walk Hard: The Dewey Cox Story': 200, b'How to Train Your Dragon': 200, b'The Three Stooges': 200, b'Pitch Perfect 2': 200, b'Toy Story 2': 200, b'Josie and the Pussycats': 200, b'Cars': 200, b'Hairspray': 200, b'The Jungle Book': 200, b'The Blues Brothers': 200, b'Rio': 400, b'High School Musical 3: Senior Year': 400, b'Zookeeper': 200, b'Spice World': 200, b'Meet Dave': 200, b'Mr. Peabody & Sherman': 200, b'Wreck-It Ralph': 200, b'Alvin and the Chipmunks: Chipwrecked': 200, b'Megamind': 200, b'The Lego Movie': 200, b'Glee: The Concert Movie': 200, b'As It Is in Heaven': 200, b'Alvin and the Chipmunks: The Squeakquel': 200, b'Across the Universe': 200, b'Straight Outta Compton': 200, b'High School Musical 2': 200, b'Mr. Hollands Opus': 200, b'Topsy-Turvy': 200, b'High School Musical': 200, b'Finding Neverland': 200, b'Max': 200, b'The Hunting Party': 200, b'Fury': 200, b'Southland Tales': 200, b'Vantage Point': 200, b'The Lucky Ones': 200, b'Damnation Alley': 200, b'The Hunger Games: Catching Fire': 200, b'American Wedding': 200, b'27 Dresses': 200, b'Monsoon Wedding': 200, b'What Happens in Vegas': 200, b'The Story of Us': 200, b'My Big Fat Greek Wedding': 200, b'Our Family Wedding': 200, b'Kate & Leopold': 200, b'Caramel': 200, b'Good Luck Chuck': 200, b'Four Weddings and a Funeral': 200, b'Leap Year': 200, b'Crossroads': 200, b'The Wedding Planner': 200, b'Very Bad Things': 200, b'Much Ado About Nothing': 200, b'My Big Fat Greek Wedding 2': 200, b'My Best Friends Girl': 200, b'Being John Malkovich': 200, b'Definitely, Maybe': 200, b'Down to You': 200, b'The Wedding Date': 200, b'The Guru': 200, b'Run, Fatboy, Run': 200, b'Shes the One': 200, b'Because I Said So': 200, b'The NeverEnding Story': 200, b'The Sorcerers Apprentice': 200, b'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe': 200, b'Harry Potter and the Chamber of Secrets': 200, b'The Chronicles of Narnia: The Voyage of the Dawn Treader': 200, b'Eragon': 200, b'Warlock': 200, b'Stormbreaker': 200, b'Oz: The Great and Powerful': 200, b'Harry Potter and the Goblet of Fire': 200, b'Pan': 200, b'The Santa Clause 2': 200, b'Seventh Son': 200, b'Hocus Pocus': 200, b'Harry Potter and the Prisoner of Azkaban': 200, b'Harry Potter and the Half-Blood Prince': 200, b'Spirited Away': 200, b'Harry Potter and the Order of the Phoenix': 200, b'Percy Jackson & the Olympians: The Lightning Thief': 200, b'Ella Enchanted': 200, b'Hotel Transylvania': 200, b'Sleepers': 200, b'Ghost': 200, b'Mystic River': 200, b'Unbreakable': 200, b'Copycat': 200, b'One Missed Call': 200, b'The Devils Advocate': 200, b'Captain America: The First Avenger': 200, b'Highlander': 200, b'The Lady from Shanghai': 200, b'The Life Aquatic with Steve Zissou': 200, b'The Godfa ...
# ----Star Wars with rating 3.0 not in movies_score-------------
# ----American Beauty with rating 3.5 not in movies_score-------------
# ----Dancer in the Dark with rating 4.0 not in movies_score-------------
# ----Jarhead with rating 4.5 not in movies_score-------------
# ----Scarface with rating 5.0 not in movies_score-------------
# ----Donnie Darko with rating 1.0 not in movies_score-------------
# ----Lost in Translation with rating 2.0 not in movies_score-------------
# ----The Dark Knight with rating 2.0 not in movies_score-------------
# ----Oceans Eleven with rating 1.0 not in movies_score-------------
# ----Edward Scissorhands with rating 3.0 not in movies_score-------------
# ----Back to the Future Part II with rating 4.5 not in movies_score-------------
# ----Saw with rating 5.0 not in movies_score-------------
# ----Minority Report with rating 0.5 not in movies_score-------------
# ----Lucky Number Slevin with rating 3.0 not in movies_score-------------
# ----Cat on a Hot Tin Roof with rating 4.0 not in movies_score-------------
# ----Batman Begins with rating 4.0 not in movies_score-------------
# ----High Noon with rating 4.0 not in movies_score-------------
# ----Casablanca with rating 1.5 not in movies_score-------------
# ----Magnolia with rating 1.0 not in movies_score-------------
# ----Summer Storm with rating 4.0 not in movies_score-------------
# ----Eyes Wide Shut with rating 3.0 not in movies_score-------------
# ----The Devil Wears Prada with rating 3.0 not in movies_score-------------
# ----A Nightmare on Elm Street with rating 2.0 not in movies_score-------------
# ----Rain Man with rating 3.0 not in movies_score-------------
# ----Leaving Las Vegas with rating 3.0 not in movies_score-------------
# ----Monsoon Wedding with rating 3.0 not in movies_score-------------
# ----Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan with rating 3.0 not in movies_score-------------
# ----Reservoir Dogs with rating 4.0 not in movies_score-------------
# ----Love Actually with rating 3.0 not in movies_score-------------
# ----Casino with rating 1.0 not in movies_score-------------
# ----Basquiat with rating 2.5 not in movies_score-------------
# ----Die Hard with rating 0.5 not in movies_score-------------
# ----Big Fish with rating 3.0 not in movies_score-------------
# ----The Hours with rating 3.0 not in movies_score-------------
# ----The Conversation with rating 1.0 not in movies_score-------------
# ----The Terminal with rating 5.0 not in movies_score-------------
# ----Harry Potter and the Goblet of Fire with rating 3.0 not in movies_score-------------
# ----The Living Daylights with rating 2.5 not in movies_score-------------
# ----American Graffiti with rating 3.0 not in movies_score-------------
# ----Finding Neverland with rating 4.5 not in movies_score-------------
# ----The Thomas Crown Affair with rating 5.0 not in movies_score-------------
# ----Cars with rating 5.0 not in movies_score-------------
# ----Dawn of the Dead with rating 5.0 not in movies_score-------------
# ----Galaxy Quest with rating 5.0 not in movies_score-------------
# ----Gremlins with rating 5.0 not in movies_score-------------
# ----Gremlins 2: The New Batch with rating 5.0 not in movies_score-------------
# ----Halloween with rating 3.5 not in movies_score-------------
# ----Ice Age: The Meltdown with rating 4.5 not in movies_score-------------
# ----Mission: Impossible II with rating 5.0 not in movies_score-------------
# ----Mulholland Drive with rating 2.5 not in movies_score-------------
# ----Whale Rider with rating 5.0 not in movies_score-------------
# ----The Thirteenth Floor with rating 4.0 not in movies_score-------------
# ----The Prestige with rating 3.0 not in movies_score-------------
# ----Ghost Rider with rating 3.5 not in movies_score-------------
# ----Bridge to Terabithia with rating 5.0 not in movies_score-------------
# ----Street Kings with rating 3.0 not in movies_score-------------
# ----300 with rating 4.0 not in movies_score-------------
# ----Dogtown and Z-Boys with rating 5.0 not in movies_score-------------
# ----Hellboy with rating 2.5 not in movies_score-------------
# ----Die Hard 2 with rating 1.0 not in movies_score-------------
# ----School of Rock with rating 4.0 not in movies_score-------------
# ----Whats Eating Gilbert Grape with rating 1.0 not in movies_score-------------
# ----Speed 2: Cruise Control with rating 0.5 not in movies_score-------------
# ----The Reaping with rating 3.0 not in movies_score-------------
# ----The Mummy Returns with rating 3.5 not in movies_score-------------
# ----Fahrenheit 9/11 with rating 3.0 not in movies_score-------------
# ----Pirates of the Caribbean: On Stranger Tides with rating 1.0 not in movies_score-------------
# ----Malcolm X with rating 3.0 not in movies_score-------------
# ----Don Juan DeMarco with rating 3.0 not in movies_score-------------
# ----The Sea Inside with rating 4.5 not in movies_score-------------
# ----Sweet November with rating 2.0 not in movies_score-------------
# ----Shakespeare in Love with rating 3.5 not in movies_score-------------
# ----eXistenZ with rating 5.0 not in movies_score-------------
# ----An Unfinished Life with rating 5.0 not in movies_score-------------
# ----Crank with rating 5.0 not in movies_score-------------
# ----Lucky You with rating 5.0 not in movies_score-------------
# ----The Elephant Man with rating 4.0 not in movies_score-------------
# ----Gerry with rating 5.0 not in movies_score-------------
# ----8 Women with rating 3.0 not in movies_score-------------
# ----My Name Is Bruce with rating 3.0 not in movies_score-------------
# ----Two Brothers with rating 3.0 not in movies_score-------------
# ----Persepolis with rating 1.0 not in movies_score-------------
# ----The Diving Bell and the Butterfly with rating 2.0 not in movies_score-------------
# ----Hidalgo with rating 2.0 not in movies_score-------------
# ----The Station Agent with rating 3.5 not in movies_score-------------
# ----Original Sin with rating 3.5 not in movies_score-------------
# ----Romeo Must Die with rating 3.0 not in movies_score-------------
# ----Romeo Is Bleeding with rating 2.0 not in movies_score-------------
# ----The Time Machine with rating 1.0 not in movies_score-------------
# ----Reindeer Games with rating 2.0 not in movies_score-------------
# ----The Glass House with rating 4.0 not in movies_score-------------
# ----The Golden Compass with rating 3.0 not in movies_score-------------
# ----Cold Mountain with rating 5.0 not in movies_score-------------
# ----Jakob the Liar with rating 4.0 not in movies_score-------------
# ----Asterix at the Olympic Games with rating 2.0 not in movies_score-------------
# ----The Chronicles of Narnia: Prince Caspian with rating 3.5 not in movies_score-------------
# ----The Bourne Identity with rating 3.5 not in movies_score-------------
# ----The Bourne Supremacy with rating 2.5 not in movies_score-------------
# ----Spanglish with rating 3.0 not in movies_score-------------
# ----Return to Me with rating 3.0 not in movies_score-------------
# ----Adaptation. with rating 3.0 not in movies_score-------------
# ----American Pie 2 with rating 4.0 not in movies_score-------------
# ----Hairspray with rating 3.5 not in movies_score-------------
# ----The Big Parade with rating 5.0 not in movies_score-------------
# ----Basic Instinct 2 with rating 2.0 not in movies_score-------------
# ----88 Minutes with rating 1.5 not in movies_score-------------
# ----Flags of Our Fathers with rating 4.0 not in movies_score-------------
# ----Beetlejuice with rating 0.5 not in movies_score-------------
# ----The Kingdom with rating 4.5 not in movies_score-------------
# ----Seabiscuit with rating 3.0 not in movies_score-------------
# ----Enchanted with rating 3.0 not in movies_score-------------
# ----Ghost Dog: The Way of the Samurai with rating 4.0 not in movies_score-------------
# ----Impostor with rating 4.5 not in movies_score-------------
# ----Boogie Nights with rating 4.0 not in movies_score-------------
# ----The Chorus with rating 3.5 not in movies_score-------------
# ----The Sentinel with rating 3.0 not in movies_score-------------
# ----The Mist with rating 4.0 not in movies_score-------------
# ----A Bridge Too Far with rating 5.0 not in movies_score-------------
# ----The Good Thief with rating 4.0 not in movies_score-------------
# ----The Shipping News with rating 2.0 not in movies_score-------------
# ----Idle Hands with rating 4.5 not in movies_score-------------
# ----Love in the Time of Cholera with rating 4.5 not in movies_score-------------
# ----The 40 Year Old Virgin with rating 3.5 not in movies_score-------------
# ----No Country for Old Men with rating 3.5 not in movies_score-------------
# ----xXx with rating 2.5 not in movies_score-------------
# ----Midnight in the Garden of Good and Evil with rating 1.5 not in movies_score-------------
# ----They Live with rating 4.0 not in movies_score-------------
# ----Wild Wild West with rating 2.5 not in movies_score-------------
# ----Prom Night with rating 3.0 not in movies_score-------------
# ----The History Boys with rating 4.0 not in movies_score-------------
# ----K-19: The Widowmaker with rating 3.5 not in movies_score-------------
# ----Mercury Rising with rating 4.0 not in movies_score-------------
# ----Twilight with rating 4.0 not in movies_score-------------
# ----The Out-of-Towners with rating 3.5 not in movies_score-------------
# ----Disclosure with rating 2.5 not in movies_score-------------
# ----The River Wild with rating 3.0 not in movies_score-------------
# ----Jackass: The Movie with rating 4.0 not in movies_score-------------
# ----Carriers with rating 4.0 not in movies_score-------------
# ----Harry Brown with rating 4.0 not in movies_score-------------
# ----Once in a Lifetime: The Extraordinary Story of the New York Cosmos with rating 5.0 not in movies_score-------------
# ----Kevin Hart: Laugh at My Pain with rating 3.5 not in movies_score-------------
# precision: 1.0
# recall: 0.0
# f1: 0.0
