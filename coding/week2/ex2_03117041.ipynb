# %% [markdown]
# ## Ομάδα
#
# Στοιχεία Μέλους 1: Αθανασίου Ιωάννης, 03117041
#
# Στοιχεία Μέλους 2: -

# %% [markdown]
# # Τεχνητή Νοημοσύνη: Εργαστηριακή Άσκηση 2
# ---
#
# Ο στόχος της εργασίας είναι η κατασκευή ενός συστήματος προτάσεων (Recommendation System) για ταινίες. Οι προτάσεις αυτές θα πηγάζουν τόσο από τα χαρακτηριστικά της ταινίας όσο και από ορισμένες αξιολογήσεις του κάθε χρήστη.
#
# Στα δεδομένα της άσκησης περιλαμβάνονται ένα αρχείο με το όνομα movies_metadata.csv το όποιο περιέχει τα χαρακτηριστικά κάθε ταινίας όπως θέμα, σκηνοθέτης ηθοποιοί, λέξεις κλειδιά κ.α. από το imdb καθώς και τα αρχεία ratings.csv τα όποια περιέχουν πραγματικές αξιολογήσεις χρηστών, χωρισμένες σε train και σε test.

# %% [markdown]
# ## Εκφώνηση
# Στην παρούσα εργασία σας ζητείται να μελετήσετε και να υλοποιήσετε τα παρακάτω:<br>

# %% [markdown]
# ### Μέρος 1

# %% [markdown]
# Στο μέρος 1 και 2 θα εργαστείτε μόνο με το αρχείο movies_metadata.csv, ενώ στο μέρος τρία θα δουλέψετε και με τα αρχεία των αξιολογήσεων.
# #### Ερώτημα 1α
#
# Αρχικά θα πρέπει, αφού μελετήσετε τη δομή και τα χαρακτηριστικά του movies_metadata.csv, να κατασκευάσετε μια βάση γνώσης για την Prolog η όποια ουσιαστικά θα αποτελεί τον κόσμο με τον όποιο θα εργαστείτε στην συνέχεια. Τα κατηγορήματα που θα δημιουργηθούν θα σας βοηθήσουν και στην κατασκευή του recommender και θα είναι της μορφής:
#
# ```
# director(Movie, Director).
# genre(Movie, Genre).
# ```
# #### Ερώτημα 1β
#
# Αφού δημιουργήσετε τον κόσμο του προβλήματος, στη συνέχεια καλείστε να δημιουργήσετε, σε Prolog, απλούς κανόνες οι οποίοι θα βρίσκουν όλες τις ταινίες με:
# 1.	Κοινό θέμα (κάποιες λέξεις σχετικά με το genre κοινές)
# 2.	Αρκετά κοινό θέμα (κάποιες λιγότερες λέξεις σχετικά με το genre κοινές π.χ. 3)
# 3.	Σχετικά κοινό θέμα (λίγες λέξεις σχετικές με το genre κοινές π.χ. 1)
# 4.	Κοινός σκηνοθέτης
# 5.	Ακριβώς ίδια πλοκή (κάποιες λέξεις κλειδιά της πλοκής κοινές)
# 6.	Σχετικά ίδια πλοκή (κάποιες λιγότερες λέξεις κλειδιά κοινές)
# 7.	Ίδιους τους βασικούς ηθοποιούς (και τους 3)
# 8.	Αρκετά ίδιους βασικούς ηθοποιούς (ορισμένους βασικούς ηθοποιούς κοινούς π.χ. 2)
# 9.	Σχετικά ίδιους ηθοποιούς (π.χ. 1 από τους 3)
# 10.	Ίδια γλώσσα
# 11.	Είναι έγχρωμες ή ασπρόμαυρες
# 12. Κοινό studio παραγωγής
# 13. Κοινή χώρα παραγωγής
# 14. Ίδια δεκαετία
#
# Αξίζει να σημειωθεί ότι στα παραπάνω μπορείτε να προσθέσετε περισσότερα ερωτήματα ή να αλλάξετε την κλιμακωσιμότητα των queries (πέρα από το ίδιο, αρκετά ίδιο, σχετικά ίδιο) που θα κατασκευάσετε(π.χ. μια κλίμακα από 1 στα 5 όπου αυτό είναι δυνατόν), μιας και αυτά στην συνέχεια θα χρησιμοποιηθούν για την λειτουργία του recommender. Έτσι μπορείτε να προσθέσετε queries με τα όποια μπορεί να παράγονται καλύτερες συστάσεις  (το αρχείο movie_metadata.csv περιέχει πολλές πληροφορίες ακόμα για κάθε ταινία όπως έτος κυκλοφορίας, βαθμολογία στο imdb, facebοok_likes κ.α.). Το συγκεκριμένο μέρος εργασίας είναι προπαρασκευαστικό οπότε όσο καλύτερα και πλουσιότερα τα ερωτήματα που θα φτιάξετε σε αυτό το μέρος τόσο καλύτερη θα είναι η απόδοσή των συστημάτων συστάσεων των επόμενων ερωτημάτων.
#
# Περισσότερες πληροφορίες για το dataset μπορείτε να διαβάσετε σε αυτό το [Link](https://www.kaggle.com/georgefila/movies-metadata):

# %% [markdown]
# ### Μέρος 2: Recommendation System

# %% [markdown]
# Στο σημείο αυτό καλείστε με βάση αυτά που κάνατε στο μέρος 1 να κατασκευάσετε queries τα όποια θα σας επιστρέφουν παρόμοιες (σε χαρακτηριστικά) ταινίες. Τα ερωτήματα αυτά θα είναι κλιμακούμενα, δηλαδή θα υπάρχουν ερωτήματα που επιστρέφουν αρκετά κοινές ταινίες αλλά και που επιστρέφουν λιγότερο και λιγότερο κοινές (σε μια κλίμακα π.χ. από 1 σε 5). Για παράδειγμα:
#
# ```
# find_simmilar_movies_5("Pirates Of The Caribbean", M).
# M = "Pirates Of The Caribbean: On Stranger Tides"
# M = "The Chronicles Of Narnia"
# M = "Prince Of Persia: The Sands Of Time"
# ...
# ```
# Για παράδειγμα, το παραπάνω ερώτημα θα επιστρέφει αρκετά κοινές σε περιεχόμενο ταινίες με την ταινια "Pirates Of The Caribbean". Θα υπάρχουν και αντίστοιχα ερωτήματα που θα βρίσκουν λιγότερο όμοιες ταινίες. Ο δείκτης ομοιότητας των ταινιών είναι αυθαίρετος και μπορείτε να τον ορίσετε εσείς όπως θέλετε, αρκεί να υπάρχει κάποια λογική σύνδεση με τα δεδομένα που περιέχονται στο αρχείο movies_metadata.csv.
#
# Συνεπώς η συνάρτηση που θα κάνει τις προτάσεις (recommendation) με είσοδο μια ταινία πρέπει να επιστρέφει-εκτυπώνει μια λίστα με τις προτεινόμενες ταινίες κατά φθίνουσα σειρά ομοιότητας.

# %% [markdown]
# ### 3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις - Αξιολογήσεις του χρήστη

# %% [markdown]
# Σε αυτό το σημείο θα εργαστείτε με τα αρχεία ratings τα όποια περιέχουν αξιολογήσεις (από 1 μέχρι 5) για τις παραπάνω ταινίες. Το προηγούμενο σύστημα συστάσεων προτείνει στον χρήστη ταινίες αποκλειστικά με βάση την ομοιότητά τους. Σε αυτό το σημείο θα γίνει μια αναβάθμιση του συστήματος έτσι ώστε να παράγονται καλύτερες  συστάσεις οι όποιες θα λαμβάνουν υπόψιν και τις προτιμήσεις του χρήστη, οι όποιες θα εξάγονται από τις αξιολογήσεις που έχει κάνει μέχρι στιγμής.
#
# Η εκπαίδευση του recommender θα γίνεται ως εξής:
#
# Για κάθε ταινία θα υπάρχει ένα score το όποιο αρχικά θε είναι ίσο με 0 και θα διαμορφώνεται από τις αξιολογήσεις κάθε user. Έτσι για έναν χρήστη με βάση τις αξιολογήσεις που υπάρχουν στο αρχείο train_ratings θα πρέπει:
#
# 1.	Για κάθε ταινία που έχει βαθμολογήσει να βρίσκονται οι κοινές ταινίες ανά κλίμακα και στο μέχρι τώρα σκορ κάθε παρόμοιας ταινίας θα προστίθεται ένα βάρος το όποιο θα μπορούσε να είναι το ποσοστό ομοιότητας της ταινίας (δηλαδή ένα βάρος για κάθε κλίμακα, αν δύο ταινίες μοιάζουν ενισχύουμε το βάρος που προσθέτουμε από το να μοιάζουν λιγότερο) επί τον βαθμό που έχει βάλει ο χρήστης για την αρχική ταινία (διαφορετικό είναι ο χρήστης να έχει βάλει 5/5 ή 1/5 σε μια ταινία από 3/5).
#
# 2. Στη συνέχεια, ανάλογα με το σκορ που έχει σχηματιστεί για κάθε ταινία, θα επιλέγεται αν αυτή θα μπορούσε να είναι προτεινόμενη για τον χρήστη ή όχι και θα μετράμε το πόσο καλά τα πήγε το σύστήμά μας με βάση ορισμένες μετρικές.
#
# Η λογική πίσω από την παραπάνω διαδικασία είναι ότι παρόμοιες ταινίες θα έχουν ανάλογο βαθμό. Για παράδειγμα αν ένας χρήστης έχει αξιολογήσει αρκετές  ταινίες οι όποιες είναι sci-fiction με 5/5 τότε μια ταίνια sci-fiction την όποια δεν έχει δεί λογικά θα του αρέσει και θα έπρεπε να την προτείνουμε.
#
# Μετά την εκπαίδευση του συστήματος σας καλείστε να δοκιμάσετε τον recommender που κατασκευάσατε στην πράξη. Για τον σκοπό αυτό θα φορτώσετε το αρχείο test_ratings.csv όπου περιέχονται οι αξιολογήσεις του ίδιου χρήστη για άλλες ταινίες. Το σύστημά σας πρέπει να προβλέπει αν μια ταινία θα πρέπει να προταθεί στον χρήστη. Μια ταίνια θα έπρεπε να έχει προταθεί στον  χρήστη, αν έχει βαθμό μεγαλύτερο του 3. Συνεπώς για την επίβλεψη του συστήματός σας θα πρέπει για κάθε μια από τις ταινίες του αρχείου test_ratings.csv να επιστρέφεται 1 ή 0 αν η ταινία θα έπαιρνε βαθμό μεγαλύτερο του 3 ή όχι, δηλαδή αν θα έπρεπε να την είχαμε προτείνει ή όχι.
#
# Στην συνέχεια, σε συνδιασμό με τις πραγματικές απαντήσεις του χρήστη θα αξιολογήσετε το σύστημά σας χρησιμοποιόντας τις μετρικές: precision, recall, f1 οι οποίες είναι οι πλέον γνωστές μετρικές και ευρέως χρησιμοποιούμενες τεχνικές για την επίβλεψη-μέτρηση απόδοσης ανάλογων συστημάτων.
#
# 1. Precision: Δείχνει πόσο ακριβές είναι το σύστημα. Υπολογίζει πόσα από τα στιγμιότυπα τα όποια προβλέψαμε ότι ανήκουν σε μια κλάση όντως ανήκουν σε αυτή. Η μετρική αυτή μας δίνει μια εικόνα σχετικά με τον αριθμό των ταινίων που προβλέψαμε ως προτεινόμενες ενώ δεν θα έπρεπε.
#
# 2. Recall: Υπολογίζει πόσα από τα στιγμιότυπα που ανήκουν σε μια κλάση (π.χ. προτεινόμενες ταινίες) προβλέφθηκαν σωστά.
#
# 3. F1: Είναι ένας μέσος μεταξύ των παραπάνω δυο μετρικών, έτσι ώστε να διατηρείται μια ισορροπία μεταξύ τους. Υπολογίζεται από την παρακάτω σχέση:
#
# $$F_1=2\frac{Precision\times{Recall}}{Precision+Recall}$$
#
# Οι παραπάνω συναρτήσεις παρέχονται από την βιβλιοθήκη scikit-learn.
#
# Τέλος για την καλύτερη επίβλεψη του συστήματος σας μπορείτε να εκπαιδεύσετε  τον recommender σας με ένα υποσύνολο ταινίων από ελάχιστες, λίγες μέχρι και πολλές (π.χ. 3, 5, 10, 50, ...) για να μελετήσετε κατά πόσο σας βοηθούν οι επιπλέον αξιολογήσεις κάθε φορά (δηλαδή κατά πόσο βελτιώνονται οι παραπάνω μετρικές στο test set).
#
# Έτσι π.χ. μπορείτε να εντοπίσετε περιπτώσεις όπως για παράδειγμα ότι με έναν recommender μπορεί να μην επιτυγχάνετε πολύ υψηλό σκορ όσο με άλλους, αλλά το βέλτιστο σκόρ σας επιτυγχάνεται πολύ γρηγόρα π.χ. με μόνο 10 ταινίες αντί 100. Έτσι για παράδειγμα αν ο αλγόριθμος τα πηγαίνει πολύ καλά για τρεις ταινίες και στη συνέχεια το σκορ βελτιώνεται ελάχιστα τότε αυτός ενδείκνυται για ένα σύστημα συστάσεων για νέους χρήστες όπου δεδομένου λίγων ταινιών ο αλγόριθμος είναι σε θέση να το να προτείνει καλές συστάσεις. Ενώ αν η καλύτερη απόδοση του αλγορίθμου σας είναι βέλτιστη με περισσότερες ταινίες π.χ. 50 τότε αυτός ο αλγόριθμος συστάσεων ενδείκνυται για παλιούς χρήστες με πολλές αξιολόγησεις.

# %% [markdown]
# ---
# ## Κατασκευή Περιβάλλοντος Εργασίας
# ---

# %% [markdown]
# ### Διάβασμα Αρχείων στο Colab (Μόνο για το Colab)
# Αν η υλοποίηση γίνει στο google colab τότε μπορεί να χρησιμοποιηθεί το google drive ως file system. Για να γίνει Mount το google drive τρέχουμε τον παρακάτω κώδικα και κλικάρουμε στο link που θα μας εμφανιστεί.
#
# ```
# from google.colab import drive
# drive.mount('/content/drive')
# import os
# os.listdir('/content/drive/My Drive')
# ```
# Έπειτα στην σελίδα που άνοιξε επιλέγουμε το mail μας και στο επόμενο παράθυρο που θα μας ανοίξει πατάμε Να επιτρέπεται. Στην συνέχεια αντιγράφουμε τον κωδικό που θα μας βγάλει και τον κάνουμε paste στο Input που έχει ανοίξει στο colab. Έτσι πλέον αν έχουμε ανεβάσει ένα αρχείο στο google drive μπορούμε να το βρούμε στην θέση:
#
# ```
# movies_filename = '/content/drive/My Drive/' + movies_metadata.csv
# ```
# Μπορούμε πλέον κανονικά να δουλέψουμε φτιάχνοντας φακέλους ή αρχεία και γενικότερα κάνοντας οτιδήποτε θα κάναμε αν ήμασταν τοπικά.
#
# ### Prolog μέσω Python
#
# Το πακέτο που θα χρησιμοποιηθεί για την επικοινωνία Python και Prolog είναι το pyswip (https://pypi.org/project/pyswip/). Για να δουλέψει το Pyswip  χρειάζεται να υπάρχει το Swi-Prolog το όποιο αν δουλεύουμε τοπικά πρέπει να το εγκαταστήσουμε, ακολουθώντας αντίστοιχες οδηγίες στην σελίδα του εργαλείου. Για να γίνει του Swi-Prolog η εγκατάσταση στο Google Colab πρέπει να τρέξουμε τον παρακάτω κώδικα:
#
# ```
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog/stable
# !sudo apt-get update
# !sudo apt-get install swi-prolog
# ```
# Σε κάποιο σημείο της εκτέλεσης εμφανίζεται ένα μήνυμα ότι πρέπει να πατήσουμε enter σε ένα input για να συνεχίσει η διαδικασία. Έπειτα από αυτό η εκτέλεση θα συνεχίσει χωρίς κάποιο πρόβλημα.
#
# Τέλος πρέπει να εγκαταστήσουμε το pyswip (**όπου και να δουλεύουμε**) όπως παρακάτω:
#
# ```
# !pip isntall pyswip
# ```

# %% [markdown]
# ---
# # Κώδικας για κατασκευή περιβάλλοντος εργασίας
#
# ## Μόνο για Google Colab
#
# Κώδικας για να γίνει Mount to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
path="" # με ευκόλο τρόπο μπορείτε να αλλάξετε το path που είναι αποθηκευμένα τα αρχεία σας
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_21900/2048306587.py in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#       3
#       4 import os
#       5 path="" # με ευκόλο τρόπο μπορείτε να αλλάξετε το path που είναι αποθηκευμένα τα αρχεία σας
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
# %%capture
#install swi-prolog
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog
# !sudo apt-get update
# !sudo apt-get install swi-prolog
#install pyswip
# !pip install pyswip

# %% [markdown]
# # **Μέρος 1: Μελέτη των Metadata, Δημιουργία κόσμου και των βασικών queries.**

# %% [markdown]
# ### Μέρος 1Α - Κατασκευή βάσης γνώσης

# %%
import pandas as pd
from pyswip import Prolog

# %% [markdown]
# #### Διαβάζω το dataset

# %%
# Η βιβλιοθήκη pandas είναι χρήσιμη για την εργασία με τέτοια δεδομένα
import pandas as pd 
# Διάβασμα του αρχείου 'movie_metadata.csv' 
path=""
data = pd.read_csv(path + "movies_metadata.csv") 
#Στο csv υπαρχούν κελία με nan τιμές
#Στις θέσεις αυτές βάζουμε 'UNK' πράγμα που  κάνουμε με την παρακάτω συνάρτηση
data.fillna("UNK", inplace=True)
# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#    Unnamed: 0     budget  ...      actor_2_name       actor_3_name
# 0           0  237000000  ...  Sigourney Weaver       Stephen Lang
# 1           1  300000000  ...   Keira Knightley  Stellan Skarsgård
# 2           2  245000000  ...       Léa Seydoux      Ralph Fiennes
# 3           3  250000000  ...       Gary Oldman      Anne Hathaway
# 4           4  260000000  ...   Samantha Morton       Willem Dafoe
#
# [5 rows x 27 columns]

# %%
def clean_text(text):
    text = text.replace(u'\xa0', u'')
    text = text.replace(u"'", u'')
    return text

# %% [markdown]
# #### Διασχίζω το dataset και παράγω τα literals της βάσης γνώσης

# %%
import json
from copy import copy

def parse_object_str_to_json(st):
    '''
    * used to parse object-like string as json
    * replace --in the middle of strings-- (") with (\")
    * use the json.loads() method
    '''
    s = copy(st)
    s = s.replace("'", '"')
    for i in range(len(s)):
        if s[i]=='"':
            if s[i-1]=="\\":
                continue
            elif s[i-1]=='{' or s[i+1]=='}':
                pass
            elif s[i+1]==',' or s[i+1]==':':
                pass
            elif s[i-2:i]==', ' or s[i-2:i]==': ':
                pass
            else:
                s = s[:i] + '\\' + s[i:]
    s = json.loads(s)
    return s


prolog = Prolog()

# list with all the KB literals
literals = []

for row in data.itertuples(index=True, name='Pandas'):
    movie_title = clean_text(getattr(row, 'movie_title'))
    
    # parse the single-valued attributes (for example genre is not a single-valued attribute, as it contains a list)
    singles = [
        'budget', 'homepage', 'language', 'original_title',
        'overview', 'popularity', 'release_date', 'gross', 'duration',
        'status', 'tagline', 'vote_average',
        'num_voted_users', 'title_year', 'country', 'director_name',
        'actor_1_name', 'actor_2_name', 'actor_3_name',
    ]    
    for attr in singles:
        val = getattr(row, attr)
        if isinstance(val, str):
            if '"' in val:
                val = val.replace('"', '\\"')
        literals.append(f"{attr}(\"{movie_title}\", \"{val}\")")
        
    # parse the multi-valued attributes
    for genre in getattr(row, 'genres').split("|"):
        genre = genre.replace('"', '\\"')
        literals.append(f"genre(\"{movie_title}\",\"{genre}\")")
    
    
    for plot_keyword in getattr(row, 'plot_keywords').split("|"):
        plot_keyword = plot_keyword.replace('"', '\\"')
        literals.append(f"plot_keyword(\"{movie_title}\",\"{plot_keyword}\")")

    companies = getattr(row, 'production_companies')
    companies = parse_object_str_to_json(companies)
    for company in companies:
        literals.append(f"production_company(\"{movie_title}\", \"{company['id']}\")")
    
    countries = getattr(row, 'production_countries')
    countries = parse_object_str_to_json(countries)
    for country in countries:
        literals.append(f"production_country(\"{movie_title}\", \"{country['iso_3166_1']}\")")
    
    languages = getattr(row, 'spoken_languages')
    languages = parse_object_str_to_json(languages)
    for lang in languages:
        literals.append(f"spoken_languages(\"{movie_title}\", \"{lang['iso_639_1']}\")")

# sort the literals and write them in a swipl file
literals.sort()
f = open("knowledge_base.pl", "w+")
for literal in literals:
    f.write(literal+'.\n')

# %% [markdown]
# ### Μέρος 1Β - κατασκευή ερωτημάτων

# %%
# I have written the queries in the queries.pl file
prolog.consult('knowledge_base.pl')
prolog.consult('queries.pl')

# %% [markdown]
# # **2ο Μέρος: Recommendation System με βάση μόνο τα χαρακτηριστικά των ταινιών.**

# %% [markdown]
# Στο σημείο αυτό με βάση τους κανόνες που κατασκευάστηκαν στο Μέρος 1 θα κατασκευαστούν κατηγορήματα για την ομοιότητα ταινιών. Παρακάτω δίνεται ένα μικρό παράδειγμα ενός κανόνα και πώς αυτός θα μπορούσε να γραφτεί μέσω του Pyswip. Επίσης όπως αναφέρεται και σε σχόλιο παραπάνω θα μπορεί να γραφτεί και μια βάση δεδομένων με τους κανόνες και να γίνει απευθείας consult.
#
# Στο παρακάτω παράδειγμα το 5 και το 4 εκφράζουν την ομοιότητα των ταινιών π.χ. οι ταινίες που παράγονται μέσω του find_similar_5 είναι πιο όμοιες από αυτές που παράγονται μέσω του find_similar_4.

# %%
# similarity checking queries are written in db.pl file
prolog.consult("db.pl")

# %% [markdown]
# * Δοκιμάζω το πιο "αυστηρό" query για την ταινία `Pirates of the Caribbean: On Stranger Tides`

# %%
# testing the most similar movies to the "Avatar" movie
q = prolog.query("find_sim_5(\"Pirates of the Caribbean: On Stranger Tides\", Y)")
s = set()
for soln in q:
    m = soln['Y'] 
    if m not in s:
        s.add(soln['Y'].decode("utf-8"))
print(s)
# Out:
# {'Avatar', 'Pirates of the Caribbean: The Curse of the Black Pearl', 'Pirates of the Caribbean: At Worlds End', 'The Fog', 'Hercules', 'The Bounty', 'Pirates of the Caribbean: Dead Mans Chest'}

# %% [markdown]
# * Παρατηρώ ότι τα αποτελέσματα φαίνονται πράγματι να είναι σχετικά

# %% [markdown]
# * Υλοποιώ και τις υπόλοιπες συναρτήσεις που χρησιμοποιούν τα αντίστοιχα find_sim{index} queries της prolog, και βρίσκουν όμοιες ταινίες με διαφορετικά επίπεδα ομοιότητας.
# * Προσπαθώ οι προτάσεις να ξεκινούν από μεγάλο αριθμό για την find_sim_1, να μειώνονται όσο οι συναρτήσεις εξειδικεύονται, και να φτάνουν περίπου σε μονοψήφιο αριθμό στον find_sim_5.

# %%
prolog.consult('queries.pl')
prolog.consult("db.pl")

def recommender_body(method, movie, query=None):
    s = set()
    if not query:
        query = f"{method}(\"{movie}\",M)"
        # print(query)
    q = prolog.query(query)
    for soln in q:
        m = soln['M'] 
        if m not in s:
            s.add(soln['M'].decode("utf-8"))
    q.close()
    answers = s
    return answers

def find_sim_1(movie):
    return recommender_body('find_sim_1', movie)

def find_sim_2(movie):
    return recommender_body('find_sim_2', movie)

def find_sim_3(movie):
    return recommender_body('find_sim_3', movie)

def find_sim_4(movie):
    return recommender_body('find_sim_4', movie)

def find_sim_5(movie):
    return recommender_body('find_sim_5', movie)

recommenders = [
    find_sim_1,
    find_sim_2,
    find_sim_3,
    find_sim_4,
    find_sim_5,
]

# %% [markdown]
# * Διαλέγω τυχαία τέσσερις ταινίες από το dataset και βρίσκω τις όμοιες ταινίες τους χρησιμοποιώντας τις προηγούμενες συναρτήσεις.
# * Για κάθε ταινία εκτυπώνω το πλήθος των ταινιών που πρότεινε η κάθε μία συνάρτηση.
#     * Για τις πιο εξειδικευμένες συναρτήσεις (find_sim_3, find_sim_4, find_sim_5) εκτυπώνω και ποιες ήταν οι
#       προτάσεις, αφού αυτές είναι πιο λίγες και έτσι μπορώ να έχω ένα δείγμα της ποιότητας του συστήματος.

# %%
# some tests...
titles = [
    "Avatar",
    "How to Train Your Dragon",
    "Pirates of the Caribbean: At Worlds End",
    "Batman v Superman: Dawn of Justice",
    "Batman",
]

for title in titles:
    recs = [rec(title) for rec in recommenders]
    print('-->', title)
    print("Number of suggestions:")
    print('find_sim_1\t| find_sim_2\t| find_sim_3\t| find_sim_4\t| find_sim_5\t|')
    print('-----------------------------------------')
    for rec in recs:
        print(len(rec), end= '\t\t| ')
    print()
    for rec in [('find_sim_3', recs[2]), ('find_sim_4', recs[3]), ('find_sim_5', recs[4])]:
        print()
        print(f"{rec[0]}:")
        print(rec[1])
    print('-----------------------------------'*3)
    print()
# Out:
# --> Avatar
# Number of suggestions:
# find_sim_1	| find_sim_2	| find_sim_3	| find_sim_4	| find_sim_5	|
# -----------------------------------------
# 821		| 136		| 54		| 34		| 10		|
#
# find_sim_3:
# {'Across the Universe', 'Treasure Planet', 'Star Trek Into Darkness', 'Gravity', 'Captain America: The Winter Soldier', 'Dawn of the Planet of the Apes', 'The Muppet Christmas Carol', 'Hugo', 'Apocalypto', 'The Martian', 'Frequency', 'Moon', 'Platoon', 'The Wild Bunch', 'Avengers: Age of Ultron', 'Big Hero 6', 'Captain America: Civil War', 'The Fifth Element', 'Seven Samurai', 'Interstellar', 'The Empire Strikes Back', 'The Longest Day', 'District 9', 'Metropolis', 'Minority Report', 'Total Recall', 'Alien', 'Source Code', 'Predator', 'The Hunger Games: Catching Fire', 'Frozen', 'Batman Begins', 'Sleeper', 'Ant-Man', 'How to Train Your Dragon 2', 'Children of Men', 'How to Train Your Dragon', 'The Little Prince', 'The Thing', 'Maleficent', '2001: A Space Odyssey', 'The Hobbit: The Battle of the Five Armies', 'Mad Max: Fury Road', 'Solaris', 'Edge of Tomorrow', 'Close Encounters of the Third Kind', 'Batman: The Dark Knight Returns, Part 2', 'The Last Samurai', 'Dances with Wolves', 'Guardians of the Galaxy', 'K-PAX', 'Dark City', 'Aliens', 'Star Trek'}
#
# find_sim_4:
# {'Titan A.E.', 'Independence Day', 'Treasure Planet', 'Star Trek Into Darkness', 'Captain America: The Winter Soldier', 'Terminator Genisys', 'Meet Dave', 'Green Lantern', 'Stargate: The Ark of Truth', 'You Only Live Twice', 'Silent Running', 'The Fifth Element', 'Interstellar', 'Alien', 'Predator', 'The Hitchhikers Guide to the Galaxy', 'Planet 51', 'John Carter', 'Predators', 'Home', 'Planet of the Apes', 'Renaissance', 'Lockout', 'Pirates of the Caribbean: On Stranger Tides', 'Enders Game', 'Edge of Tomorrow', 'Alien³', 'I, Robot', 'Jupiter Ascending', 'Guardians of the Galaxy', 'Battle: Los Angeles', 'Aliens', 'A Monster in Paris', 'Jimmy Neutron: Boy Genius'}
#
# find_sim_5:
# {'Pirates of the Caribbean: On Stranger Tides', 'Star Trek Into Darkness', 'The Fifth Element', 'Alien', 'Galaxina', 'Alien³', 'Guardians of the Galaxy', 'John Carter', 'Predators', 'Aliens'}
# ---------------------------------------------------------------------------------------------------------
#
# --> How to Train Your Dragon
# Number of suggestions:
# find_sim_1	| find_sim_2	| find_sim_3	| find_sim_4	| find_sim_5	|
# -----------------------------------------
# 472		| 101		| 35		| 16		| 8		|
#
# find_sim_3:
# {'Reign of Fire', 'Hachi: A Dogs Tale', 'Bridge to Terabithia', 'Star Trek Into Darkness', 'Mulan', 'Apocalypto', 'George and the Dragon', 'Jurassic Park', 'The Wild Bunch', 'Toy Story 2', 'Gladiator', 'The Last Dragon', 'Toy Story', 'Avatar', 'Pirates of the Caribbean: The Curse of the Black Pearl', 'Crouching Tiger, Hidden Dragon', 'Harry Potter and the Prisoner of Azkaban', 'Dear Frankie', 'Pirates of the Caribbean: Dead Mans Chest', 'Ernest & Celestine', 'The Iron Giant', 'The Lego Movie', 'The First Great Train Robbery', 'The Black Stallion', 'Howls Moving Castle', 'Anne of Green Gables', 'How to Train Your Dragon 2', 'Petes Dragon', 'Dungeons & Dragons: Wrath of the Dragon God', 'The Hobbit: The Battle of the Five Armies', 'Princess Mononoke', 'The Hobbit: The Desolation of Smaug', 'The Incredibles', 'The Mummy: Tomb of the Dragon Emperor', 'The Life Aquatic with Steve Zissou'}
#
# find_sim_4:
# {'Shrek the Third', 'Beowulf', 'Reign of Fire', 'The Hobbit: The Battle of the Five Armies', 'Pirates of the Caribbean: On Stranger Tides', 'Shipwrecked', 'Savva. Heart of the Warrior', 'Mulan', 'Crouching Tiger, Hidden Dragon', 'The Sorcerers Apprentice', 'George and the Dragon', 'How to Train Your Dragon 2', 'Petes Dragon', 'Kung Fu Panda 3', 'Dungeons & Dragons: Wrath of the Dragon God', 'Alvin and the Chipmunks'}
#
# find_sim_5:
# {'Shrek the Third', 'Reign of Fire', 'DragonHeart', 'The Mummy: Tomb of the Dragon Emperor', 'How to Train Your Dragon 2', 'Platoon', 'Petes Dragon', 'Dungeons & Dragons: Wrath of the Dragon God'}
# ---------------------------------------------------------------------------------------------------------
#
# --> Pirates of the Caribbean: At Worlds End
# Number of suggestions:
# find_sim_1	| find_sim_2	| find_sim_3	| find_sim_4	| find_sim_5	|
# -----------------------------------------
# 632		| 116		| 42		| 15		| 8		|
#
# find_sim_3:
# {'The Pirates! In an Adventure with Scientists!', 'Captain America: The Winter Soldier', 'Captain Phillips', 'The Avengers', 'Life of Pi', 'Jurassic Park', 'Big Hero 6', 'Captain America: Civil War', 'Iron Man', 'Beetlejuice', 'The Worlds End', 'Pirates of the Caribbean: The Curse of the Black Pearl', 'Harry Potter and the Prisoner of Azkaban', 'The Princess Bride', 'The Abyss', 'Enter the Void', 'VeggieTales: The Pirates Who Dont Do Anything', 'Pirates of the Caribbean: Dead Mans Chest', 'Harry Potter and the Chamber of Secrets', 'X-Men: Days of Future Past', '22 Jump Street', 'Aladdin', 'Wreck-It Ralph', 'The Muppet Movie', 'Kill Bill: Vol. 2', 'The Hunger Games: Catching Fire', 'Frozen', 'Big Fish', 'Ant-Man', 'How to Train Your Dragon', 'Scott Pilgrim vs. the World', 'The Lost World: Jurassic Park', 'Cast Away', 'Pirates of the Caribbean: On Stranger Tides', 'War of the Worlds', 'Deadpool', 'The Book of Life', 'Jaws', 'The Life Aquatic with Steve Zissou', 'Guardians of the Galaxy', 'The Ice Pirates', 'Cirque du Soleil: Worlds Away'}
#
# find_sim_4:
# {'Shrek the Third', 'The Lost World: Jurassic Park', 'The Pirates! In an Adventure with Scientists!', 'Pirates of the Caribbean: On Stranger Tides', 'Cutthroat Island', 'Pirates of the Caribbean: The Curse of the Black Pearl', 'In the Heart of the Sea', 'Life of Pi', 'Harry Potter and the Prisoner of Azkaban', 'King Kong', 'VeggieTales: The Pirates Who Dont Do Anything', 'Pirates of the Caribbean: Dead Mans Chest', 'The Man with the Golden Gun', 'Nims Island', 'Poseidon'}
#
# find_sim_5:
# {'Shrek the Third', 'The Lost World: Jurassic Park', 'Cutthroat Island', 'Pirates of the Caribbean: On Stranger Tides', 'Pirates of the Caribbean: The Curse of the Black Pearl', 'In the Heart of the Sea', 'Pirates of the Caribbean: Dead Mans Chest', 'Nims Island'}
# ---------------------------------------------------------------------------------------------------------
#
# --> Batman v Superman: Dawn of Justice
# Number of suggestions:
# find_sim_1	| find_sim_2	| find_sim_3	| find_sim_4	| find_sim_5	|
# -----------------------------------------
# 625		| 120		| 38		| 42		| 18		|
#
# find_sim_3:
# {'Superman Returns', 'V for Vendetta', 'Captain America: The Winter Soldier', 'Superman', 'The Avengers', 'Avengers: Age of Ultron', 'Big Hero 6', 'Captain America: Civil War', 'Kick-Ass', 'The Equalizer', 'Superman IV: The Quest for Peace', 'Iron Man', 'Batman Returns', 'Oldboy', 'Superman III', 'The Dark Knight', 'Batman & Robin', 'Kill Bill: Vol. 1', 'Man of Steel', 'Sin City', 'X-Men: Days of Future Past', 'X-Men: First Class', 'The Revenant', 'Ice Age: Dawn of the Dinosaurs', 'The Lego Movie', 'Batman Begins', 'Superman II', 'Ant-Man', 'Batman Forever', 'Fantastic Mr. Fox', 'Furious 7', 'Point Blank', 'Batman', 'Deadpool', 'The Incredibles', 'Batman: The Dark Knight Returns, Part 2', 'Watchmen', 'The Dark Knight Rises'}
#
# find_sim_4:
# {'Superman Returns', 'The Amazing Spider-Man', 'Captain America: The Winter Soldier', 'Superman', 'The Shadow', 'The Avengers', 'Avengers: Age of Ultron', 'Captain America: Civil War', 'Green Lantern', 'Iron Man 3', 'Superman IV: The Quest for Peace', 'Fantastic Four', 'Fantastic 4: Rise of the Silver Surfer', 'Iron Man', 'Thor', 'Spider-Man 3', 'Batman Returns', 'Suicide Squad', 'Superman III', 'X2', 'Batman & Robin', 'Captain America: The First Avenger', 'Blade: Trinity', 'Man of Steel', 'The Amazing Spider-Man 2', 'Thor: The Dark World', 'X-Men: First Class', 'Iron Man 2', 'Dragonball Evolution', 'Batman Begins', 'X-Men', 'Superman II', 'Ant-Man', 'Batman Forever', 'Now You See Me 2', 'Teenage Mutant Ninja Turtles', 'Mystery Men', 'Batman', 'Deadpool', 'The Incredible Hulk', 'Watchmen', 'The Wolverine'}
#
# find_sim_5:
# {'Superman IV: The Quest for Peace', 'Superman Returns', 'Iron Man 2', 'Watchmen', 'Batman', 'Batman Returns', 'Suicide Squad', 'Superman III', 'The Dark Knight', 'Superman', 'Batman Begins', 'Superman II', 'Batman & Robin', 'Batman Forever', 'Man of Steel', 'Green Lantern', 'The Dark Knight Rises', 'Teenage Mutant Ninja Turtles'}
# ---------------------------------------------------------------------------------------------------------
#
# --> Batman
# Number of suggestions:
# find_sim_1	| find_sim_2	| find_sim_3	| find_sim_4	| find_sim_5	|
# -----------------------------------------
# 1593		| 259		| 36		| 24		| 15		|
#
# find_sim_3:
# {'The Secret Life of Walter Mitty', 'Captain America: The Winter Soldier', 'The NeverEnding Story', 'Frequency', 'The Avengers', 'Avengers: Age of Ultron', 'Kick-Ass', 'Captain America: Civil War', 'Taken', 'Iron Man', 'Batman Returns', 'The Dark Knight', 'Birdman', 'Interstellar', 'Alice in Wonderland', 'X-Men: First Class', 'Gangs of New York', 'Das Boot', 'Total Recall', 'The Lego Movie', 'Crimson Tide', 'The Black Stallion', 'Batman Begins', 'Ant-Man', 'How to Train Your Dragon 2', 'The Talented Mr. Ripley', 'The Hunt for Red October', '127 Hours', 'Mad Max: Fury Road', 'Touching the Void', 'Deadpool', 'The Incredibles', 'Jaws', 'Batman: The Dark Knight Returns, Part 2', 'Watchmen', 'The Dark Knight Rises'}
#
# find_sim_4:
# {'Superman Returns', 'Defendor', 'Superman', 'Kick-Ass', 'Green Lantern', 'G.I. Joe: Retaliation', 'Deep Blue Sea', 'Superman IV: The Quest for Peace', 'Spider-Man 3', 'Batman Returns', 'Suicide Squad', 'Superman III', 'The Dark Knight', 'Kick-Ass 2', 'Batman & Robin', 'Man of Steel', 'Alice in Wonderland', 'Spider-Man 2', 'Batman Begins', 'Superman II', 'Batman Forever', 'Batman v Superman: Dawn of Justice', 'The Spy Who Loved Me', 'The Dark Knight Rises'}
#
# find_sim_5:
# {'Superman IV: The Quest for Peace', 'Superman Returns', 'Batman Returns', 'Batman v Superman: Dawn of Justice', 'The Dark Knight', 'Superman III', 'Superman', 'Batman Begins', 'Alice in Wonderland', 'Superman II', 'Batman & Robin', 'Batman Forever', 'Man of Steel', 'Green Lantern', 'The Dark Knight Rises'}
# ---------------------------------------------------------------------------------------------------------

# %% [markdown]
# * Παρατηρώ ότι και πάλι τα αποτελέσματα είναι ενθαρρυντικά για την λειτουργία του recommender.
# * Ορίζω και την συνάρτηση simple_recommender, που συνδυάζει τα queries αυτά, και επιστρέφει προτεινόμενες ταινίες, με έναν βαθμό ομοιότητας για την κάθε μία, ώστε να την χρησιμοποιήσω στην συνέχεια της εργαστηριακής άσκησης

# %%
def simple_recommender(movie):
    seen_movies = set()
    result = []

    def find_sim_of_movie(movie, sim_degree):
      nonlocal seen_movies
      nonlocal result
      q = prolog.query(f"find_sim_{sim_degree}(\"{movie}\",M)")
      if q:
        for soln in q:
            m = soln['M'].decode("utf-8")
            if m not in seen_movies:
                seen_movies.add(soln['M'])
                result.append((m, sim_degree))
      q.close()


    find_sim_of_movie(movie, 5)
    find_sim_of_movie(movie, 4)
    find_sim_of_movie(movie, 3)
    find_sim_of_movie(movie, 2)
    find_sim_of_movie(movie, 1)
    
    
    return result

# %% [markdown]
# * Δοκιμάζω την συνάρτηση για την ταινία Avatar:

# %%
simple_recommender("Avatar")
# Out:
# [('Star Trek Into Darkness', 5),
#  ('John Carter', 5),
#  ('Pirates of the Caribbean: On Stranger Tides', 5),
#  ('Predators', 5),
#  ('The Fifth Element', 5),
#  ('Aliens', 5),
#  ('Alien³', 5),
#  ('Galaxina', 5),
#  ('Guardians of the Galaxy', 5),
#  ('Alien', 5),
#  ('Captain America: The Winter Soldier', 4),
#  ('Enders Game', 4),
#  ('Green Lantern', 4),
#  ('Independence Day', 4),
#  ('Jimmy Neutron: Boy Genius', 4),
#  ('John Carter', 4),
#  ('Jupiter Ascending', 4),
#  ('Pirates of the Caribbean: On Stranger Tides', 4),
#  ('Planet of the Apes', 4),
#  ('Predator', 4),
#  ('Predators', 4),
#  ('Star Trek Into Darkness', 4),
#  ('Terminator Genisys', 4),
#  ('The Fifth Element', 4),
#  ('Titan A.E.', 4),
#  ('You Only Live Twice', 4),
#  ('Alien', 4),
#  ('Aliens', 4),
#  ('Alien³', 4),
#  ('Battle: Los Angeles', 4),
#  ('Edge of Tomorrow', 4),
#  ('I, Robot', 4),
#  ('Lockout', 4),
#  ('Renaissance', 4),
#  ('A Monster in Paris', 4),
#  ('Treasure Planet', 4),
#  ('Interstellar', 4),
#  ('Meet Dave', 4),
#  ('Planet 51', 4),
#  ('Silent Running', 4),
#  ('Stargate: The Ark of Truth', 4),
#  ('The Hitchhikers Guide to the Galaxy', 4),
#  ('Home', 4),
#  ('Guardians of the Galaxy', 4),
#  ('Alien', 3),
#  ('Aliens', 3),
#  ('Ant-Man', 3),
#  ('Apocalypto', 3),
#  ('Avengers: Age of Ultron', 3),
#  ('Batman Begins', 3),
#  ('Batman: The Dark Knight Returns, Part 2', 3),
#  ('Big Hero 6', 3),
#  ('Captain America: Civil War', 3),
#  ('Captain America: The Winter Soldier', 3),
#  ('Children of Men', 3),
#  ('Dawn of the Planet of the Apes', 3),
#  ('Edge of Tomorrow', 3),
#  ('Guardians of the Galaxy', 3),
#  ('How to Train Your Dragon 2', 3),
#  ('Mad Max: Fury Road', 3),
#  ('Maleficent', 3),
#  ('Minority Report', 3),
#  ('Platoon', 3),
#  ('Predator', 3),
#  ('Seven Samurai', 3),
#  ('Star Trek Into Darkness', 3),
#  ('Star Trek', 3),
#  ('The Empire Strikes Back', 3),
#  ('The Fifth Element', 3),
#  ('The Hobbit: The Battle of the Five Armies', 3),
#  ('The Hunger Games: Catching Fire', 3),
#  ('The Last Samurai', 3),
#  ('The Longest Day', 3),
#  ('Total Recall', 3),
#  ('2001: A Space Odyssey', 3),
#  ('Across the Universe', 3),
#  ('Dances with Wolves', 3),
#  ('Frozen', 3),
#  ('How to Train Your Dragon', 3),
#  ('Hugo', 3),
#  ('Interstellar', 3),
#  ('Solaris', 3),
#  ('The Little Prince', 3),
#  ('The Martian', 3),
#  ('The Wild Bunch', 3),
#  ('Treasure Planet', 3),
#  ('The Muppet Christmas Carol', 3),
#  ('Close Encounters of the Third Kind', 3),
#  ('Dark City', 3),
#  ('District 9', 3),
#  ('Frequency', 3),
#  ('Gravity', 3),
#  ('K-PAX', 3),
#  ('Metropolis', 3),
#  ('Moon', 3),
#  ('Sleeper', 3),
#  ('Source Code', 3),
#  ('The Thing', 3),
#  ('Predator', 2),
#  ('Star Trek Into Darkness', 2),
#  ('Captain America: The Winter Soldier', 2),
#  ('The Fifth Element', 2),
#  ('Edge of Tomorrow', 2),
#  ('Aliens', 2),
#  ('Alien', 2),
#  ('Treasure Planet', 2),
#  ('Platoon', 2),
#  ('The Thin Red Line', 2),
#  ('Moon', 2),
#  ('Interstellar', 2),
#  ('300', 2),
#  ('Ant-Man', 2),
#  ('Apocalypto', 2),
#  ('Avengers: Age of Ultron', 2),
#  ('Baahubali: The Beginning', 2),
#  ('Batman', 2),
#  ('Big Hero 6', 2),
#  ('Big Trouble in Little China', 2),
#  ('Bloody Sunday', 2),
#  ('Captain America: Civil War', 2),
#  ('Casino Royale', 2),
#  ('Crossroads', 2),
#  ('Crouching Tiger, Hidden Dragon', 2),
#  ('Das Boot', 2),
#  ('Deadpool', 2),
#  ('First Blood', 2),
#  ('Gladiator', 2),
#  ('Goldfinger', 2),
#  ('Guardians of the Galaxy', 2),
#  ('Hero', 2),
#  ('House of Flying Daggers', 2),
#  ('How to Train Your Dragon 2', 2),
#  ('Inception', 2),
#  ('Indiana Jones and the Last Crusade', 2),
#  ('Indiana Jones and the Temple of Doom', 2),
#  ('Iron Man', 2),
#  ('Its a Mad, Mad, Mad, Mad World', 2),
#  ('Letters from Iwo Jima', 2),
#  ('Life of Pi', 2),
#  ('Mad Max 2: The Road Warrior', 2),
#  ('Mad Max: Fury Road', 2),
#  ('Maleficent', 2),
#  ('Mission: Impossible - Rogue Nation', 2),
#  ('O Brother, Where Art Thou?', 2),
#  ('Pirates of the Caribbean: Dead Mans Chest', 2),
#  ('Pirates of the Caribbean: The Curse of the Black Pearl', 2),
#  ('Raiders of the Lost Ark', 2),
#  ('Red Cliff', 2),
#  ('Return of the Jedi', 2),
#  ('Scott Pilgrim vs. the World', 2),
#  ('Serenity', 2),
#  ('Sherlock Holmes', 2),
#  ('Sherlock Holmes: A Game of Shadows', 2),
#  ('Silver Medalist', 2),
#  ('Sorcerer', 2),
#  ('Star Trek II: The Wrath of Khan', 2),
#  ('Star Trek', 2),
#  ('Star Trek: First Contact', 2),
#  ('Star Wars', 2),
#  ('Star Wars: Clone Wars: Volume 1', 2),
#  ('Star Wars: Episode III - Revenge of the Sith', 2),
#  ('Tae Guk Gi: The Brotherhood of War', 2),
#  ('The Abyss', 2),
#  ('The Avengers', 2),
#  ('The Count of Monte Cristo', 2),
#  ('The Empire Strikes Back', 2),
#  ('The Fugitive', 2),
#  ('The Good, The Bad, The Weird', 2),
#  ('The Hobbit: An Unexpected Journey', 2),
#  ('The Hobbit: The Battle of the Five Armies', 2),
#  ('The Hunger Games: Catching Fire', 2),
#  ('The Hunt for Red October', 2),
#  ('The Incredibles', 2),
#  ('The Last of the Mohicans', 2),
#  ('The Lord of the Rings: The Fellowship of the Ring', 2),
#  ('The Lord of the Rings: The Return of the King', 2),
#  ('The Lord of the Rings: The Two Towers', 2),
#  ('The Losers', 2),
#  ('The Man from U.N.C.L.E.', 2),
#  ('The Proposition', 2),
#  ('Tombstone', 2),
#  ('Total Recall', 2),
#  ('Touching the Void', 2),
#  ('X-Men: Days of Future Past', 2),
#  ('X-Men: First Class', 2),
#  ('Kung Fu Hustle', 2),
#  ('The Crow', 2),
#  ('V for Vendetta', 2),
#  ('Children of Men', 2),
#  ('Dawn of the Planet of the Apes', 2),
#  ('Minority Report', 2),
#  ('Rise of the Planet of the Apes', 2),
#  ('Terminator 2: Judgment Day', 2),
#  ('The Matrix', 2),
#  ('The Maze Runner', 2),
#  ('The Terminator', 2),
#  ('They Live', 2),
#  ('Watchmen', 2),
#  ('Aladdin', 2),
#  ('Big Fish', 2),
#  ('E.T. the Extra-Terrestrial', 2),
#  ('Harry Potter and the Chamber of Secrets', 2),
#  ('Harry Potter and the Goblet of Fire', 2),
#  ('Harry Potter and the Half-Blood Prince', 2),
#  ('Harry Potter and the Order of the Phoenix', 2),
#  ('Harry Potter and the Philosophers Stone', 2),
#  ('Harry Potter and the Prisoner of Azkaban', 2),
#  ('How to Train Your Dragon', 2),
#  ('Howls Moving Castle', 2),
#  ('Monty Python and the Holy Grail', 2),
#  ('Princess Mononoke', 2),
#  ('Shrek', 2),
#  ('Spirited Away', 2),
#  ('Stardust', 2),
#  ('The Book of Life', 2),
#  ('The Emperors New Groove', 2),
#  ('The Hobbit: The Desolation of Smaug', 2),
#  ('The Iron Giant', 2),
#  ('The Lego Movie', 2),
#  ('The Little Prince', 2),
#  ('The NeverEnding Story', 2),
#  ('The Princess Bride', 2),
#  ('The Secret Life of Walter Mitty', 2),
#  ('The Wizard of Oz', 2),
#  ('2001: A Space Odyssey', 2),
#  ('Back to the Future Part II', 2),
#  ('Back to the Future Part III', 2),
#  ('Back to the Future', 2),
#  ('Jurassic Park', 2),
#  ('Solaris', 2),
#  ('The Martian', 2),
#  ('Eraserhead', 2),
#  ('Somewhere in Time', 2),
#  ('The Visitors', 2),
#  ('Chicken Little', 1),
#  ('Green Lantern', 1),
#  ('John Carter', 1),
#  ('Predator', 1),
#  ('Star Trek Into Darkness', 1),
#  ('Pirates of the Caribbean: On Stranger Tides', 1),
#  ('A Monster in Paris', 1),
#  ('Captain America: The Winter Soldier', 1),
#  ('I, Robot', 1),
#  ('Terminator Genisys', 1),
#  ('Jupiter Ascending', 1),
#  ('Predators', 1),
#  ('Planet of the Apes', 1),
#  ('Planet 51', 1),
#  ('Battle: Los Angeles', 1),
#  ('Independence Day', 1),
#  ('Jimmy Neutron: Boy Genius', 1),
#  ('Repo Man', 1),
#  ('The Fifth Element', 1),
#  ('Edge of Tomorrow', 1),
#  ('Aliens', 1),
#  ('Alien³', 1),
#  ('Galaxina', 1),
#  ('Mission to Mars', 1),
#  ('Stargate: The Ark of Truth', 1),
#  ('The Hitchhikers Guide to the Galaxy', 1),
#  ('Alien', 1),
#  ('Home', 1),
#  ('Meet Dave', 1),
#  ('Titan A.E.', 1),
#  ('Treasure Planet', 1),
#  ('Platoon', 1),
#  ('The Four Feathers', 1),
#  ('The Thin Red Line', 1),
#  ('We Were Soldiers', 1),
#  ('Renaissance', 1),
#  ('Pocahontas', 1),
#  ('The Time Travelers Wife', 1),
#  ('Jason X', 1),
#  ('Lockout', 1),
#  ('Moon', 1),
#  ('Enders Game', 1),
#  ('Cypher', 1),
#  ('You Only Live Twice', 1),
#  ('Cargo', 1),
#  ('Interstellar', 1),
#  ('Silent Running', 1),
#  ('The Astronauts Wife', 1),
#  ('12 Rounds', 1),
#  ('16 Blocks', 1),
#  ('1911', 1),
#  ('2012', 1),
#  ('3 Ninjas Kick Back', 1),
#  ('30 Minutes or Less', 1),
#  ('300', 1),
#  ('3000 Miles to Graceland', 1),
#  ('47 Ronin', 1),
#  ('9', 1),
#  ('A Knights Tale', 1),
#  ('A Lonely Place to Die', 1),
#  ('A Sound of Thunder', 1),
#  ('A View to a Kill', 1),
#  ('AVP: Alien vs. Predator', 1),
#  ('Action Jackson', 1),
#  ('After Earth', 1),
#  ('Airborne', 1),
#  ('Alexander', 1),
#  ('Alive', 1),
#  ('All About the Benjamins', 1),
#  ('All Is Lost', 1),
#  ('American Ninja 2: The Confrontation', 1),
#  ('Anacondas: The Hunt for the Blood Orchid', 1),
#  ('Ant-Man', 1),
#  ('Apocalypto', 1),
#  ('Armageddon', 1),
#  ('Arn: The Knight Templar', 1),
#  ('Around the World in 80 Days', 1),
#  ('Assassins', 1),
#  ('Avengers: Age of Ultron', 1),
#  ('Baahubali: The Beginning', 1),
#  ('Babylon A.D.', 1),
#  ('Babys Day Out', 1),
#  ('Bad Boys II', 1),
#  ('Bad Company', 1),
#  ('Ballistic: Ecks vs. Sever', 1),
#  ('Batman v Superman: Dawn of Justice', 1),
#  ('Batman', 1),
#  ('Battleship', 1),
#  ('Beastmaster 2: Through the Portal of Time', 1),
#  ('Beowulf', 1),
#  ('Big Hero 6', 1),
#  ('Big Trouble in Little China', 1),
#  ('Blackthorn', 1),
#  ('Blade: Trinity', 1),
#  ('BloodRayne', 1),
#  ('Bloody Sunday', 1),
#  ('Brave', 1),
#  ('Broken Arrow', 1),
#  ('Captain America: Civil War', 1),
#  ('Captain America: The First Avenger', 1),
#  ('Caravans', 1),
#  ('Casino Royale', 1),
#  ('Catch That Kid', 1),
#  ('Cellular', 1),
#  ('Centurion', 1),
#  ('Chain of Command', 1),
#  ('Changing Lanes', 1),
#  ('Charlies Angels', 1),
#  ('Charlies Angels: Full Throttle', 1),
#  ('Cirque du Freak: The Vampires Assistant', 1),
#  ('Clash of the Titans', 1),
#  ('Cliffhanger', 1),
#  ('Commando', 1),
#  ('Conan the Barbarian', 1),
#  ('Conan the Destroyer', 1),
#  ('Congo', 1),
#  ('Cotton Comes to Harlem', 1),
#  ('Crossover', 1),
#  ('Crossroads', 1),
#  ('Crouching Tiger, Hidden Dragon', 1),
#  ('Cutthroat Island', 1),
#  ('DOA: Dead or Alive', 1),
#  ('Damnation Alley', 1),
#  ('Dantes Peak', 1),
#  ('Das Boot', 1),
#  ('Daylight', 1),
#  ('Deadpool', 1),
#  ('Deep Rising', 1),
#  ('Diamonds Are Forever', 1),
#  ('Dick Tracy', 1),
#  ('Die Another Day', 1),
#  ('Divergent', 1),
#  ('Doom', 1),
#  ('Double Take', 1),
#  ('Dr. No', 1),
#  ('Dragon Blade', 1),
#  ('Dragonball Evolution', 1),
#  ('Dune', 1),
#  ('Dungeons & Dragons: Wrath of the Dragon God', 1),
#  ('Epic Movie', 1),
#  ('Eragon', 1),
#  ('Escape from L.A.', 1),
#  ('Executive Decision', 1),
#  ('Exodus: Gods and Kings', 1),
#  ('Extreme Ops', 1),
#  ('Falcon Rising', 1),
#  ('Fantastic 4: Rise of the Silver Surfer', 1),
#  ('Fantastic Four', 1),
#  ('Fighting Tommy Riley', 1),
#  ('Final Fantasy: The Spirits Within', 1),
#  ('Firefox', 1),
#  ('First Blood', 1),
#  ('First Knight', 1),
#  ('Flight of the Intruder', 1),
#  ('Flight of the Phoenix', 1),
#  ('Flyboys', 1),
#  ('For Your Eyes Only', 1),
#  ('Force 10 from Navarone', 1),
#  ('From Russia with Love', 1),
#  ('G-Force', 1),
#  ('G.I. Joe: Retaliation', 1),
#  ('G.I. Joe: The Rise of Cobra', 1),
#  ('Gladiator', 1),
#  ('Godzilla 2000', 1),
#  ('GoldenEye', 1),
#  ('Goldfinger', 1),
#  ('Green Zone', 1),
#  ('Gridiron Gang', 1),
#  ('Guardians of the Galaxy', 1),
#  ('Hanna', 1),
#  ('Hercules', 1),
#  ('Hero', 1),
#  ('Highlander', 1),
#  ('Highway', 1),
#  ('Hollywood Homicide', 1),
#  ('House of Flying Daggers', 1),
#  ('How to Train Your Dragon 2', 1),
#  ('Hudson Hawk', 1),
#  ('I Am Number Four', 1),
#  ('I Spy', 1),
#  ('In the Heart of the Sea', 1),
#  ('In the Name of the King III', 1),
#  ('In the Name of the King: A Dungeon Siege Tale', 1),
#  ('Inception', 1),
#  ('Independence Day: Resurgence', 1),
#  ('Indiana Jones and the Kingdom of the Crystal Skull', 1),
#  ('Indiana Jones and the Last Crusade', 1),
#  ('Indiana Jones and the Temple of Doom', 1),
#  ('Inspector Gadget', 1),
#  ('Into the Blue', 1),
#  ('Iron Man 2', 1),
#  ('Iron Man 3', 1),
#  ('Iron Man', 1),
#  ('Ironclad', 1),
#  ('Ishtar', 1),
#  ('Its a Mad, Mad, Mad, Mad World', 1),
#  ('Johnny English Reborn', 1),
#  ('Johnny English', 1),
#  ('Jonah: A VeggieTales Movie', 1),
#  ('Journey 2: The Mysterious Island', 1),
#  ('Journey to Saturn', 1),
#  ('Journey to the Center of the Earth', 1),
#  ('Jurassic Park III', 1),
#  ('Jurassic World', 1),
#  ('Kick-Ass 2', 1),
#  ('Killer Elite', 1),
#  ('King Kong', 1),
#  ('Kingdom of Heaven', 1),
#  ('Knock Off', 1),
#  ('Knowing', 1),
#  ('Krull', 1),
#  ('Kung Fu Panda 3', 1),
#  ('Lara Croft Tomb Raider: The Cradle of Life', 1),
#  ('Lara Croft: Tomb Raider', 1),
#  ('Last Action Hero', 1),
#  ('Legend of a Rabbit', 1),
#  ('Lethal Weapon 3', 1),
#  ('Lethal Weapon 4', 1),
#  ('Letters from Iwo Jima', 1),
#  ('Licence to Kill', 1),
#  ('Life of Pi', 1),
#  ('Lions for Lambs', 1),
#  ('Live and Let Die', 1),
#  ('Logans Run', 1),
#  ('Lucky Numbers', 1),
#  ('MacGruber', 1),
#  ('Mad Max 2: The Road Warrior', 1),
#  ('Mad Max Beyond Thunderdome', 1),
#  ('Mad Max', 1),
#  ('Mad Max: Fury Road', 1),
#  ('Madison', 1),
#  ('Maleficent', 1),
#  ('Man of Steel', 1),
#  ('March or Die', 1),
#  ('Maximum Risk', 1),
#  ('Megaforce', 1),
#  ('Men in Black II', 1),
#  ('Men in Black', 1),
#  ('Mercy Streets', 1),
#  ('Mighty Joe Young', 1),
#  ('Mission: Impossible - Ghost Protocol', 1),
#  ('Mission: Impossible - Rogue Nation', 1),
#  ('Mission: Impossible II', 1),
#  ('Mission: Impossible III', 1),
#  ('Mission: Impossible', 1),
#  ('Money Talks', 1),
#  ('Monkeybone', 1),
#  ('Moonraker', 1),
#  ('Mystery Men', 1),
#  ('Nancy Drew', 1),
#  ('National Treasure', 1),
#  ('Never Say Never Again', 1),
#  ('Nicholas Nickleby', 1),
#  ('Night at the Museum', 1),
#  ('Night at the Museum: Battle of the Smithsonian', 1),
#  ('Nothing to Lose', 1),
#  ('Now You See Me 2', 1),
#  ('Nowhere to Run', 1),
#  ('O Brother, Where Art Thou?', 1),
#  ('Oblivion', 1),
#  ('Octopussy', 1),
#  ('On Her Majestys Secret Service', 1),
#  ('Ong Bak 2', 1),
#  ('Osmosis Jones', 1),
#  ('Pacific Rim', 1),
#  ('Paul Blart: Mall Cop', 1),
#  ('Paycheck', 1),
#  ('Pirates of the Caribbean: At Worlds End', 1),
#  ('Pirates of the Caribbean: Dead Mans Chest', 1),
#  ('Pirates of the Caribbean: The Curse of the Black Pearl', 1),
#  ('Pokémon: Spell of the Unknown', 1),
#  ('Pompeii', 1),
#  ('Poseidon', 1),
#  ('Prince of Persia: The Sands of Time', 1),
#  ('Proof of Life', 1),
#  ('Puss in Boots', 1),
#  ('Quantum of Solace', 1),
#  ('Quigley Down Under', 1),
#  ('RED', 1),
#  ('Rabbit-Proof Fence', 1),
#  ('Race to Witch Mountain', 1),
#  ('Raiders of the Lost Ark', 1),
#  ('Rambo III', 1),
#  ('Rambo: First Blood Part II', 1),
#  ('Red Cliff', 1),
#  ('Red Sonja', 1),
#  ('Red Tails', 1),
#  ('Reign of Fire', 1),
#  ('Reno 911!: Miami', 1),
#  ('Resident Evil: Afterlife', 1),
#  ('Return of the Jedi', 1),
#  ('Robin Hood', 1),
#  ('Robin and Marian', 1),
#  ('RoboCop 3', 1),
#  ('Rockaway', 1),
#  ('Ronin', 1),
#  ('Sahara', 1),
#  ('Saints and Soldiers', 1),
#  ('Scott Pilgrim vs. the World', 1),
#  ('Serenity', 1),
#  ('Shaft', 1),
#  ('Shanghai Knights', 1),
#  ('Shanghai Noon', 1),
#  ('Sheena', 1),
#  ('Sherlock Holmes', 1),
#  ('Sherlock Holmes: A Game of Shadows', 1),
#  ('Shin Godzilla', 1),
#  ('Silver Medalist', 1),
#  ('Six Days Seven Nights', 1),
#  ('Six-String Samurai', 1),
#  ('Sky Captain and the World of Tomorrow', 1),
#  ('Skyfall', 1),
#  ('Small Soldiers', 1),
#  ('Sorcerer', 1),
#  ('Southland Tales', 1),
#  ('Space Cowboys', 1),
#  ('Spawn', 1),
#  ('Spectre', 1),
#  ('Speed 2: Cruise Control', 1),
#  ('Speed', 1),
#  ('Spider-Man 2', 1),
#  ('Spider-Man 3', 1),
#  ('Spy Kids 2: The Island of Lost Dreams', 1),
#  ('Spy Kids 3-D: Game Over', 1),
#  ('Spy Kids', 1),
#  ('Star Trek Beyond', 1),
#  ('Star Trek II: The Wrath of Khan', 1),
#  ('Star Trek III: The Search for Spock', 1),
#  ('Star Trek V: The Final Frontier', 1),
#  ('Star Trek VI: The Undiscovered Country', 1),
#  ('Star Trek', 1),
#  ('Star Trek: First Contact', 1),
#  ('Star Trek: Generations', 1),
#  ('Star Trek: Insurrection', 1),
#  ('Star Trek: Nemesis', 1),
#  ('Star Wars', 1),
#  ('Star Wars: Clone Wars: Volume 1', 1),
#  ('Star Wars: Episode I - The Phantom Menace', 1),
#  ('Star Wars: Episode II - Attack of the Clones', 1),
#  ('Star Wars: Episode III - Revenge of the Sith', 1),
#  ('Starship Troopers', 1),
#  ('Steel', 1),
#  ('Stormbreaker', 1),
#  ('Street Fighter', 1),
#  ('Street Fighter: The Legend of Chun-Li', 1),
#  ('Suicide Squad', 1),
#  ('Supercross', 1),
#  ('Superman II', 1),
#  ('Superman III', 1),
#  ('Superman IV: The Quest for Peace', 1),
#  ('Superman Returns', 1),
#  ('Superman', 1),
#  ('Switchback', 1),
#  ('TRON: Legacy', 1),
#  ('Tae Guk Gi: The Brotherhood of War', 1),
#  ('Tango & Cash', 1),
#  ('Team America: World Police', 1),
#  ('Teenage Mutant Ninja Turtles II: The Secret of the Ooze', 1),
#  ('Teenage Mutant Ninja Turtles III', 1),
#  ('Teenage Mutant Ninja Turtles', 1),
#  ('Teenage Mutant Ninja Turtles: Out of the Shadows', 1),
#  ('The 13th Warrior', 1),
#  ('The Abyss', 1),
#  ('The Adventures of Huck Finn', 1),
#  ('The Adventures of Rocky & Bullwinkle', 1),
#  ('The Amazing Spider-Man 2', 1),
#  ('The Amazing Spider-Man', 1),
#  ('The Art of War', 1),
#  ('The Avengers', 1),
#  ('The Big Hit', 1),
#  ('The Black Hole', 1),
#  ('The Blood of Heroes', 1),
#  ('The Borrowers', 1),
#  ('The Brothers Grimm', 1),
#  ('The Cave', 1),
#  ('The Charge of the Light Brigade', 1),
#  ('The Core', 1),
#  ('The Count of Monte Cristo', 1),
#  ('The Covenant', 1),
#  ('The Crocodile Hunter: Collision Course', 1),
#  ('The Day After Tomorrow', 1),
#  ('The Dukes of Hazzard', 1),
#  ('The Edge', 1),
#  ('The Empire Strikes Back', 1),
#  ('The Expendables 2', 1),
#  ('The Expendables 3', 1),
#  ('The Expendables', 1),
#  ('The Forbidden Kingdom', 1),
#  ('The Forsaken', 1),
#  ('The Fugitive', 1),
#  ('The Glimmer Man', 1),
#  ('The Golden Child', 1),
#  ('The Good, The Bad, The Weird', 1),
#  ('The Green Inferno', 1),
#  ('The Hobbit: An Unexpected Journey', 1),
#  ('The Hobbit: The Battle of the Five Armies', 1),
#  ('The Host', 1),
#  ('The Hunger Games: Catching Fire', 1),
#  ('The Hunger Games: Mockingjay - Part 2', 1),
#  ('The Hunt for Red October', 1),
#  ('The Hunting Party', 1),
#  ('The Huntsman: Winters War', 1),
#  ('The Incredible Hulk', 1),
#  ('The Incredibles', 1),
#  ('The Island', 1),
#  ('The Jackal', 1),
#  ('The Last Airbender', 1),
#  ('The Last Dragon', 1),
#  ('The Last Legion', 1),
#  ('The Last Witch Hunter', 1),
#  ('The Last of the Mohicans', 1),
#  ('The Legend of Hells Gate: An American Conspiracy', 1),
#  ('The Legend of Hercules', 1),
#  ('The Legend of Tarzan', 1),
#  ('The Legend of Zorro', 1),
#  ('The Legend of the Lone Ranger', 1),
#  ('The Living Daylights', 1),
#  ('The Lone Ranger', 1),
#  ('The Lord of the Rings: The Fellowship of the Ring', 1),
#  ('The Lord of the Rings: The Return of the King', 1),
#  ('The Lord of the Rings: The Two Towers', 1),
#  ('The Losers', 1),
#  ('The Lost World: Jurassic Park', 1),
#  ('The Lovers', 1),
#  ('The Man from U.N.C.L.E.', 1),
#  ('The Man in the Iron Mask', 1),
#  ('The Man with the Golden Gun', 1),
#  ('The Marine', 1),
#  ('The Mask of Zorro', 1),
#  ('The Matrix Reloaded', 1),
#  ('The Matrix Revolutions', 1),
#  ('The Messenger: The Story of Joan of Arc', 1),
#  ('The Monkey King 2', 1),
#  ('The Mortal Instruments: City of Bones', 1),
#  ('The Mummy Returns', 1),
#  ('The Mummy: Tomb of the Dragon Emperor', 1),
#  ('The Musketeer', 1),
#  ('The Negotiator', 1),
#  ('The Other Side of Heaven', 1),
#  ('The Phantom', 1),
#  ('The Proposition', 1),
#  ('The River Wild', 1),
#  ('The Rock', 1),
#  ('The Rundown', 1),
#  ('The Saint', 1),
#  ('The Scorpion King', 1),
#  ('The Shadow', 1),
#  ('The Sorcerers Apprentice', 1),
#  ('The Spy Who Loved Me', 1),
#  ('The Three Musketeers', 1),
#  ('The Time Machine', 1),
#  ('The Warriors Way', 1),
#  ('The Wolverine', 1),
#  ('The World Is Not Enough', 1),
#  ('Thor', 1),
#  ('Thor: The Dark World', 1),
#  ('Three Kings', 1),
#  ('Thunderball', 1),
#  ('Thunderbirds', 1),
#  ('Tidal Wave', 1),
#  ('Timeline', 1),
#  ('Tombstone', 1),
#  ('Tomorrow Never Dies', 1),
#  ('Tora! Tora! Tora!', 1),
#  ('Total Recall', 1),
#  ('Touching the Void', 1),
#  ('Tracker', 1),
#  ('Transformers', 1),
#  ('Transformers: Age of Extinction', 1),
#  ('Transformers: Dark of the Moon', 1),
#  ('Transformers: Revenge of the Fallen', 1),
#  ('Twister', 1),
#  ('U.F.O.', 1),
#  ('Underworld: Rise of the Lycans', 1),
#  ('Undisputed', 1),
#  ('Valley of the Wolves: Iraq', 1),
#  ('Vertical Limit', 1),
#  ('Virgin Territory', 1),
#  ('Walking Tall', 1),
#  ('War, Inc.', 1),
#  ('Warcraft', 1),
#  ('Waterworld', 1),
#  ('White Fang', 1),
#  ('Wild Hogs', 1),
#  ('Wild Wild West', 1),
#  ('Without a Paddle', 1),
#  ('Witless Protection', 1),
#  ('X-Men Origins: Wolverine', 1),
#  ('X-Men', 1),
#  ('X-Men: Days of Future Past', 1),
#  ('X-Men: First Class', 1),
#  ('X-Men: The Last Stand', 1),
#  ('X2', 1),
#  ('Young Guns', 1),
#  ('Young Sherlock Holmes', 1),
#  ('xXx', 1),
#  ('xXx: State of the Union', 1),
#  ('Abraham Lincoln: Vampire Hunter', 1),
#  ('Aliens vs Predator: Requiem', 1),
#  ('Alone in the Dark', 1),
#  ('Batman & Robin', 1),
#  ('Batman Forever', 1),
#  ('Batman Returns', 1),
#  ('Blade II', 1),
#  ('Bulletproof Monk', 1),
#  ('Curse of the Golden Flower', 1),
#  ('Dawn of the Dead', 1),
#  ('Daybreakers', 1),
#  ('Dracula Untold', 1),
#  ('Dragon Wars: D-War', 1),
#  ('Drive Angry', 1),
#  ('Elektra', 1),
#  ('End of Days', 1),
#  ('Firestarter', 1),
#  ('Ghost Rider', 1),
#  ('Ghost Rider: Spirit of Vengeance', 1),
#  ('Ghostbusters', 1),
#  ('Hancock', 1),
#  ('Hansel & Gretel: Witch Hunters', 1),
#  ('Hellboy', 1),
#  ('Highlander: Endgame', 1),
#  ('Highlander: The Final Dimension', 1),
#  ('Immortals', 1),
#  ('Ink', 1),
#  ('Jack the Giant Slayer', 1),
#  ('Jonah Hex', 1),
#  ('Kung Fu Hustle', 1),
#  ('Mortal Kombat', 1),
#  ('Mortal Kombat: Annihilation', 1),
#  ('My Super Ex-Girlfriend', 1),
#  ('Night Watch', 1),
#  ('Priest', 1),
#  ('R.I.P.D.', 1),
#  ('Spider-Man', 1),
#  ('Sucker Punch', 1),
#  ('Tank Girl', 1),
#  ('The Beastmaster', 1),
#  ('The Crow', 1),
#  ('The Inhabited Island', 1),
#  ('The League of Extraordinary Gentlemen', 1),
#  ('The Medallion', 1),
#  ('The Nutcracker: The Untold Story', 1),
#  ('The Promise', 1),
#  ('Underworld', 1),
#  ('Underworld: Awakening', 1),
#  ('Underworld: Evolution', 1),
#  ('V for Vendetta', 1),
#  ('Vampires', 1),
#  ('Warriors of Virtue', 1),
#  ('Alien Zone', 1),
#  ('Alien: Resurrection', 1),
#  ('American Hero', 1),
#  ('Astro Boy', 1),
#  ('Attack the Block', 1),
#  ('Battle for the Planet of the Apes', 1),
#  ('Battlefield Earth', 1),
#  ('Capricorn One', 1),
#  ('Carriers', 1),
#  ('Chain Reaction', 1),
#  ('Chappie', 1),
#  ('Children of Men', 1),
#  ('Cloverfield', 1),
#  ('Conquest of the Planet of the Apes', 1),
#  ('Dawn of the Planet of the Apes', 1),
#  ('Death Race 2000', 1),
#  ('Death Race', 1),
#  ('Deep Blue Sea', 1),
#  ('Diary of the Dead', 1),
#  ('District B13', 1),
#  ('Doomsday', 1),
#  ('Dredd', 1),
#  ('Dylan Dog: Dead of Night', 1),
#  ('Echo Dr.', 1),
#  ('Elysium', 1),
#  ('Equilibrium', 1),
#  ('Escape from New York', 1),
#  ('Escape from the Planet of the Apes', 1),
#  ('Face/Off', 1),
#  ('Fortress', 1),
#  ('Gamer', 1),
#  ('Ghosts of Mars', 1),
#  ('Hav Plenty', 1),
#  ('Hollow Man', 1),
#  ('Hulk', 1),
#  ('I Am Legend', 1),
#  ('Impostor', 1),
#  ('In Time', 1),
#  ('Independence Daysaster', 1),
#  ('Krrish', 1),
#  ('Lake Placid', 1),
#  ('Left Behind', 1),
#  ('Looper', 1),
#  ('Lucy', 1),
#  ('Megamind', 1),
#  ('Megiddo: The Omega Code 2', 1),
#  ('Men in Black 3', 1),
#  ('Meteor', 1),
#  ('Minority Report', 1),
#  ('Outbreak', 1),
#  ('Pandorum', 1),
#  ('Phantasm II', 1),
#  ('Pitch Black', 1),
#  ('Pixels', 1),
#  ('Predator 2', 1),
#  ('Real Steel', 1),
#  ('Red Planet', 1),
#  ('Repo Men', 1),
#  ('Resident Evil', 1),
#  ('Resident Evil: Apocalypse', 1),
#  ('Resident Evil: Extinction', 1),
#  ('Resident Evil: Retribution', 1),
#  ('Riddick', 1),
#  ('Rise of the Planet of the Apes', 1),
#  ('RoboCop', 1),
#  ('Rollerball', 1),
#  ('Snowpiercer', 1),
#  ('Soldier', 1),
#  ('Species', 1),
#  ('Speed Racer', 1),
#  ('Split Second', 1),
#  ('Stake Land', 1),
#  ('Superhero Movie', 1),
#  ('Surrogates', 1),
#  ('Terminator 2: Judgment Day', 1),
#  ('Terminator 3: Rise of the Machines', 1),
#  ('Terminator Salvation', 1),
#  ('The Adventures of Pluto Nash', 1),
#  ('The Book of Eli', 1),
#  ('The Chronicles of Riddick', 1),
#  ('The Darkest Hour', 1),
#  ('The Dead Undead', 1),
#  ('The Devils Tomb', 1),
#  ('The Helix... Loaded', 1),
#  ('The Ice Pirates', 1),
#  ('The Matrix', 1),
#  ('The Maze Runner', 1),
#  ('The One', 1),
#  ('The Running Man', 1),
#  ('The Spirit', 1),
#  ('The Stepford Wives', 1),
#  ('The Terminator', 1),
#  ('The Toxic Avenger', 1),
#  ('The Tuxedo', 1),
#  ('The Worlds End', 1),
#  ('The Wraith', 1),
#  ('They Live', 1),
#  ('Timecop', 1),
#  ('Ultraviolet', 1),
#  ('Universal Soldier: The Return', 1),
#  ('Virtuosity', 1),
#  ('Volcano', 1),
#  ('Watchmen', 1),
#  ('Wing Commander', 1),
#  ('World War Z', 1),
#  ('Zombie Hunter', 1),
#  ('eXistenZ', 1),
#  ('Æon Flux', 1),
#  ('A Simple Wish', 1),
#  ('Aladdin', 1),
#  ('Alice in Wonderland', 1),
#  ('Aliens in the Attic', 1),
#  ('Arthur and the Invisibles', 1),
#  ('Asterix at the Olympic Games', 1),
#  ('Babe: Pig in the City', 1),
#  ('Big Fish', 1),
#  ('Bill & Teds Bogus Journey', 1),
#  ('Black Knight', 1),
#  ('Charlie and the Chocolate Factory', 1),
#  ('City of Ember', 1),
#  ('Delgo', 1),
#  ('Dogma', 1),
#  ('Dragon Nest: Warriors Dawn', 1),
#  ('E.T. the Extra-Terrestrial', 1),
#  ('Epic', 1),
#  ('Forbidden Kingdom', 1),
#  ('Harry Potter and the Chamber of Secrets', 1),
#  ('Harry Potter and the Goblet of Fire', 1),
#  ('Harry Potter and the Half-Blood Prince', 1),
#  ('Harry Potter and the Order of the Phoenix', 1),
#  ('Harry Potter and the Philosophers Stone', 1),
#  ('Harry Potter and the Prisoner of Azkaban', 1),
#  ('Hellboy II: The Golden Army', 1),
#  ('Herbie Fully Loaded', 1),
#  ('Hook', 1),
#  ('How to Train Your Dragon', 1),
#  ('Howls Moving Castle', 1),
#  ('Inkheart', 1),
#  ('Jumper', 1),
#  ('Ladyhawke', 1),
#  ('Legend of the Guardians: The Owls of GaHoole', 1),
#  ('Mirror Mirror', 1),
#  ('Monty Python and the Holy Grail', 1),
#  ('Night at the Museum: Secret of the Tomb', 1),
#  ('Nims Island', 1),
#  ('Oz: The Great and Powerful', 1),
#  ('Pan', 1),
#  ('Percy Jackson & the Olympians: The Lightning Thief', 1),
#  ('Percy Jackson: Sea of Monsters', 1),
#  ('Petes Dragon', 1),
#  ('Princess Mononoke', 1),
#  ('Return to Never Land', 1),
#  ('Return to Oz', 1),
#  ('Sausage Party', 1),
#  ('Savva. Heart of the Warrior', 1),
#  ('Scooby-Doo 2: Monsters Unleashed', 1),
#  ('Seventh Son', 1),
#  ('Shrek 2', 1),
#  ('Shrek Forever After', 1),
#  ('Shrek the Third', 1),
#  ('Shrek', 1),
#  ('Snow White and the Huntsman', 1),
#  ('Son of the Mask', 1),
#  ('Spice World', 1),
#  ('Spirited Away', 1),
#  ('Stardust', 1),
#  ('Super Mario Bros.', 1),
#  ('The Adventurer: The Curse of the Midas Box', 1),
#  ('The Ant Bully', 1),
#  ('The BFG', 1),
#  ('The Barbarians', 1),
#  ('The Book of Life', 1),
#  ('The Brave Little Toaster', 1),
#  ('The Chronicles of Narnia: Prince Caspian', 1),
#  ('The Chronicles of Narnia: The Lion, the Witch and the Wardrobe', 1),
#  ('The Chronicles of Narnia: The Voyage of the Dawn Treader', 1),
#  ('The Croods', 1),
#  ('The Emperors New Groove', 1),
#  ('The Golden Compass', 1),
#  ('The Hobbit: The Desolation of Smaug', 1),
#  ('The Hole', 1),
#  ('The Hunger Games', 1),
#  ('The Imaginarium of Doctor Parnassus', 1),
#  ('The Indian in the Cupboard', 1),
#  ('The Iron Giant', 1),
#  ('The Jungle Book', 1),
#  ('The Lego Movie', 1),
#  ('The Little Prince', 1),
#  ('The NeverEnding Story', 1),
#  ('The Polar Express', 1),
#  ('The Princess Bride', 1),
#  ('The Secret Life of Walter Mitty', 1),
#  ('The Smurfs', 1),
#  ('The Spiderwick Chronicles', 1),
#  ('The Thief and the Cobbler', 1),
#  ('The Twilight Saga: Breaking Dawn - Part 2', 1),
#  ('The Twilight Saga: Eclipse', 1),
#  ('The Twilight Saga: New Moon', 1),
#  ('The Wiz', 1),
#  ('The Wizard of Oz', 1),
#  ('Thunder and the House of Magic', 1),
#  ('Time Bandits', 1),
#  ('Twilight', 1),
#  ('Warlock', 1),
#  ('Zathura: A Space Adventure', 1),
#  ('20,000 Leagues Under the Sea', 1),
#  ('2001: A Space Odyssey', 1),
#  ('A.I. Artificial Intelligence', 1),
#  ('Allegiant', 1),
#  ('Atlantis: The Lost Empire', 1),
#  ('Austin Powers: The Spy Who Shagged Me', 1),
#  ('Back to the Future Part II', 1),
#  ('Back to the Future Part III', 1),
#  ('Back to the Future', 1),
#  ('Beneath the Planet of the Apes', 1),
#  ('Bill & Teds Excellent Adventure', 1),
#  ('Clockstoppers', 1),
#  ...]

# %% [markdown]
# # **3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις-Αξιολογήσεις του χρήστη-Εκπαίδευση και Πρόβλεψη**

# %% [markdown]
# * Αρχικά μελετάμε τις αξιολογήσεις κάθε χρήστη για να καταλάβουμε την δομή και τις πληροφορίες κάθε αρχείου.
# * Ορίζω τα βάρη με τα οποία θα χρησιμοποιήσω τις αξιολογήσεις που βρίσκονται στα datasets, με βάση τον βαθμό ομοιότητας που υπολογίζει ο recommender μου.
# * Έτσι, ορίζω την συνάρτηση εκπαίδευσης των recommenders, και την συνάρτηση με την οποία θα βρίσκω τις προβλέψεις τους.

# %%
from tqdm.notebook import tqdm
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import random

score_weights = {
    1: 1,
    2: 2,
    3: 5,
    4: 8,
    5: 15,
}

rating_weights = {
    0: -2,
    1: -1,
    2: 0,
    3: 4,
    4: 7,
    5: 10,
}

def train_recommender(ratings, rating_weights, score_weights, number_of_movies = 10):
    """
    Στην συνάρτηση αυτή μπορούμε να ορίζουμε ποιο υποσύνολο των αξιολογήσεων θα χρησιμοποιήσουμε
    για το train μαζί με τα βάρη ομοιότητας και σκορ
    Σε συνδυασμό με τον αριθμό των ταινιών που θέλουμε να χρησιμοποιήσουμε σαν σύνολο δεδομένων
    π.χ. 10 από τις 100 ή 3 από τις 100 κ.ο.κ
    Αν θέλουμε να χρησιμοποιήσουμε όλες τις ταινίες σαν training set τότε ορίζουμε το number_of_movies = - 1
    """

    if number_of_movies > len(ratings):
        number_of_movies = len(ratings)


    if number_of_movies != -1:
        indexes = random.sample(range(len(ratings)), number_of_movies)
        ratings = ratings.iloc[indexes]

    movie_score = {}
    
    for row in tqdm(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = int(getattr(row, 'rating'))

        similar_movies = simple_recommender(movie)
        for sim in similar_movies:
            similar_movie, similarity_score = sim 
            if similar_movie not in movie_score:
                movie_score[similar_movie] = rating_weights[rating] * score_weights[similarity_score]
            else:
                movie_score[similar_movie] += rating_weights[rating] * score_weights[similarity_score] #το weight θα το ορίσετε ανα επίπεδο ομοιότητας οι πολύ όμοιες ταινίες θα έχουν μεγαλύτερο βάρος
    return movie_score


#αυτό είναι ένα παράδειγμα για το πως θα μπορούσε να υλοποιήθει η predict
#έχουμε ορίσει ότι μια ταινία θα έπρεπε να είναι προτεινόμενη αν είχε σκορ > 0
def predict_example(ratings, movie_score):
    real, pred = [], []
    
    for i, row in enumerate(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        if movie in movie_score.keys(): #αν έχουμε σχηματίσει βαθμολογία για την ταινία αυτή
            pred.append(int(movie_score[movie] > 0)) #heuristic για το αν μια ταινία είναι προτεινόμενη
            real.append(int(rating > 3))# έτσι ορίζουμε ότι μια ταινία θα έπρεπε να είναι προτεινόμενη
            #η συνθήκη αυτή δεν μπορεί να αλλάξει
        else: #δεν μπορούμε να προτείνουμε κάτι για το όποιο δεν έχουμε σχηματίσει εικόνα
            pred.append(0)
            real.append(int(rating > 3))
    return real, pred


def get_metrics(real, pred):
    metrics = {}
    metrics["precision"] = precision_score(real, pred, zero_division=True)
    metrics["recall"] = recall_score(real, pred)
    metrics["f1"] = f1_score(real, pred)
    return metrics

# %% [markdown]
# Οι παραπάνω εκπαιδεύουν, τεστάρουν και μετρούν την απόδοσή του συστήματος στάσεων μας.
# Για την εκπαίδευση του συστήματος μπορούμε κάθε φορά να χρησιμοποιήσουμε ένα τυχαίο υποσύνολο του training set.
# Όμως είναι πιθανό το υποσύνολο των ταινιών αυτόν να επηρεάζει τα αποτελέσματα στο training set.
# Για παράδειγμα, για ένα πείραμα, αν επιλέξουμε 3 ταινίες στις 10, τα αποτελέσματα μας μπορεί να είναι ίδια και αυτό να μην οφείλεται στο γεγονός ότι ο ταξινομητής μας τα πηγαίνει καλά στις 3 ταινίες αλλά στο γεγονός ότι οι υπόλοιπες 7 είναι τέτοιες ταινίες που δεν μας βοηθούν καθόλου.
# Αν είχαμε επιλέξει διαφορετικές 3 ταινίες, μπορεί να τα πηγαίναμε χάλια.
# Οπότε, προτείνουμε να τρέξετε κάθε φορά έναν αριθμό πειραμάτων για κάθε υποσύνολο ταινιών π.χ. 10 πειράματα με 3 ταινίες, 10 πειράματα για 20 ταινίες κ.ο.κ. και να κρατήσετε σαν τελικό σκορ το μέσο όρο όλων των πειραμάτων. Έτσι τα αποτελέσματα των προβλέψεών σας θα είναι πιο αντικειμενικά.

# %%
train_ratings = pd.read_csv(path + "train_ratings.csv")
test_ratings = pd.read_csv(path + "test_ratings.csv")

# %% [markdown]
# * Εκπαιδεύω τον recommender δοκιμάζοντας διαφορετικές τιμές της παραμέτρου number_of_movies της train, ώστε να καταλήξω σε συμπέρασμα σχετικά με την καλύτερη χρήση του (για νέους ή παλιούς χρήστες).

# %%
from statistics import mean
all_metrics = dict()

for num in range(5, len(train_ratings)+1, 5):
    print("Training for number of movies:", num)
    all_metrics[num] = dict()
    metrics = []
    for i in range (10):
      print(f"\t* Epoch {i}", end='')
      movie_score = train_recommender(train_ratings, rating_weights, score_weights, 10)
      real, pred = predict_example(test_ratings, movie_score)
      metrics.append(get_metrics(real, pred))

    for metric in metrics[0].keys():
        val = np.mean([m[metric] for m in metrics])
        print (f"{metric}: {val}")
        all_metrics[num][metric] = val
    
for d in all_metrics:
  print(d, all_metrics[d])
# Out:
# Training for number of movies: 5
# 	* Epoch 0
# 0it [00:00, ?it/s]
# 	* Epoch 1
# 0it [00:00, ?it/s]
# 	* Epoch 2
# 0it [00:00, ?it/s]
# 	* Epoch 3
# 0it [00:00, ?it/s]
# 	* Epoch 4
# 0it [00:00, ?it/s]
# 	* Epoch 5
# 0it [00:00, ?it/s]
# 	* Epoch 6
# 0it [00:00, ?it/s]
# 	* Epoch 7
# 0it [00:00, ?it/s]
# 	* Epoch 8
# 0it [00:00, ?it/s]
# 	* Epoch 9
# 0it [00:00, ?it/s]
# precision: 0.4958816469065555
# recall: 0.5986111111111111
# f1: 0.5336293114254639
# Training for number of movies: 10
# 	* Epoch 0
# 0it [00:00, ?it/s]
# 	* Epoch 1
# 0it [00:00, ?it/s]
# 	* Epoch 2
# 0it [00:00, ?it/s]
# 	* Epoch 3
# 0it [00:00, ?it/s]
# 	* Epoch 4
# 0it [00:00, ?it/s]
# 	* Epoch 5
# 0it [00:00, ?it/s]
# 	* Epoch 6
# 0it [00:00, ?it/s]
# 	* Epoch 7
# 0it [00:00, ?it/s]
# 	* Epoch 8
# 0it [00:00, ?it/s]
# 	* Epoch 9
# 0it [00:00, ?it/s]
# precision: 0.5072161469178854
# recall: 0.6055555555555555
# f1: 0.5451511195184301
# Training for number of movies: 15
# 	* Epoch 0
# 0it [00:00, ?it/s]
# 	* Epoch 1
# 0it [00:00, ?it/s]
# 	* Epoch 2
# 0it [00:00, ?it/s]
# 	* Epoch 3
# 0it [00:00, ?it/s]
# 	* Epoch 4
# 0it [00:00, ?it/s]
# 	* Epoch 5
# 0it [00:00, ?it/s]
# 	* Epoch 6
# 0it [00:00, ?it/s]
# 	* Epoch 7
# 0it [00:00, ?it/s]
# 	* Epoch 8
# 0it [00:00, ?it/s]
# 	* Epoch 9
# 0it [00:00, ?it/s]
# precision: 0.4985615963156628
# recall: 0.5625
# f1: 0.5236486891212796
# Training for number of movies: 20
# 	* Epoch 0
# 0it [00:00, ?it/s]
# 	* Epoch 1
# 0it [00:00, ?it/s]
# 	* Epoch 2
# 0it [00:00, ?it/s]
# 	* Epoch 3
# 0it [00:00, ?it/s]
# 	* Epoch 4
# 0it [00:00, ?it/s]
# 	* Epoch 5
# 0it [00:00, ?it/s]
# 	* Epoch 6
# 0it [00:00, ?it/s]
# 	* Epoch 7
# 0it [00:00, ?it/s]
# 	* Epoch 8
# 0it [00:00, ?it/s]
# 	* Epoch 9
# 0it [00:00, ?it/s]
# precision: 0.49298498292379483
# recall: 0.5986111111111111
# f1: 0.5372410713046369
# Training for number of movies: 25
# 	* Epoch 0
# 0it [00:00, ?it/s]
# 	* Epoch 1
# 0it [00:00, ?it/s]
# 	* Epoch 2
# 0it [00:00, ?it/s]
# 	* Epoch 3
# 0it [00:00, ?it/s]
# 	* Epoch 4
# 0it [00:00, ?it/s]
# 	* Epoch 5
# 0it [00:00, ?it/s]
# 	* Epoch 6
# 0it [00:00, ?it/s]
# 	* Epoch 7
# 0it [00:00, ?it/s]
# 	* Epoch 8
# 0it [00:00, ?it/s]
# 	* Epoch 9
# 0it [00:00, ?it/s]
# precision: 0.4787241663199772
# recall: 0.5666666666666667
# f1: 0.5165126360512013
# Training for number of movies: 30
# 	* Epoch 0
# 0it [00:00, ?it/s]
# 	* Epoch 1
# 0it [00:00, ?it/s]
# 	* Epoch 2
# 0it [00:00, ?it/s]
# 	* Epoch 3
# 0it [00:00, ?it/s]
# 	* Epoch 4
# 0it [00:00, ?it/s]
# 	* Epoch 5
# 0it [00:00, ?it/s]
# 	* Epoch 6
# 0it [00:00, ?it/s]
# 	* Epoch 7
# 0it [00:00, ?it/s]
# 	* Epoch 8
# 0it [00:00, ?it/s]
# 	* Epoch 9
# 0it [00:00, ?it/s]
# precision: 0.49281599145915395
# recall: 0.5722222222222222
# f1: 0.5255002699472346
# Training for number of movies: 35
# 	* Epoch 0
# 0it [00:00, ?it/s]
# 	* Epoch 1
# 0it [00:00, ?it/s]
# 	* Epoch 2
# 0it [00:00, ?it/s]
# 	* Epoch 3
# 0it [00:00, ?it/s]
# 	* Epoch 4
# 0it [00:00, ?it/s]
# 	* Epoch 5
# 0it [00:00, ?it/s]
# 	* Epoch 6
# 0it [00:00, ?it/s]
# 	* Epoch 7
# 0it [00:00, ?it/s]
# 	* Epoch 8
# 0it [00:00, ?it/s]
# 	* Epoch 9
# 0it [00:00, ?it/s]
# precision: 0.48649845923240653
# recall: 0.5999999999999999
# f1: 0.5329063730386105
# Training for number of movies: 40
# 	* Epoch 0
# 0it [00:00, ?it/s]
# 	* Epoch 1
# 0it [00:00, ?it/s]
# 	* Epoch 2
# 0it [00:00, ?it/s]
# 	* Epoch 3
# 0it [00:00, ?it/s]
# 	* Epoch 4
# 0it [00:00, ?it/s]
# 	* Epoch 5
# 0it [00:00, ?it/s]
# 	* Epoch 6
# 0it [00:00, ?it/s]
# 	* Epoch 7
# 0it [00:00, ?it/s]
# 	* Epoch 8
# 0it [00:00, ?it/s]
# 	* Epoch 9
# 0it [00:00, ?it/s]
# precision: 0.49563637914408243
# recall: 0.601388888888889
# f1: 0.5413133790803715
# Training for number of movies: 45
# 	* Epoch 0
# 0it [00:00, ?it/s]
# 	* Epoch 1
# 0it [00:00, ?it/s]
# 	* Epoch 2
# 0it [00:00, ?it/s]
# 	* Epoch 3
# 0it [00:00, ?it/s]
# 	* Epoch 4
# 0it [00:00, ?it/s]
# 	* Epoch 5
# 0it [00:00, ?it/s]
# 	* Epoch 6
# 0it [00:00, ?it/s]
# 	* Epoch 7
# 0it [00:00, ?it/s]
# 	* Epoch 8
# 0it [00:00, ?it/s]
# 	* Epoch 9
# 0it [00:00, ?it/s]
# precision: 0.5026279247887151
# recall: 0.625
# f1: 0.5548000317999605
# Training for number of movies: 50
# 	* Epoch 0
# 0it [00:00, ?it/s]
# 	* Epoch 1
# 0it [00:00, ?it/s]
# 	* Epoch 2
# 0it [00:00, ?it/s]
# 	* Epoch 3
# 0it [00:00, ?it/s]
# 	* Epoch 4
# 0it [00:00, ?it/s]
# 	* Epoch 5
# 0it [00:00, ?it/s]
# 	* Epoch 6
# 0it [00:00, ?it/s]
# 	* Epoch 7
# 0it [00:00, ?it/s]
# 	* Epoch 8
# 0it [00:00, ?it/s]
# 	* Epoch 9
# 0it [00:00, ?it/s]
# precision: 0.5093315473471226
# recall: 0.6138888888888889
# f1: 0.552825596271182
# Training for number of movies: 55
# 	* Epoch 0
# 0it [00:00, ?it/s]
# 	* Epoch 1
# 0it [00:00, ?it/s]
# 	* Epoch 2
# 0it [00:00, ?it/s]
# 	* Epoch 3
# 0it [00:00, ?it/s]
# 	* Epoch 4
# 0it [00:00, ?it/s]
# 	* Epoch 5
# 0it [00:00, ?it/s]
# 	* Epoch 6
# 0it [00:00, ?it/s]
# 	* Epoch 7
# 0it [00:00, ?it/s]
# 	* Epoch 8
# 0it [00:00, ?it/s]
# 	* Epoch 9
# 0it [00:00, ?it/s]
# precision: 0.49402480617404115
# recall: 0.6430555555555555
# f1: 0.5555740417483379
# Training for number of movies: 60
# 	* Epoch 0
# 0it [00:00, ?it/s]
# 	* Epoch 1
# 0it [00:00, ?it/s]
# 	* Epoch 2
# 0it [00:00, ?it/s]
# 	* Epoch 3
# 0it [00:00, ?it/s]
# 	* Epoch 4
# 0it [00:00, ?it/s]
# 	* Epoch 5
# 0it [00:00, ?it/s]
# 	* Epoch 6
# 0it [00:00, ?it/s]
# 	* Epoch 7
# 0it [00:00, ?it/s]
# 	* Epoch 8
# 0it [00:00, ?it/s]
# 	* Epoch 9
# 0it [00:00, ?it/s]
# precision: 0.5058633088418075
# recall: 0.5694444444444444
# f1: 0.5309491999526268
# Training for number of movies: 65
# 	* Epoch 0
# 0it [00:00, ?it/s]
# 	* Epoch 1
# 0it [00:00, ?it/s]
# 	* Epoch 2
# 0it [00:00, ?it/s]
# 	* Epoch 3
# 0it [00:00, ?it/s]
# 	* Epoch 4
# 0it [00:00, ?it/s]
# 	* Epoch 5
# 0it [00:00, ?it/s]
# 	* Epoch 6
# 0it [00:00, ?it/s]
# 	* Epoch 7
# 0it [00:00, ?it/s]
# 	* Epoch 8
# 0it [00:00, ?it/s]
# 	* Epoch 9
# 0it [00:00, ?it/s]
# precision: 0.49514418680016925
# recall: 0.5944444444444443
# f1: 0.538422373612663
# Training for number of movies: 70
# 	* Epoch 0
# 0it [00:00, ?it/s]
# 	* Epoch 1
# 0it [00:00, ?it/s]
# 	* Epoch 2
# 0it [00:00, ?it/s]
# 	* Epoch 3
# 0it [00:00, ?it/s]
# 	* Epoch 4
# 0it [00:00, ?it/s]
# 	* Epoch 5
# 0it [00:00, ?it/s]
# 	* Epoch 6
# 0it [00:00, ?it/s]
# 	* Epoch 7
# 0it [00:00, ?it/s]
# 	* Epoch 8
# 0it [00:00, ?it/s]
# 	* Epoch 9
# 0it [00:00, ?it/s]
# precision: 0.49412044591488213
# recall: 0.5722222222222222
# f1: 0.5264723836034106
# Training for number of movies: 75
# 	* Epoch 0
# 0it [00:00, ?it/s]
# 	* Epoch 1
# 0it [00:00, ?it/s]
# 	* Epoch 2
# 0it [00:00, ?it/s]
# 	* Epoch 3
# 0it [00:00, ?it/s]
# 	* Epoch 4
# 0it [00:00, ?it/s]
# 	* Epoch 5
# 0it [00:00, ?it/s]
# 	* Epoch 6
# 0it [00:00, ?it/s]
# 	* Epoch 7
# 0it [00:00, ?it/s]
# 	* Epoch 8
# 0it [00:00, ?it/s]
# 	* Epoch 9
# 0it [00:00, ?it/s]
# precision: 0.4785572952891739
# recall: 0.5611111111111111
# f1: 0.5125434547038143
# Training for number of movies: 80
# 	* Epoch 0
# 0it [00:00, ?it/s]
# 	* Epoch 1
# 0it [00:00, ?it/s]
# 	* Epoch 2
# 0it [00:00, ?it/s]
# 	* Epoch 3
# 0it [00:00, ?it/s]
# 	* Epoch 4
# 0it [00:00, ?it/s]
# 	* Epoch 5
# 0it [00:00, ?it/s]
# 	* Epoch 6
# 0it [00:00, ?it/s]
# 	* Epoch 7
# 0it [00:00, ?it/s]
# 	* Epoch 8
# 0it [00:00, ?it/s]
# 	* Epoch 9
# 0it [00:00, ?it/s]
# precision: 0.49589861644482236
# recall: 0.6097222222222223
# f1: 0.5426029291846072
# Training for number of movies: 85
# 	* Epoch 0
# 0it [00:00, ?it/s]
# 	* Epoch 1
# 0it [00:00, ?it/s]
# 	* Epoch 2
# 0it [00:00, ?it/s]
# 	* Epoch 3
# 0it [00:00, ?it/s]
# 	* Epoch 4
# 0it [00:00, ?it/s]
# 	* Epoch 5
# 0it [00:00, ?it/s]
# 	* Epoch 6
# 0it [00:00, ?it/s]
# 	* Epoch 7
# 0it [00:00, ?it/s]
# 	* Epoch 8
# 0it [00:00, ?it/s]
# 	* Epoch 9
# 0it [00:00, ?it/s]
# precision: 0.4870989353494938
# recall: 0.5750000000000001
# f1: 0.5233264749430726
# Training for number of movies: 90
# 	* Epoch 0
# 0it [00:00, ?it/s]
# 	* Epoch 1
# 0it [00:00, ?it/s]
# 	* Epoch 2
# 0it [00:00, ?it/s]
# 	* Epoch 3
# 0it [00:00, ?it/s]
# 	* Epoch 4
# 0it [00:00, ?it/s]
# 	* Epoch 5
# 0it [00:00, ?it/s]
# 	* Epoch 6
# 0it [00:00, ?it/s]
# 	* Epoch 7
# 0it [00:00, ?it/s]
# 	* Epoch 8
# 0it [00:00, ?it/s]
# 	* Epoch 9
# 0it [00:00, ?it/s]
# precision: 0.49561862743678137
# recall: 0.5402777777777777
# f1: 0.498416079991528
# Training for number of movies: 95
# 	* Epoch 0
# 0it [00:00, ?it/s]
# 	* Epoch 1
# 0it [00:00, ?it/s]
# 	* Epoch 2
# 0it [00:00, ?it/s]
# 	* Epoch 3
# 0it [00:00, ?it/s]
# 	* Epoch 4
# 0it [00:00, ?it/s]
# 	* Epoch 5
# 0it [00:00, ?it/s]
# 	* Epoch 6
# 0it [00:00, ?it/s]
# 	* Epoch 7
# 0it [00:00, ?it/s]
# 	* Epoch 8
# 0it [00:00, ?it/s]
# 	* Epoch 9
# 0it [00:00, ?it/s]
# precision: 0.504683892543615
# recall: 0.6222222222222222
# f1: 0.5547682505159297
# Training for number of movies: 100
# 	* Epoch 0
# 0it [00:00, ?it/s]
# 	* Epoch 1
# 0it [00:00, ?it/s]
# 	* Epoch 2
# 0it [00:00, ?it/s]
# 	* Epoch 3
# 0it [00:00, ?it/s]
# 	* Epoch 4
# 0it [00:00, ?it/s]
# 	* Epoch 5
# 0it [00:00, ?it/s]
# 	* Epoch 6
# 0it [00:00, ?it/s]
# 	* Epoch 7
# 0it [00:00, ?it/s]
# 	* Epoch 8
# 0it [00:00, ?it/s]
# 	* Epoch 9
# 0it [00:00, ?it/s]
# precision: 0.4939413699942051
# recall: 0.5847222222222223
# f1: 0.525855536110898
# 5 {'precision': 0.4958816469065555, 'recall': 0.5986111111111111, 'f1': 0.5336293114254639}
# 10 {'precision': 0.5072161469178854, 'recall': 0.6055555555555555, 'f1': 0.5451511195184301}
# 15 {'precision': 0.4985615963156628, 'recall': 0.5625, 'f1': 0.5236486891212796}
# 20 {'precision': 0.49298498292379483, 'recall': 0.5986111111111111, 'f1': 0.5372410713046369}
# 25 {'precision': 0.4787241663199772, 'recall': 0.5666666666666667, 'f1': 0.5165126360512013}
# 30 {'precision': 0.49281599145915395, 'recall': 0.5722222222222222, 'f1': 0.5255002699472346}
# 35 {'precision': 0.48649845923240653, 'recall': 0.5999999999999999, 'f1': 0.5329063730386105}
# 40 {'precision': 0.49563637914408243, 'recall': 0.601388888888889, 'f1': 0.5413133790803715}
# 45 {'precision': 0.5026279247887151, 'recall': 0.625, 'f1': 0.5548000317999605}
# 50 {'precision': 0.5093315473471226, 'recall': 0.6138888888888889, 'f1': 0.552825596271182}
# 55 {'precision': 0.49402480617404115, 'recall': 0.6430555555555555, 'f1': 0.5555740417483379}
# 60 {'precision': 0.5058633088418075, 'recall': 0.5694444444444444, 'f1': 0.5309491999526268}
# 65 {'precision': 0.49514418680016925, 'recall': 0.5944444444444443, 'f1': 0.538422373612663}
# 70 {'precision': 0.49412044591488213, 'recall': 0.5722222222222222, 'f1': 0.5264723836034106}
# 75 {'precision': 0.4785572952891739, 'recall': 0.5611111111111111, 'f1': 0.5125434547038143}
# 80 {'precision': 0.49589861644482236, 'recall': 0.6097222222222223, 'f1': 0.5426029291846072}
# 85 {'precision': 0.4870989353494938, 'recall': 0.5750000000000001, 'f1': 0.5233264749430726}
# 90 {'precision': 0.49561862743678137, 'recall': 0.5402777777777777, 'f1': 0.498416079991528}
# 95 {'precision': 0.504683892543615, 'recall': 0.6222222222222222, 'f1': 0.5547682505159297}
# 100 {'precision': 0.4939413699942051, 'recall': 0.5847222222222223, 'f1': 0.525855536110898}

# %% [markdown]
# * Συνοψίζω γραφικά τα αποτελέσματα για τις 3 μετρικές precision, recall, f1 με χρήση διαφορετικών πληθών ταινιών του training set κάθε φορά:

# %%
import matplotlib.pyplot as plt

def my_plot(name, axs):
    # plt.figure()
    axs.plot([k for k in all_metrics], [all_metrics[k][name] for k in all_metrics])
    axs.set_title(name)
    axs.set(xlabel='number_of_movies')

fig, axs = plt.subplots(1, 3, figsize=(30, 5), sharey=True)
my_plot('precision', axs[0])
my_plot('recall', axs[1])
my_plot('f1', axs[2])

# %%
precisions = [x[0] for x in sorted(all_metrics.items(), key= lambda x: x[1]['precision'], reverse=True)]
recalls = [x[0] for x in sorted(all_metrics.items(), key= lambda x: x[1]['recall'], reverse=True)]
f1s = [x[0] for x in sorted(all_metrics.items(), key= lambda x: x[1]['f1'], reverse=True)]
print("Reversely sorted number_of_movies for:")
print("\t* highest precision-scores:", precisions)
print("\t* highest recall-scores:   ", recalls)
print("\t* highest f1-scores:       ", f1s)
# Out:
# Reversely sorted number_of_movies for:
# 	* highest precision-scores: [50, 10, 60, 95, 45, 15, 80, 5, 40, 90, 65, 70, 55, 100, 20, 30, 85, 35, 25, 75]
# 	* highest recall-scores:    [55, 45, 95, 50, 80, 10, 40, 35, 5, 20, 65, 100, 85, 30, 70, 60, 25, 15, 75, 90]
# 	* highest f1-scores:        [55, 45, 95, 50, 10, 80, 40, 65, 20, 5, 35, 60, 70, 100, 30, 15, 85, 25, 75, 90]

# %% [markdown]
# # Συμπεράσματα

# %% [markdown]
# * Παρατηρώ ότι οι μετρική accuracy κυμαίνεται περίπου στο 50%, η f1 στο 55% και η recall λίγο πάνω από το 60%.
# * Έτσι, καταλαβαίνω ότι σε γενικές γραμμές, περίπου οι μισές ταινίες που προβλέπει ο recommender είναι σωστές.
# * Επίσης, παρατηρώ ότι τα ποσοστά αυξομειώνονται με μη συστηματικό τρόπο, με υψηλές ζώνες για number_of_movies γύρω στο το 10%, το 50%, το 80% και γύρω στο 90%.
# * Ωστόσο, σε γενικές γραμμές δεν παρατηρείται κάποια ιδιαίτερα σημαντική αύξηση των μετρικών  με την αύξηση της παραμέτρου number_of_movies (πέρα από ένα peak του recall για number_of_movies=55).
# * Επομένως, θα μπορούσαμε να πούμε ότι ο recommender μπορεί να χρησιμοποιηθεί αποτελεσματικά για σχετικά νέους χρήστες (που να έχουν προβεί ήδη σε περίπου 10 αξιολογήσεις).
